# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Dec 22 10:51:46 2023

@author: yhzha
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score,roc_auc_score,average_precision_score

from itertools import combinations
from utilPlus import gcm_test,anm_test
import os
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

import datetime
import pytz

def causalDirect(p_value_foward,p_value_backward,v1,v2,alpha = 0.05):
    result = False
    if p_value_foward >= p_value_backward:
        if p_value_foward >= alpha:
            if p_value_backward < alpha:
                print("Identifiable: \n \
                      {} is cause and P-value is {}, \n \
                      {} is effect and P-value is {}.".format(v1,round(p_value_foward,2),v2,round(p_value_backward,2)))
                result = True
            else:
                print("Unidentifiable: \n \
                      ALL direction's P-value large than {}. \n \
                      The direction mabey that {} cause {}.".format(alpha, v1, v2))
        else:
            print("Unidentifiable: \n \
                  ALL direction's P-value small than {}. \n \
                  The direction mabey that {} cause {}.".format(alpha, v1, v2))
    else:
        if p_value_backward >= alpha:
            if p_value_foward < alpha:
                print("Identifiable: \n \
                      {} is cause and P-value is {}, \n \
                      {} is effect and P-value is {}.".format(v2,round(p_value_backward,2),v1,round(p_value_foward,2)))
                result = True
            else:
                print("Unidentifiable: \n \
                      ALL direction's P-value large than {}. \n \
                      The direction mabey that {} cause {}.".format(alpha,v2,v1))
        else:
            print("Unidentifiable: \n \
                  ALL direction's P-value small than {}. \n \
                  The direction mabey that {} cause {}.".format(alpha, v2,v1))
    return result
        
def P_Identify(dataFrame,searchV,aimV,searchVType,corMat,corTheta = 0.05,CITheta = 0.05,directTheta = 0.1,is_str = True,exclSet = []):
    """
    Parameters
    ----------
    dataFrame : dataFrame
        DESCRIPTION.
    searchV : list
        DESCRIPTION.
    aimV : TYPE
        DESCRIPTION.
    aimVType : TYPE
        DESCRIPTION.
    corMat : DataFrame
        DESCRIPTION.
    corTheta : TYPE, optional
        DESCRIPTION. The default is 0.2.
    CITheta : TYPE, optional
        DESCRIPTION. The default is 0.05.
    directTheta : TYPE, optional
        DESCRIPTION. The default is 0.05.
    is_str : TYPE, Bool
        DESCRIPTION. Whether strict judgement. 
        False means judging only according to the size of the P value in different directions; 
        True means judging the parent-child relationship strictly according to the threshold;

    Returns
    -------
    None.

    """
    aimVType = searchVType[aimV]

    if len(searchV) == len(corMat):
        print("Start Identify!")
        print("Aim Variable:",aimV)
    else:
        print("corMat is not consistency with searchV")
        return
    
    if corTheta == 'count':
        corA = [np.abs(corMat[aimV].iloc[i]) for i in range(len(corMat[aimV]))]
        nLen = len(corA)
        countNum = 12
        per_ = (1 - round(countNum / nLen, 2)) * 100
        
        corTheta = np.percentile(corA, per_)
        AdjIndex = (corMat[aimV] >= corTheta) | (corMat[aimV] <= -corTheta)
    else:
        AdjIndex = (corMat[aimV] >= corTheta) | (corMat[aimV] <= -corTheta)
    
    Adj = set([searchV[i] for i in range(len(searchV)) if AdjIndex.iloc[i]])
    Adj = Adj - set([aimV])
    Adj = Adj - set(exclSet)
    print('exclSet:',exclSet)
    print('Init Adj:',Adj)
    
    AdjDict = {}
    for x_a in Adj:
        AdjDict[x_a] = corMat.loc[x_a,aimV]
    
    sortedAdjDict = sorted(AdjDict.items(), key=lambda x: x[1])

    NoAdj = [] 
    for x_c in sortedAdjDict:
        
        x_ = x_c[0]
        print(x_)
        size = 1
        CAdj = Adj - set([x_])
        if len(CAdj) >= size:
            test = True
        else:
            test = False
            print("No much variable to CI test!")
        while test:
            for CAdj_ in combinations(CAdj,size):
                print(CAdj_)
                
                test_statistic,P_ = gcm_test(X = dataFrame[[aimV]].values.ravel(), 
                                             Y = dataFrame[[x_]].values.ravel(), 
                                             Z = dataFrame[list(CAdj_)], 
                                             X_type = aimVType, 
                                             Y_type = searchVType[x_],
                                             is_hypyopt = True)
                
                if P_ > CITheta:
                    print("P Value: ", P_)
                    NoAdj.append(x_)
                    Adj = CAdj
                    test = False
                    
                    break
            size = size + 1
            if size > 3:
                test = False
            if len(CAdj) < size:
                test = False
    print("Train Adj:",Adj)
    parSet = []
    chiSet = []
    for pc_ in Adj:
        ## new ANM
        P_foward_, P_back_ = anm_test(X = dataFrame[[aimV]].values.ravel(), 
                                      Y = dataFrame[[pc_]].values.ravel(), 
                                      X_type = aimVType, 
                                      Y_type = searchVType[pc_],
                                      is_hypyopt = True)
        
        causalDirect(P_foward_, P_back_,aimV, pc_)
        if is_str:
            if (P_foward_ > directTheta) & (P_back_ <= directTheta):
                print('find')
                print(P_foward_,P_back_)
                chiSet.append(pc_)
            elif (P_foward_ <= directTheta) & (P_back_ > directTheta):
                print('find')
                print(P_foward_,P_back_)
                parSet.append(pc_)
            elif P_foward_ <= P_back_:
                parSet.append(pc_)
            elif abs(P_foward_ - P_back_) <= 0.05:
                parSet.append(pc_)
            else:
                chiSet.append(pc_)
        else:
            if P_back_ >= directTheta:
                parSet.append(pc_)
            elif P_foward_ >= directTheta:
                chiSet.append(pc_)
            else:
                parSet.append(pc_)

    print("parSet:",parSet)
    print("chiSet:",chiSet)
                
    return parSet,chiSet,NoAdj,Adj


def A_Identify(dataFrame,searchV,aimV,searchVType,corMat,corTheta = 0.05,CITheta = 0.05,directTheta = 0.1,is_str = True):
    search = True
    toIdeSet = [aimV]
    Ancestors = {}
    exclSet = []
    while search:
        toIdeSet_ = []
        exclSet_ = []
        for IdeV in toIdeSet:
            # print(IdeV)
            P_IdeV,C_IdeV,NA_IdeV,A_IdeV = P_Identify(dataFrame,searchV,IdeV,searchVType,corMat,corTheta,CITheta,directTheta,is_str,exclSet)
            toIdeSet_.extend(P_IdeV)
            exclSet_.extend(C_IdeV)
            Ancestors[IdeV] = P_IdeV
        if len(toIdeSet_) == 0:
            search = False
        else:
            exclSet_.extend(toIdeSet)
            exclSet.extend(exclSet_)
            toIdeSet = toIdeSet_
            
    
    return Ancestors

dataFile = '../dataset/NhanesDataTrain.csv'

dataFrame = pd.read_csv(dataFile)
dataFrame = dataFrame.loc[dataFrame['RIDAGEYR'] >= 20,:]
NoUseV = ['SEQN', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDRETH3', 'RIDEXMON', 'DIQ050']

dataFrame = dataFrame.drop(columns = NoUseV)
dataFrame.columns

aimV = 'DIQ010'
useCol = list(dataFrame.columns)

# 'discrete' 'continuous'
useColType = {}
for col_ in useCol:
    useColType[col_] = 'continuous'

useColType[aimV] = 'discrete'

continuousV = [key for key, value in useColType.items() if value == 'continuous']

scaler = MinMaxScaler()
dataFrame.loc[:,continuousV] = scaler.fit_transform(dataFrame.loc[:,continuousV])

corMat = dataFrame.corr(method='spearman')
corPercDesc = corMat[aimV].describe(percentiles = [.1, .5, .75, .9, .95])

corTheta = corPercDesc.loc['90%']
corTheta = 'count'

Start_time = datetime.datetime.now(pytz.timezone('Asia/Shanghai'))
print("Start_time:", Start_time)
 

# Gene Data
Ancestors = A_Identify(dataFrame = dataFrame,searchV = useCol,aimV = aimV,
                       searchVType = useColType, corMat = corMat, 
                       corTheta = corTheta,CITheta = 0.2,directTheta = 0.2)

print('Ancestors:',Ancestors)


End_time = datetime.datetime.now(pytz.timezone('Asia/Shanghai'))
print("End_time:", End_time)

time_difference = End_time - Start_time
print("time_difference:", time_difference)
# Out:
# Start_time: 2024-05-21 12:13:17.261672+08:00
# Start Identify!
# Aim Variable: DIQ010
# exclSet: []
# Init Adj: {'LBDRFOSI', 'LBDNENO', 'URXUMS', 'BMXBMI', 'LBXMCHSI', 'LBDTCSI', 'URDACT', 'LBXWBCSI', 'LBXMC', 'BPXOSY1', 'LBXRDW'}
# URDACT
# ('LBDRFOSI',)
# ('LBDNENO',)
# ('URXUMS',)
# ('BMXBMI',)
# ('LBXMCHSI',)
# ('LBDTCSI',)
# ('LBXWBCSI',)
# ('LBXMC',)
# ('BPXOSY1',)
# ('LBXRDW',)
# ('LBDRFOSI', 'LBDNENO')
# ('LBDRFOSI', 'URXUMS')
# ('LBDRFOSI', 'BMXBMI')
# ('LBDRFOSI', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMC')
# ('LBDRFOSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXRDW')
# ('LBDNENO', 'URXUMS')
# P Value:  0.2435296908733542
# BMXBMI
# ('LBDRFOSI',)
# ('LBDNENO',)
# ('URXUMS',)
# ('LBXMCHSI',)
# ('LBDTCSI',)
# ('LBXWBCSI',)
# ('LBXMC',)
# ('BPXOSY1',)
# ('LBXRDW',)
# ('LBDRFOSI', 'LBDNENO')
# ('LBDRFOSI', 'URXUMS')
# ('LBDRFOSI', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMC')
# ('LBDRFOSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXRDW')
# ('LBDNENO', 'URXUMS')
# ('LBDNENO', 'LBXMCHSI')
# ('LBDNENO', 'LBDTCSI')
# ('LBDNENO', 'LBXWBCSI')
# ('LBDNENO', 'LBXMC')
# ('LBDNENO', 'BPXOSY1')
# ('LBDNENO', 'LBXRDW')
# ('URXUMS', 'LBXMCHSI')
# ('URXUMS', 'LBDTCSI')
# ('URXUMS', 'LBXWBCSI')
# ('URXUMS', 'LBXMC')
# ('URXUMS', 'BPXOSY1')
# ('URXUMS', 'LBXRDW')
# ('LBXMCHSI', 'LBDTCSI')
# ('LBXMCHSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBXRDW')
# ('LBDTCSI', 'LBXWBCSI')
# ('LBDTCSI', 'LBXMC')
# ('LBDTCSI', 'BPXOSY1')
# ('LBDTCSI', 'LBXRDW')
# ('LBXWBCSI', 'LBXMC')
# ('LBXWBCSI', 'BPXOSY1')
# ('LBXWBCSI', 'LBXRDW')
# ('LBXMC', 'BPXOSY1')
# ('LBXMC', 'LBXRDW')
# ('BPXOSY1', 'LBXRDW')
# ('LBDRFOSI', 'LBDNENO', 'URXUMS')
# ('LBDRFOSI', 'LBDNENO', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDNENO', 'LBDTCSI')
# ('LBDRFOSI', 'LBDNENO', 'LBXWBCSI')
# ('LBDRFOSI', 'LBDNENO', 'LBXMC')
# ('LBDRFOSI', 'LBDNENO', 'BPXOSY1')
# ('LBDRFOSI', 'LBDNENO', 'LBXRDW')
# ('LBDRFOSI', 'URXUMS', 'LBXMCHSI')
# ('LBDRFOSI', 'URXUMS', 'LBDTCSI')
# ('LBDRFOSI', 'URXUMS', 'LBXWBCSI')
# ('LBDRFOSI', 'URXUMS', 'LBXMC')
# ('LBDRFOSI', 'URXUMS', 'BPXOSY1')
# ('LBDRFOSI', 'URXUMS', 'LBXRDW')
# ('LBDRFOSI', 'LBXMCHSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXMC')
# ('LBDRFOSI', 'LBXMCHSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXRDW')
# ('LBDRFOSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBDTCSI', 'LBXMC')
# ('LBDRFOSI', 'LBDTCSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBDTCSI', 'LBXRDW')
# ('LBDRFOSI', 'LBXWBCSI', 'LBXMC')
# ('LBDRFOSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXWBCSI', 'LBXRDW')
# ('LBDRFOSI', 'LBXMC', 'BPXOSY1')
# ('LBDRFOSI', 'LBXMC', 'LBXRDW')
# ('LBDRFOSI', 'BPXOSY1', 'LBXRDW')
# ('LBDNENO', 'URXUMS', 'LBXMCHSI')
# ('LBDNENO', 'URXUMS', 'LBDTCSI')
# ('LBDNENO', 'URXUMS', 'LBXWBCSI')
# ('LBDNENO', 'URXUMS', 'LBXMC')
# ('LBDNENO', 'URXUMS', 'BPXOSY1')
# ('LBDNENO', 'URXUMS', 'LBXRDW')
# ('LBDNENO', 'LBXMCHSI', 'LBDTCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXMC')
# ('LBDNENO', 'LBXMCHSI', 'BPXOSY1')
# ('LBDNENO', 'LBXMCHSI', 'LBXRDW')
# ('LBDNENO', 'LBDTCSI', 'LBXWBCSI')
# ('LBDNENO', 'LBDTCSI', 'LBXMC')
# ('LBDNENO', 'LBDTCSI', 'BPXOSY1')
# ('LBDNENO', 'LBDTCSI', 'LBXRDW')
# ('LBDNENO', 'LBXWBCSI', 'LBXMC')
# ('LBDNENO', 'LBXWBCSI', 'BPXOSY1')
# ('LBDNENO', 'LBXWBCSI', 'LBXRDW')
# ('LBDNENO', 'LBXMC', 'BPXOSY1')
# ('LBDNENO', 'LBXMC', 'LBXRDW')
# ('LBDNENO', 'BPXOSY1', 'LBXRDW')
# ('URXUMS', 'LBXMCHSI', 'LBDTCSI')
# ('URXUMS', 'LBXMCHSI', 'LBXWBCSI')
# ('URXUMS', 'LBXMCHSI', 'LBXMC')
# ('URXUMS', 'LBXMCHSI', 'BPXOSY1')
# ('URXUMS', 'LBXMCHSI', 'LBXRDW')
# ('URXUMS', 'LBDTCSI', 'LBXWBCSI')
# ('URXUMS', 'LBDTCSI', 'LBXMC')
# ('URXUMS', 'LBDTCSI', 'BPXOSY1')
# ('URXUMS', 'LBDTCSI', 'LBXRDW')
# ('URXUMS', 'LBXWBCSI', 'LBXMC')
# ('URXUMS', 'LBXWBCSI', 'BPXOSY1')
# ('URXUMS', 'LBXWBCSI', 'LBXRDW')
# ('URXUMS', 'LBXMC', 'BPXOSY1')
# ('URXUMS', 'LBXMC', 'LBXRDW')
# ('URXUMS', 'BPXOSY1', 'LBXRDW')
# ('LBXMCHSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBDTCSI', 'LBXMC')
# ('LBXMCHSI', 'LBDTCSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBDTCSI', 'LBXRDW')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXMC')
# ('LBXMCHSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXRDW')
# ('LBXMCHSI', 'LBXMC', 'BPXOSY1')
# ('LBXMCHSI', 'LBXMC', 'LBXRDW')
# ('LBXMCHSI', 'BPXOSY1', 'LBXRDW')
# ('LBDTCSI', 'LBXWBCSI', 'LBXMC')
# ('LBDTCSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBDTCSI', 'LBXWBCSI', 'LBXRDW')
# ('LBDTCSI', 'LBXMC', 'BPXOSY1')
# ('LBDTCSI', 'LBXMC', 'LBXRDW')
# ('LBDTCSI', 'BPXOSY1', 'LBXRDW')
# ('LBXWBCSI', 'LBXMC', 'BPXOSY1')
# ('LBXWBCSI', 'LBXMC', 'LBXRDW')
# ('LBXWBCSI', 'BPXOSY1', 'LBXRDW')
# ('LBXMC', 'BPXOSY1', 'LBXRDW')
# URXUMS
# ('LBDRFOSI',)
# ('LBDNENO',)
# ('BMXBMI',)
# ('LBXMCHSI',)
# ('LBDTCSI',)
# ('LBXWBCSI',)
# ('LBXMC',)
# ('BPXOSY1',)
# ('LBXRDW',)
# ('LBDRFOSI', 'LBDNENO')
# ('LBDRFOSI', 'BMXBMI')
# ('LBDRFOSI', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMC')
# ('LBDRFOSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXRDW')
# ('LBDNENO', 'BMXBMI')
# ('LBDNENO', 'LBXMCHSI')
# ('LBDNENO', 'LBDTCSI')
# ('LBDNENO', 'LBXWBCSI')
# ('LBDNENO', 'LBXMC')
# ('LBDNENO', 'BPXOSY1')
# ('LBDNENO', 'LBXRDW')
# ('BMXBMI', 'LBXMCHSI')
# ('BMXBMI', 'LBDTCSI')
# ('BMXBMI', 'LBXWBCSI')
# ('BMXBMI', 'LBXMC')
# ('BMXBMI', 'BPXOSY1')
# ('BMXBMI', 'LBXRDW')
# ('LBXMCHSI', 'LBDTCSI')
# ('LBXMCHSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBXRDW')
# ('LBDTCSI', 'LBXWBCSI')
# ('LBDTCSI', 'LBXMC')
# ('LBDTCSI', 'BPXOSY1')
# ('LBDTCSI', 'LBXRDW')
# ('LBXWBCSI', 'LBXMC')
# ('LBXWBCSI', 'BPXOSY1')
# ('LBXWBCSI', 'LBXRDW')
# ('LBXMC', 'BPXOSY1')
# ('LBXMC', 'LBXRDW')
# ('BPXOSY1', 'LBXRDW')
# ('LBDRFOSI', 'LBDNENO', 'BMXBMI')
# ('LBDRFOSI', 'LBDNENO', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDNENO', 'LBDTCSI')
# ('LBDRFOSI', 'LBDNENO', 'LBXWBCSI')
# ('LBDRFOSI', 'LBDNENO', 'LBXMC')
# ('LBDRFOSI', 'LBDNENO', 'BPXOSY1')
# ('LBDRFOSI', 'LBDNENO', 'LBXRDW')
# ('LBDRFOSI', 'BMXBMI', 'LBXMCHSI')
# ('LBDRFOSI', 'BMXBMI', 'LBDTCSI')
# ('LBDRFOSI', 'BMXBMI', 'LBXWBCSI')
# ('LBDRFOSI', 'BMXBMI', 'LBXMC')
# ('LBDRFOSI', 'BMXBMI', 'BPXOSY1')
# ('LBDRFOSI', 'BMXBMI', 'LBXRDW')
# ('LBDRFOSI', 'LBXMCHSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXMC')
# ('LBDRFOSI', 'LBXMCHSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXRDW')
# ('LBDRFOSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBDTCSI', 'LBXMC')
# ('LBDRFOSI', 'LBDTCSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBDTCSI', 'LBXRDW')
# ('LBDRFOSI', 'LBXWBCSI', 'LBXMC')
# ('LBDRFOSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXWBCSI', 'LBXRDW')
# ('LBDRFOSI', 'LBXMC', 'BPXOSY1')
# ('LBDRFOSI', 'LBXMC', 'LBXRDW')
# ('LBDRFOSI', 'BPXOSY1', 'LBXRDW')
# ('LBDNENO', 'BMXBMI', 'LBXMCHSI')
# ('LBDNENO', 'BMXBMI', 'LBDTCSI')
# ('LBDNENO', 'BMXBMI', 'LBXWBCSI')
# ('LBDNENO', 'BMXBMI', 'LBXMC')
# ('LBDNENO', 'BMXBMI', 'BPXOSY1')
# ('LBDNENO', 'BMXBMI', 'LBXRDW')
# ('LBDNENO', 'LBXMCHSI', 'LBDTCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXMC')
# ('LBDNENO', 'LBXMCHSI', 'BPXOSY1')
# ('LBDNENO', 'LBXMCHSI', 'LBXRDW')
# ('LBDNENO', 'LBDTCSI', 'LBXWBCSI')
# ('LBDNENO', 'LBDTCSI', 'LBXMC')
# ('LBDNENO', 'LBDTCSI', 'BPXOSY1')
# ('LBDNENO', 'LBDTCSI', 'LBXRDW')
# ('LBDNENO', 'LBXWBCSI', 'LBXMC')
# ('LBDNENO', 'LBXWBCSI', 'BPXOSY1')
# ('LBDNENO', 'LBXWBCSI', 'LBXRDW')
# ('LBDNENO', 'LBXMC', 'BPXOSY1')
# ('LBDNENO', 'LBXMC', 'LBXRDW')
# ('LBDNENO', 'BPXOSY1', 'LBXRDW')
# ('BMXBMI', 'LBXMCHSI', 'LBDTCSI')
# ('BMXBMI', 'LBXMCHSI', 'LBXWBCSI')
# ('BMXBMI', 'LBXMCHSI', 'LBXMC')
# ('BMXBMI', 'LBXMCHSI', 'BPXOSY1')
# ('BMXBMI', 'LBXMCHSI', 'LBXRDW')
# ('BMXBMI', 'LBDTCSI', 'LBXWBCSI')
# ('BMXBMI', 'LBDTCSI', 'LBXMC')
# ('BMXBMI', 'LBDTCSI', 'BPXOSY1')
# ('BMXBMI', 'LBDTCSI', 'LBXRDW')
# ('BMXBMI', 'LBXWBCSI', 'LBXMC')
# ('BMXBMI', 'LBXWBCSI', 'BPXOSY1')
# ('BMXBMI', 'LBXWBCSI', 'LBXRDW')
# ('BMXBMI', 'LBXMC', 'BPXOSY1')
# ('BMXBMI', 'LBXMC', 'LBXRDW')
# ('BMXBMI', 'BPXOSY1', 'LBXRDW')
# ('LBXMCHSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBDTCSI', 'LBXMC')
# ('LBXMCHSI', 'LBDTCSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBDTCSI', 'LBXRDW')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXMC')
# ('LBXMCHSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXRDW')
# ('LBXMCHSI', 'LBXMC', 'BPXOSY1')
# ('LBXMCHSI', 'LBXMC', 'LBXRDW')
# ('LBXMCHSI', 'BPXOSY1', 'LBXRDW')
# ('LBDTCSI', 'LBXWBCSI', 'LBXMC')
# ('LBDTCSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBDTCSI', 'LBXWBCSI', 'LBXRDW')
# ('LBDTCSI', 'LBXMC', 'BPXOSY1')
# ('LBDTCSI', 'LBXMC', 'LBXRDW')
# ('LBDTCSI', 'BPXOSY1', 'LBXRDW')
# ('LBXWBCSI', 'LBXMC', 'BPXOSY1')
# ('LBXWBCSI', 'LBXMC', 'LBXRDW')
# ('LBXWBCSI', 'BPXOSY1', 'LBXRDW')
# ('LBXMC', 'BPXOSY1', 'LBXRDW')
# LBXRDW
# ('LBDRFOSI',)
# ('LBDNENO',)
# ('URXUMS',)
# ('BMXBMI',)
# ('LBXMCHSI',)
# ('LBDTCSI',)
# ('LBXWBCSI',)
# ('LBXMC',)
# ('BPXOSY1',)
# ('LBDRFOSI', 'LBDNENO')
# ('LBDRFOSI', 'URXUMS')
# ('LBDRFOSI', 'BMXBMI')
# ('LBDRFOSI', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMC')
# ('LBDRFOSI', 'BPXOSY1')
# ('LBDNENO', 'URXUMS')
# ('LBDNENO', 'BMXBMI')
# ('LBDNENO', 'LBXMCHSI')
# ('LBDNENO', 'LBDTCSI')
# ('LBDNENO', 'LBXWBCSI')
# ('LBDNENO', 'LBXMC')
# ('LBDNENO', 'BPXOSY1')
# ('URXUMS', 'BMXBMI')
# ('URXUMS', 'LBXMCHSI')
# ('URXUMS', 'LBDTCSI')
# ('URXUMS', 'LBXWBCSI')
# ('URXUMS', 'LBXMC')
# ('URXUMS', 'BPXOSY1')
# ('BMXBMI', 'LBXMCHSI')
# ('BMXBMI', 'LBDTCSI')
# ('BMXBMI', 'LBXWBCSI')
# ('BMXBMI', 'LBXMC')
# ('BMXBMI', 'BPXOSY1')
# ('LBXMCHSI', 'LBDTCSI')
# ('LBXMCHSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'BPXOSY1')
# ('LBDTCSI', 'LBXWBCSI')
# ('LBDTCSI', 'LBXMC')
# ('LBDTCSI', 'BPXOSY1')
# ('LBXWBCSI', 'LBXMC')
# ('LBXWBCSI', 'BPXOSY1')
# ('LBXMC', 'BPXOSY1')
# ('LBDRFOSI', 'LBDNENO', 'URXUMS')
# ('LBDRFOSI', 'LBDNENO', 'BMXBMI')
# ('LBDRFOSI', 'LBDNENO', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDNENO', 'LBDTCSI')
# ('LBDRFOSI', 'LBDNENO', 'LBXWBCSI')
# ('LBDRFOSI', 'LBDNENO', 'LBXMC')
# ('LBDRFOSI', 'LBDNENO', 'BPXOSY1')
# ('LBDRFOSI', 'URXUMS', 'BMXBMI')
# ('LBDRFOSI', 'URXUMS', 'LBXMCHSI')
# ('LBDRFOSI', 'URXUMS', 'LBDTCSI')
# ('LBDRFOSI', 'URXUMS', 'LBXWBCSI')
# ('LBDRFOSI', 'URXUMS', 'LBXMC')
# ('LBDRFOSI', 'URXUMS', 'BPXOSY1')
# ('LBDRFOSI', 'BMXBMI', 'LBXMCHSI')
# ('LBDRFOSI', 'BMXBMI', 'LBDTCSI')
# ('LBDRFOSI', 'BMXBMI', 'LBXWBCSI')
# ('LBDRFOSI', 'BMXBMI', 'LBXMC')
# ('LBDRFOSI', 'BMXBMI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXMCHSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXMC')
# ('LBDRFOSI', 'LBXMCHSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBDTCSI', 'LBXMC')
# ('LBDRFOSI', 'LBDTCSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXWBCSI', 'LBXMC')
# ('LBDRFOSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXMC', 'BPXOSY1')
# ('LBDNENO', 'URXUMS', 'BMXBMI')
# ('LBDNENO', 'URXUMS', 'LBXMCHSI')
# ('LBDNENO', 'URXUMS', 'LBDTCSI')
# ('LBDNENO', 'URXUMS', 'LBXWBCSI')
# ('LBDNENO', 'URXUMS', 'LBXMC')
# ('LBDNENO', 'URXUMS', 'BPXOSY1')
# ('LBDNENO', 'BMXBMI', 'LBXMCHSI')
# ('LBDNENO', 'BMXBMI', 'LBDTCSI')
# ('LBDNENO', 'BMXBMI', 'LBXWBCSI')
# ('LBDNENO', 'BMXBMI', 'LBXMC')
# ('LBDNENO', 'BMXBMI', 'BPXOSY1')
# ('LBDNENO', 'LBXMCHSI', 'LBDTCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXMC')
# ('LBDNENO', 'LBXMCHSI', 'BPXOSY1')
# ('LBDNENO', 'LBDTCSI', 'LBXWBCSI')
# ('LBDNENO', 'LBDTCSI', 'LBXMC')
# ('LBDNENO', 'LBDTCSI', 'BPXOSY1')
# ('LBDNENO', 'LBXWBCSI', 'LBXMC')
# ('LBDNENO', 'LBXWBCSI', 'BPXOSY1')
# ('LBDNENO', 'LBXMC', 'BPXOSY1')
# ('URXUMS', 'BMXBMI', 'LBXMCHSI')
# ('URXUMS', 'BMXBMI', 'LBDTCSI')
# ('URXUMS', 'BMXBMI', 'LBXWBCSI')
# ('URXUMS', 'BMXBMI', 'LBXMC')
# ('URXUMS', 'BMXBMI', 'BPXOSY1')
# ('URXUMS', 'LBXMCHSI', 'LBDTCSI')
# ('URXUMS', 'LBXMCHSI', 'LBXWBCSI')
# ('URXUMS', 'LBXMCHSI', 'LBXMC')
# ('URXUMS', 'LBXMCHSI', 'BPXOSY1')
# ('URXUMS', 'LBDTCSI', 'LBXWBCSI')
# ('URXUMS', 'LBDTCSI', 'LBXMC')
# ('URXUMS', 'LBDTCSI', 'BPXOSY1')
# ('URXUMS', 'LBXWBCSI', 'LBXMC')
# ('URXUMS', 'LBXWBCSI', 'BPXOSY1')
# ('URXUMS', 'LBXMC', 'BPXOSY1')
# ('BMXBMI', 'LBXMCHSI', 'LBDTCSI')
# ('BMXBMI', 'LBXMCHSI', 'LBXWBCSI')
# ('BMXBMI', 'LBXMCHSI', 'LBXMC')
# ('BMXBMI', 'LBXMCHSI', 'BPXOSY1')
# ('BMXBMI', 'LBDTCSI', 'LBXWBCSI')
# ('BMXBMI', 'LBDTCSI', 'LBXMC')
# ('BMXBMI', 'LBDTCSI', 'BPXOSY1')
# ('BMXBMI', 'LBXWBCSI', 'LBXMC')
# ('BMXBMI', 'LBXWBCSI', 'BPXOSY1')
# ('BMXBMI', 'LBXMC', 'BPXOSY1')
# ('LBXMCHSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBDTCSI', 'LBXMC')
# ('LBXMCHSI', 'LBDTCSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXMC')
# ('LBXMCHSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBXMC', 'BPXOSY1')
# ('LBDTCSI', 'LBXWBCSI', 'LBXMC')
# ('LBDTCSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBDTCSI', 'LBXMC', 'BPXOSY1')
# ('LBXWBCSI', 'LBXMC', 'BPXOSY1')
# BPXOSY1
# ('LBDRFOSI',)
# ('LBDNENO',)
# ('URXUMS',)
# ('BMXBMI',)
# ('LBXMCHSI',)
# ('LBDTCSI',)
# ('LBXWBCSI',)
# ('LBXMC',)
# ('LBXRDW',)
# ('LBDRFOSI', 'LBDNENO')
# ('LBDRFOSI', 'URXUMS')
# ('LBDRFOSI', 'BMXBMI')
# ('LBDRFOSI', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMC')
# ('LBDRFOSI', 'LBXRDW')
# ('LBDNENO', 'URXUMS')
# ('LBDNENO', 'BMXBMI')
# ('LBDNENO', 'LBXMCHSI')
# ('LBDNENO', 'LBDTCSI')
# ('LBDNENO', 'LBXWBCSI')
# ('LBDNENO', 'LBXMC')
# ('LBDNENO', 'LBXRDW')
# ('URXUMS', 'BMXBMI')
# ('URXUMS', 'LBXMCHSI')
# ('URXUMS', 'LBDTCSI')
# ('URXUMS', 'LBXWBCSI')
# ('URXUMS', 'LBXMC')
# ('URXUMS', 'LBXRDW')
# ('BMXBMI', 'LBXMCHSI')
# ('BMXBMI', 'LBDTCSI')
# ('BMXBMI', 'LBXWBCSI')
# ('BMXBMI', 'LBXMC')
# ('BMXBMI', 'LBXRDW')
# ('LBXMCHSI', 'LBDTCSI')
# ('LBXMCHSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'LBXRDW')
# ('LBDTCSI', 'LBXWBCSI')
# ('LBDTCSI', 'LBXMC')
# ('LBDTCSI', 'LBXRDW')
# ('LBXWBCSI', 'LBXMC')
# ('LBXWBCSI', 'LBXRDW')
# ('LBXMC', 'LBXRDW')
# ('LBDRFOSI', 'LBDNENO', 'URXUMS')
# ('LBDRFOSI', 'LBDNENO', 'BMXBMI')
# ('LBDRFOSI', 'LBDNENO', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDNENO', 'LBDTCSI')
# ('LBDRFOSI', 'LBDNENO', 'LBXWBCSI')
# ('LBDRFOSI', 'LBDNENO', 'LBXMC')
# ('LBDRFOSI', 'LBDNENO', 'LBXRDW')
# ('LBDRFOSI', 'URXUMS', 'BMXBMI')
# ('LBDRFOSI', 'URXUMS', 'LBXMCHSI')
# ('LBDRFOSI', 'URXUMS', 'LBDTCSI')
# ('LBDRFOSI', 'URXUMS', 'LBXWBCSI')
# ('LBDRFOSI', 'URXUMS', 'LBXMC')
# ('LBDRFOSI', 'URXUMS', 'LBXRDW')
# ('LBDRFOSI', 'BMXBMI', 'LBXMCHSI')
# ('LBDRFOSI', 'BMXBMI', 'LBDTCSI')
# ('LBDRFOSI', 'BMXBMI', 'LBXWBCSI')
# ('LBDRFOSI', 'BMXBMI', 'LBXMC')
# ('LBDRFOSI', 'BMXBMI', 'LBXRDW')
# ('LBDRFOSI', 'LBXMCHSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXMC')
# ('LBDRFOSI', 'LBXMCHSI', 'LBXRDW')
# ('LBDRFOSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBDRFOSI', 'LBDTCSI', 'LBXMC')
# ('LBDRFOSI', 'LBDTCSI', 'LBXRDW')
# ('LBDRFOSI', 'LBXWBCSI', 'LBXMC')
# ('LBDRFOSI', 'LBXWBCSI', 'LBXRDW')
# ('LBDRFOSI', 'LBXMC', 'LBXRDW')
# ('LBDNENO', 'URXUMS', 'BMXBMI')
# ('LBDNENO', 'URXUMS', 'LBXMCHSI')
# ('LBDNENO', 'URXUMS', 'LBDTCSI')
# ('LBDNENO', 'URXUMS', 'LBXWBCSI')
# ('LBDNENO', 'URXUMS', 'LBXMC')
# ('LBDNENO', 'URXUMS', 'LBXRDW')
# ('LBDNENO', 'BMXBMI', 'LBXMCHSI')
# ('LBDNENO', 'BMXBMI', 'LBDTCSI')
# ('LBDNENO', 'BMXBMI', 'LBXWBCSI')
# ('LBDNENO', 'BMXBMI', 'LBXMC')
# ('LBDNENO', 'BMXBMI', 'LBXRDW')
# ('LBDNENO', 'LBXMCHSI', 'LBDTCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXMC')
# ('LBDNENO', 'LBXMCHSI', 'LBXRDW')
# ('LBDNENO', 'LBDTCSI', 'LBXWBCSI')
# ('LBDNENO', 'LBDTCSI', 'LBXMC')
# ('LBDNENO', 'LBDTCSI', 'LBXRDW')
# ('LBDNENO', 'LBXWBCSI', 'LBXMC')
# ('LBDNENO', 'LBXWBCSI', 'LBXRDW')
# ('LBDNENO', 'LBXMC', 'LBXRDW')
# ('URXUMS', 'BMXBMI', 'LBXMCHSI')
# ('URXUMS', 'BMXBMI', 'LBDTCSI')
# ('URXUMS', 'BMXBMI', 'LBXWBCSI')
# ('URXUMS', 'BMXBMI', 'LBXMC')
# ('URXUMS', 'BMXBMI', 'LBXRDW')
# ('URXUMS', 'LBXMCHSI', 'LBDTCSI')
# ('URXUMS', 'LBXMCHSI', 'LBXWBCSI')
# ('URXUMS', 'LBXMCHSI', 'LBXMC')
# ('URXUMS', 'LBXMCHSI', 'LBXRDW')
# ('URXUMS', 'LBDTCSI', 'LBXWBCSI')
# ('URXUMS', 'LBDTCSI', 'LBXMC')
# ('URXUMS', 'LBDTCSI', 'LBXRDW')
# ('URXUMS', 'LBXWBCSI', 'LBXMC')
# ('URXUMS', 'LBXWBCSI', 'LBXRDW')
# ('URXUMS', 'LBXMC', 'LBXRDW')
# ('BMXBMI', 'LBXMCHSI', 'LBDTCSI')
# ('BMXBMI', 'LBXMCHSI', 'LBXWBCSI')
# ('BMXBMI', 'LBXMCHSI', 'LBXMC')
# ('BMXBMI', 'LBXMCHSI', 'LBXRDW')
# ('BMXBMI', 'LBDTCSI', 'LBXWBCSI')
# ('BMXBMI', 'LBDTCSI', 'LBXMC')
# ('BMXBMI', 'LBDTCSI', 'LBXRDW')
# ('BMXBMI', 'LBXWBCSI', 'LBXMC')
# ('BMXBMI', 'LBXWBCSI', 'LBXRDW')
# ('BMXBMI', 'LBXMC', 'LBXRDW')
# ('LBXMCHSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBDTCSI', 'LBXMC')
# ('LBXMCHSI', 'LBDTCSI', 'LBXRDW')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXMC')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXRDW')
# ('LBXMCHSI', 'LBXMC', 'LBXRDW')
# ('LBDTCSI', 'LBXWBCSI', 'LBXMC')
# ('LBDTCSI', 'LBXWBCSI', 'LBXRDW')
# ('LBDTCSI', 'LBXMC', 'LBXRDW')
# ('LBXWBCSI', 'LBXMC', 'LBXRDW')
# LBDRFOSI
# ('LBDNENO',)
# ('URXUMS',)
# ('BMXBMI',)
# ('LBXMCHSI',)
# ('LBDTCSI',)
# ('LBXWBCSI',)
# ('LBXMC',)
# ('BPXOSY1',)
# ('LBXRDW',)
# ('LBDNENO', 'URXUMS')
# ('LBDNENO', 'BMXBMI')
# ('LBDNENO', 'LBXMCHSI')
# ('LBDNENO', 'LBDTCSI')
# ('LBDNENO', 'LBXWBCSI')
# ('LBDNENO', 'LBXMC')
# ('LBDNENO', 'BPXOSY1')
# ('LBDNENO', 'LBXRDW')
# ('URXUMS', 'BMXBMI')
# ('URXUMS', 'LBXMCHSI')
# ('URXUMS', 'LBDTCSI')
# ('URXUMS', 'LBXWBCSI')
# ('URXUMS', 'LBXMC')
# ('URXUMS', 'BPXOSY1')
# ('URXUMS', 'LBXRDW')
# ('BMXBMI', 'LBXMCHSI')
# ('BMXBMI', 'LBDTCSI')
# ('BMXBMI', 'LBXWBCSI')
# ('BMXBMI', 'LBXMC')
# ('BMXBMI', 'BPXOSY1')
# ('BMXBMI', 'LBXRDW')
# ('LBXMCHSI', 'LBDTCSI')
# ('LBXMCHSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBXRDW')
# ('LBDTCSI', 'LBXWBCSI')
# ('LBDTCSI', 'LBXMC')
# ('LBDTCSI', 'BPXOSY1')
# ('LBDTCSI', 'LBXRDW')
# ('LBXWBCSI', 'LBXMC')
# ('LBXWBCSI', 'BPXOSY1')
# ('LBXWBCSI', 'LBXRDW')
# ('LBXMC', 'BPXOSY1')
# ('LBXMC', 'LBXRDW')
# ('BPXOSY1', 'LBXRDW')
# ('LBDNENO', 'URXUMS', 'BMXBMI')
# ('LBDNENO', 'URXUMS', 'LBXMCHSI')
# ('LBDNENO', 'URXUMS', 'LBDTCSI')
# ('LBDNENO', 'URXUMS', 'LBXWBCSI')
# ('LBDNENO', 'URXUMS', 'LBXMC')
# ('LBDNENO', 'URXUMS', 'BPXOSY1')
# ('LBDNENO', 'URXUMS', 'LBXRDW')
# ('LBDNENO', 'BMXBMI', 'LBXMCHSI')
# ('LBDNENO', 'BMXBMI', 'LBDTCSI')
# ('LBDNENO', 'BMXBMI', 'LBXWBCSI')
# ('LBDNENO', 'BMXBMI', 'LBXMC')
# ('LBDNENO', 'BMXBMI', 'BPXOSY1')
# ('LBDNENO', 'BMXBMI', 'LBXRDW')
# ('LBDNENO', 'LBXMCHSI', 'LBDTCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXWBCSI')
# ('LBDNENO', 'LBXMCHSI', 'LBXMC')
# ('LBDNENO', 'LBXMCHSI', 'BPXOSY1')
# ('LBDNENO', 'LBXMCHSI', 'LBXRDW')
# ('LBDNENO', 'LBDTCSI', 'LBXWBCSI')
# ('LBDNENO', 'LBDTCSI', 'LBXMC')
# ('LBDNENO', 'LBDTCSI', 'BPXOSY1')
# ('LBDNENO', 'LBDTCSI', 'LBXRDW')
# ('LBDNENO', 'LBXWBCSI', 'LBXMC')
# ('LBDNENO', 'LBXWBCSI', 'BPXOSY1')
# ('LBDNENO', 'LBXWBCSI', 'LBXRDW')
# ('LBDNENO', 'LBXMC', 'BPXOSY1')
# ('LBDNENO', 'LBXMC', 'LBXRDW')
# ('LBDNENO', 'BPXOSY1', 'LBXRDW')
# ('URXUMS', 'BMXBMI', 'LBXMCHSI')
# ('URXUMS', 'BMXBMI', 'LBDTCSI')
# ('URXUMS', 'BMXBMI', 'LBXWBCSI')
# ('URXUMS', 'BMXBMI', 'LBXMC')
# ('URXUMS', 'BMXBMI', 'BPXOSY1')
# ('URXUMS', 'BMXBMI', 'LBXRDW')
# ('URXUMS', 'LBXMCHSI', 'LBDTCSI')
# ('URXUMS', 'LBXMCHSI', 'LBXWBCSI')
# ('URXUMS', 'LBXMCHSI', 'LBXMC')
# ('URXUMS', 'LBXMCHSI', 'BPXOSY1')
# ('URXUMS', 'LBXMCHSI', 'LBXRDW')
# ('URXUMS', 'LBDTCSI', 'LBXWBCSI')
# ('URXUMS', 'LBDTCSI', 'LBXMC')
# ('URXUMS', 'LBDTCSI', 'BPXOSY1')
# ('URXUMS', 'LBDTCSI', 'LBXRDW')
# ('URXUMS', 'LBXWBCSI', 'LBXMC')
# ('URXUMS', 'LBXWBCSI', 'BPXOSY1')
# ('URXUMS', 'LBXWBCSI', 'LBXRDW')
# ('URXUMS', 'LBXMC', 'BPXOSY1')
# ('URXUMS', 'LBXMC', 'LBXRDW')
# ('URXUMS', 'BPXOSY1', 'LBXRDW')
# ('BMXBMI', 'LBXMCHSI', 'LBDTCSI')
# ('BMXBMI', 'LBXMCHSI', 'LBXWBCSI')
# ('BMXBMI', 'LBXMCHSI', 'LBXMC')
# ('BMXBMI', 'LBXMCHSI', 'BPXOSY1')
# ('BMXBMI', 'LBXMCHSI', 'LBXRDW')
# ('BMXBMI', 'LBDTCSI', 'LBXWBCSI')
# ('BMXBMI', 'LBDTCSI', 'LBXMC')
# ('BMXBMI', 'LBDTCSI', 'BPXOSY1')
# ('BMXBMI', 'LBDTCSI', 'LBXRDW')
# ('BMXBMI', 'LBXWBCSI', 'LBXMC')
# ('BMXBMI', 'LBXWBCSI', 'BPXOSY1')
# ('BMXBMI', 'LBXWBCSI', 'LBXRDW')
# ('BMXBMI', 'LBXMC', 'BPXOSY1')
# ('BMXBMI', 'LBXMC', 'LBXRDW')
# ('BMXBMI', 'BPXOSY1', 'LBXRDW')
# ('LBXMCHSI', 'LBDTCSI', 'LBXWBCSI')
# ('LBXMCHSI', 'LBDTCSI', 'LBXMC')
# ('LBXMCHSI', 'LBDTCSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBDTCSI', 'LBXRDW')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXMC')
# ('LBXMCHSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBXMCHSI', 'LBXWBCSI', 'LBXRDW')
# ('LBXMCHSI', 'LBXMC', 'BPXOSY1')
# ('LBXMCHSI', 'LBXMC', 'LBXRDW')
# ('LBXMCHSI', 'BPXOSY1', 'LBXRDW')
# ('LBDTCSI', 'LBXWBCSI', 'LBXMC')
# ('LBDTCSI', 'LBXWBCSI', 'BPXOSY1')
# ('LBDTCSI', 'LBXWBCSI', 'LBXRDW')
# ('LBDTCSI', 'LBXMC', 'BPXOSY1')
# ('LBDTCSI', 'LBXMC', 'LBXRDW')
# ('LBDTCSI', 'BPXOSY1', 'LBXRDW')
# ('LBXWBCSI', 'LBXMC', 'BPXOSY1')
# ('LBXWBCSI', 'LBXMC', 'LBXRDW')
# ('LBXWBCSI', 'BPXOSY1', 'LBXRDW')
# ('LBXMC', 'BPXOSY1', 'LBXRDW')
# LBDNENO
# ('LBDRFOSI',)
# ('URXUMS',)
# ('BMXBMI',)
# ('LBXMCHSI',)
# ('LBDTCSI',)
# ('LBXWBCSI',)
# P Value:  0.24960908036018925
# LBXWBCSI
# ('LBDRFOSI',)
# ('URXUMS',)
# ('BMXBMI',)
# ('LBXMCHSI',)
# ('LBDTCSI',)
# ('LBXMC',)
# ('BPXOSY1',)
# ('LBXRDW',)
# ('LBDRFOSI', 'URXUMS')
# ('LBDRFOSI', 'BMXBMI')
# ('LBDRFOSI', 'LBXMCHSI')
# ('LBDRFOSI', 'LBDTCSI')
# ('LBDRFOSI', 'LBXMC')
# ('LBDRFOSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXRDW')
# ('URXUMS', 'BMXBMI')
# ('URXUMS', 'LBXMCHSI')
# ('URXUMS', 'LBDTCSI')
# ('URXUMS', 'LBXMC')
# ('URXUMS', 'BPXOSY1')
# ('URXUMS', 'LBXRDW')
# ('BMXBMI', 'LBXMCHSI')
# P Value:  0.41278030102552654
# LBXMCHSI
# ('LBDRFOSI',)
# ('URXUMS',)
# ('BMXBMI',)
# ('LBDTCSI',)
# ('LBXMC',)
# P Value:  0.2032638556135875
# LBXMC
# ('LBDRFOSI',)
# ('URXUMS',)
# ('BMXBMI',)
# ('LBDTCSI',)
# ('BPXOSY1',)
# ('LBXRDW',)
# P Value:  0.3797164502265227
# LBDTCSI
# ('LBDRFOSI',)
# ('URXUMS',)
# ('BMXBMI',)
# ('BPXOSY1',)
# ('LBXRDW',)
# ('LBDRFOSI', 'URXUMS')
# ('LBDRFOSI', 'BMXBMI')
# ('LBDRFOSI', 'BPXOSY1')
# ('LBDRFOSI', 'LBXRDW')
# ('URXUMS', 'BMXBMI')
# ('URXUMS', 'BPXOSY1')
# ('URXUMS', 'LBXRDW')
# ('BMXBMI', 'BPXOSY1')
# ('BMXBMI', 'LBXRDW')
# ('BPXOSY1', 'LBXRDW')
# ('LBDRFOSI', 'URXUMS', 'BMXBMI')
# ('LBDRFOSI', 'URXUMS', 'BPXOSY1')
# ('LBDRFOSI', 'URXUMS', 'LBXRDW')
# ('LBDRFOSI', 'BMXBMI', 'BPXOSY1')
# ('LBDRFOSI', 'BMXBMI', 'LBXRDW')
# ('LBDRFOSI', 'BPXOSY1', 'LBXRDW')
# ('URXUMS', 'BMXBMI', 'BPXOSY1')
# ('URXUMS', 'BMXBMI', 'LBXRDW')
# ('URXUMS', 'BPXOSY1', 'LBXRDW')
# ('BMXBMI', 'BPXOSY1', 'LBXRDW')
# Train Adj: {'LBDRFOSI', 'URXUMS', 'BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW'}
# t_statistic_X: 0.06319246881636785
# corr_Y: 0.27532318120581417
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that DIQ010 cause LBDRFOSI.
# t_statistic_X: 0.6400629748742658
# corr_Y: 0.15117021582495366
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that URXUMS cause DIQ010.
# t_statistic_X: 0.017889192097147122
# corr_Y: 0.2171792635453011
# Identifiable:
#                        DIQ010 is cause and P-value is 0.32,
#                        BMXBMI is effect and P-value is 0.0.
# find
# 0.3205675779984867 2.966881845009163e-34
# t_statistic_X: 0.029359878989810878
# corr_Y: -0.15131734902352484
# Identifiable:
#                        DIQ010 is cause and P-value is 0.1,
#                        LBDTCSI is effect and P-value is 0.0.
# t_statistic_X: 0.018154559103385953
# corr_Y: 0.2009989346904353
# Identifiable:
#                        DIQ010 is cause and P-value is 0.31,
#                        BPXOSY1 is effect and P-value is 0.0.
# find
# 0.3134405229727105 1.748427325269837e-29
# t_statistic_X: -0.011792669597453054
# corr_Y: 0.23751955320482457
# Identifiable:
#                        DIQ010 is cause and P-value is 0.51,
#                        LBXRDW is effect and P-value is 0.0.
# find
# 0.5126255533065323 8.016201555747294e-41
# parSet: ['LBDRFOSI', 'URXUMS']
# chiSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW']
# Start Identify!
# Aim Variable: LBDRFOSI
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010']
# Init Adj: {'LBXLYPCT', 'LBDFOTSI', 'LBDLYMNO', 'LBXHCT', 'URDACT', 'LBXRBCSI', 'URXCRS', 'LBXNEPCT'}
# LBXLYPCT
# ('LBDFOTSI',)
# ('LBDLYMNO',)
# ('LBXHCT',)
# ('URDACT',)
# ('LBXRBCSI',)
# ('URXCRS',)
# ('LBXNEPCT',)
# ('LBDFOTSI', 'LBDLYMNO')
# ('LBDFOTSI', 'LBXHCT')
# ('LBDFOTSI', 'URDACT')
# ('LBDFOTSI', 'LBXRBCSI')
# ('LBDFOTSI', 'URXCRS')
# ('LBDFOTSI', 'LBXNEPCT')
# ('LBDLYMNO', 'LBXHCT')
# ('LBDLYMNO', 'URDACT')
# ('LBDLYMNO', 'LBXRBCSI')
# ('LBDLYMNO', 'URXCRS')
# ('LBDLYMNO', 'LBXNEPCT')
# ('LBXHCT', 'URDACT')
# ('LBXHCT', 'LBXRBCSI')
# ('LBXHCT', 'URXCRS')
# ('LBXHCT', 'LBXNEPCT')
# ('URDACT', 'LBXRBCSI')
# ('URDACT', 'URXCRS')
# ('URDACT', 'LBXNEPCT')
# ('LBXRBCSI', 'URXCRS')
# ('LBXRBCSI', 'LBXNEPCT')
# ('URXCRS', 'LBXNEPCT')
# ('LBDFOTSI', 'LBDLYMNO', 'LBXHCT')
# ('LBDFOTSI', 'LBDLYMNO', 'URDACT')
# ('LBDFOTSI', 'LBDLYMNO', 'LBXRBCSI')
# ('LBDFOTSI', 'LBDLYMNO', 'URXCRS')
# ('LBDFOTSI', 'LBDLYMNO', 'LBXNEPCT')
# ('LBDFOTSI', 'LBXHCT', 'URDACT')
# ('LBDFOTSI', 'LBXHCT', 'LBXRBCSI')
# ('LBDFOTSI', 'LBXHCT', 'URXCRS')
# ('LBDFOTSI', 'LBXHCT', 'LBXNEPCT')
# ('LBDFOTSI', 'URDACT', 'LBXRBCSI')
# ('LBDFOTSI', 'URDACT', 'URXCRS')
# ('LBDFOTSI', 'URDACT', 'LBXNEPCT')
# ('LBDFOTSI', 'LBXRBCSI', 'URXCRS')
# ('LBDFOTSI', 'LBXRBCSI', 'LBXNEPCT')
# ('LBDFOTSI', 'URXCRS', 'LBXNEPCT')
# ('LBDLYMNO', 'LBXHCT', 'URDACT')
# ('LBDLYMNO', 'LBXHCT', 'LBXRBCSI')
# ('LBDLYMNO', 'LBXHCT', 'URXCRS')
# ('LBDLYMNO', 'LBXHCT', 'LBXNEPCT')
# ('LBDLYMNO', 'URDACT', 'LBXRBCSI')
# ('LBDLYMNO', 'URDACT', 'URXCRS')
# ('LBDLYMNO', 'URDACT', 'LBXNEPCT')
# ('LBDLYMNO', 'LBXRBCSI', 'URXCRS')
# ('LBDLYMNO', 'LBXRBCSI', 'LBXNEPCT')
# ('LBDLYMNO', 'URXCRS', 'LBXNEPCT')
# ('LBXHCT', 'URDACT', 'LBXRBCSI')
# ('LBXHCT', 'URDACT', 'URXCRS')
# ('LBXHCT', 'URDACT', 'LBXNEPCT')
# ('LBXHCT', 'LBXRBCSI', 'URXCRS')
# ('LBXHCT', 'LBXRBCSI', 'LBXNEPCT')
# ('LBXHCT', 'URXCRS', 'LBXNEPCT')
# ('URDACT', 'LBXRBCSI', 'URXCRS')
# ('URDACT', 'LBXRBCSI', 'LBXNEPCT')
# ('URDACT', 'URXCRS', 'LBXNEPCT')
# ('LBXRBCSI', 'URXCRS', 'LBXNEPCT')
# URXCRS
# ('LBXLYPCT',)
# ('LBDFOTSI',)
# ('LBDLYMNO',)
# ('LBXHCT',)
# ('URDACT',)
# ('LBXRBCSI',)
# ('LBXNEPCT',)
# ('LBXLYPCT', 'LBDFOTSI')
# ('LBXLYPCT', 'LBDLYMNO')
# ('LBXLYPCT', 'LBXHCT')
# ('LBXLYPCT', 'URDACT')
# ('LBXLYPCT', 'LBXRBCSI')
# ('LBXLYPCT', 'LBXNEPCT')
# ('LBDFOTSI', 'LBDLYMNO')
# ('LBDFOTSI', 'LBXHCT')
# ('LBDFOTSI', 'URDACT')
# P Value:  0.4290158798489887
# LBXRBCSI
# ('LBXLYPCT',)
# ('LBDFOTSI',)
# ('LBDLYMNO',)
# ('LBXHCT',)
# ('URDACT',)
# ('LBXNEPCT',)
# ('LBXLYPCT', 'LBDFOTSI')
# ('LBXLYPCT', 'LBDLYMNO')
# ('LBXLYPCT', 'LBXHCT')
# ('LBXLYPCT', 'URDACT')
# ('LBXLYPCT', 'LBXNEPCT')
# ('LBDFOTSI', 'LBDLYMNO')
# ('LBDFOTSI', 'LBXHCT')
# P Value:  0.8416755267053475
# LBXHCT
# ('LBXLYPCT',)
# ('LBDFOTSI',)
# ('LBDLYMNO',)
# ('URDACT',)
# ('LBXNEPCT',)
# ('LBXLYPCT', 'LBDFOTSI')
# ('LBXLYPCT', 'LBDLYMNO')
# ('LBXLYPCT', 'URDACT')
# ('LBXLYPCT', 'LBXNEPCT')
# ('LBDFOTSI', 'LBDLYMNO')
# ('LBDFOTSI', 'URDACT')
# ('LBDFOTSI', 'LBXNEPCT')
# ('LBDLYMNO', 'URDACT')
# ('LBDLYMNO', 'LBXNEPCT')
# ('URDACT', 'LBXNEPCT')
# ('LBXLYPCT', 'LBDFOTSI', 'LBDLYMNO')
# ('LBXLYPCT', 'LBDFOTSI', 'URDACT')
# ('LBXLYPCT', 'LBDFOTSI', 'LBXNEPCT')
# ('LBXLYPCT', 'LBDLYMNO', 'URDACT')
# ('LBXLYPCT', 'LBDLYMNO', 'LBXNEPCT')
# ('LBXLYPCT', 'URDACT', 'LBXNEPCT')
# ('LBDFOTSI', 'LBDLYMNO', 'URDACT')
# ('LBDFOTSI', 'LBDLYMNO', 'LBXNEPCT')
# ('LBDFOTSI', 'URDACT', 'LBXNEPCT')
# ('LBDLYMNO', 'URDACT', 'LBXNEPCT')
# LBDLYMNO
# ('LBXLYPCT',)
# P Value:  0.5516723196040123
# LBXNEPCT
# ('URDACT',)
# ('LBDFOTSI',)
# ('LBXLYPCT',)
# ('LBXHCT',)
# ('URDACT', 'LBDFOTSI')
# ('URDACT', 'LBXLYPCT')
# ('URDACT', 'LBXHCT')
# ('LBDFOTSI', 'LBXLYPCT')
# ('LBDFOTSI', 'LBXHCT')
# ('LBXLYPCT', 'LBXHCT')
# ('URDACT', 'LBDFOTSI', 'LBXLYPCT')
# ('URDACT', 'LBDFOTSI', 'LBXHCT')
# ('URDACT', 'LBXLYPCT', 'LBXHCT')
# ('LBDFOTSI', 'LBXLYPCT', 'LBXHCT')
# URDACT
# ('LBDFOTSI',)
# ('LBXLYPCT',)
# ('LBXHCT',)
# ('LBXNEPCT',)
# ('LBDFOTSI', 'LBXLYPCT')
# ('LBDFOTSI', 'LBXHCT')
# ('LBDFOTSI', 'LBXNEPCT')
# ('LBXLYPCT', 'LBXHCT')
# P Value:  0.447051551140639
# LBDFOTSI
# ('LBXLYPCT',)
# ('LBXHCT',)
# ('LBXNEPCT',)
# ('LBXLYPCT', 'LBXHCT')
# ('LBXLYPCT', 'LBXNEPCT')
# ('LBXHCT', 'LBXNEPCT')
# ('LBXLYPCT', 'LBXHCT', 'LBXNEPCT')
# Train Adj: {'LBDFOTSI', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT'}
# corr_X: -0.05366073859653964
# corr_Y: -0.04952530824005431
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LBDFOTSI cause LBDRFOSI.
# corr_X: 0.0027674033352180507
# corr_Y: 0.03582561760568282
# Identifiable:
#                        LBDRFOSI is cause and P-value is 0.88,
#                        LBXLYPCT is effect and P-value is 0.05.
# find
# 0.8778878664685523 0.04662547664826726
# corr_X: 0.0030481032193297912
# corr_Y: 0.04846489433207324
# Identifiable:
#                        LBDRFOSI is cause and P-value is 0.87,
#                        LBXHCT is effect and P-value is 0.01.
# find
# 0.8656142410666066 0.007094704234999135
# corr_X: -0.002344125451247266
# corr_Y: -0.025138430056815396
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBDRFOSI cause LBXNEPCT.
# find
# 0.896450402930081 0.16274071732512171
# parSet: ['LBDFOTSI']
# chiSet: ['LBXLYPCT', 'LBXHCT', 'LBXNEPCT']
# Start Identify!
# Aim Variable: URXUMS
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010']
# Init Adj: {'LBDNENO', 'LBXLYPCT', 'URDACT', 'LBXMC', 'URXCRS', 'URDFLOW1', 'LBXNEPCT'}
# URDFLOW1
# ('LBDNENO',)
# P Value:  0.3481180408017328
# LBXLYPCT
# ('LBDNENO',)
# ('URDACT',)
# ('LBXMC',)
# ('URXCRS',)
# ('LBXNEPCT',)
# ('LBDNENO', 'URDACT')
# ('LBDNENO', 'LBXMC')
# ('LBDNENO', 'URXCRS')
# ('LBDNENO', 'LBXNEPCT')
# ('URDACT', 'LBXMC')
# ('URDACT', 'URXCRS')
# ('URDACT', 'LBXNEPCT')
# P Value:  0.4086482910449951
# LBXMC
# ('URXCRS',)
# ('LBDNENO',)
# ('URDACT',)
# P Value:  0.5072405029391667
# LBDNENO
# ('URDACT',)
# P Value:  0.5695877303334596
# LBXNEPCT
# ('URXCRS',)
# ('URDACT',)
# P Value:  0.24257307475131196
# URXCRS
# ('URDACT',)
# URDACT
# ('URXCRS',)
# Train Adj: {'URXCRS', 'URDACT'}
# corr_X: -0.07182590898711157
# corr_Y: -0.07730134016006916
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that URXUMS cause URXCRS.
# corr_X: -0.21973043079686616
# corr_Y: -0.11097922516391243
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that URDACT cause URXUMS.
# parSet: ['URXCRS', 'URDACT']
# chiSet: []
# Start Identify!
# Aim Variable: LBDFOTSI
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS']
# Init Adj: {'BPXODI1', 'LBXMCVSI', 'LBDLYMNO', 'LBXMCHSI', 'LBXMC', 'LBXRBCSI', 'URXCRS'}
# URXCRS
# ('BPXODI1',)
# ('LBXMCVSI',)
# ('LBDLYMNO',)
# ('LBXMCHSI',)
# ('LBXMC',)
# ('LBXRBCSI',)
# ('BPXODI1', 'LBXMCVSI')
# ('BPXODI1', 'LBDLYMNO')
# ('BPXODI1', 'LBXMCHSI')
# ('BPXODI1', 'LBXMC')
# ('BPXODI1', 'LBXRBCSI')
# ('LBXMCVSI', 'LBDLYMNO')
# ('LBXMCVSI', 'LBXMCHSI')
# ('LBXMCVSI', 'LBXMC')
# ('LBXMCVSI', 'LBXRBCSI')
# ('LBDLYMNO', 'LBXMCHSI')
# ('LBDLYMNO', 'LBXMC')
# ('LBDLYMNO', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'LBXRBCSI')
# ('LBXMC', 'LBXRBCSI')
# ('BPXODI1', 'LBXMCVSI', 'LBDLYMNO')
# ('BPXODI1', 'LBXMCVSI', 'LBXMCHSI')
# ('BPXODI1', 'LBXMCVSI', 'LBXMC')
# ('BPXODI1', 'LBXMCVSI', 'LBXRBCSI')
# ('BPXODI1', 'LBDLYMNO', 'LBXMCHSI')
# ('BPXODI1', 'LBDLYMNO', 'LBXMC')
# ('BPXODI1', 'LBDLYMNO', 'LBXRBCSI')
# ('BPXODI1', 'LBXMCHSI', 'LBXMC')
# ('BPXODI1', 'LBXMCHSI', 'LBXRBCSI')
# ('BPXODI1', 'LBXMC', 'LBXRBCSI')
# ('LBXMCVSI', 'LBDLYMNO', 'LBXMCHSI')
# ('LBXMCVSI', 'LBDLYMNO', 'LBXMC')
# ('LBXMCVSI', 'LBDLYMNO', 'LBXRBCSI')
# ('LBXMCVSI', 'LBXMCHSI', 'LBXMC')
# ('LBXMCVSI', 'LBXMCHSI', 'LBXRBCSI')
# ('LBXMCVSI', 'LBXMC', 'LBXRBCSI')
# ('LBDLYMNO', 'LBXMCHSI', 'LBXMC')
# ('LBDLYMNO', 'LBXMCHSI', 'LBXRBCSI')
# ('LBDLYMNO', 'LBXMC', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXMC', 'LBXRBCSI')
# LBXRBCSI
# ('BPXODI1',)
# ('LBXMCVSI',)
# ('LBDLYMNO',)
# ('LBXMCHSI',)
# ('LBXMC',)
# ('URXCRS',)
# ('BPXODI1', 'LBXMCVSI')
# ('BPXODI1', 'LBDLYMNO')
# ('BPXODI1', 'LBXMCHSI')
# ('BPXODI1', 'LBXMC')
# ('BPXODI1', 'URXCRS')
# ('LBXMCVSI', 'LBDLYMNO')
# ('LBXMCVSI', 'LBXMCHSI')
# ('LBXMCVSI', 'LBXMC')
# ('LBXMCVSI', 'URXCRS')
# ('LBDLYMNO', 'LBXMCHSI')
# ('LBDLYMNO', 'LBXMC')
# ('LBDLYMNO', 'URXCRS')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'URXCRS')
# ('LBXMC', 'URXCRS')
# ('BPXODI1', 'LBXMCVSI', 'LBDLYMNO')
# ('BPXODI1', 'LBXMCVSI', 'LBXMCHSI')
# ('BPXODI1', 'LBXMCVSI', 'LBXMC')
# ('BPXODI1', 'LBXMCVSI', 'URXCRS')
# ('BPXODI1', 'LBDLYMNO', 'LBXMCHSI')
# ('BPXODI1', 'LBDLYMNO', 'LBXMC')
# ('BPXODI1', 'LBDLYMNO', 'URXCRS')
# ('BPXODI1', 'LBXMCHSI', 'LBXMC')
# ('BPXODI1', 'LBXMCHSI', 'URXCRS')
# ('BPXODI1', 'LBXMC', 'URXCRS')
# ('LBXMCVSI', 'LBDLYMNO', 'LBXMCHSI')
# ('LBXMCVSI', 'LBDLYMNO', 'LBXMC')
# ('LBXMCVSI', 'LBDLYMNO', 'URXCRS')
# ('LBXMCVSI', 'LBXMCHSI', 'LBXMC')
# ('LBXMCVSI', 'LBXMCHSI', 'URXCRS')
# ('LBXMCVSI', 'LBXMC', 'URXCRS')
# ('LBDLYMNO', 'LBXMCHSI', 'LBXMC')
# ('LBDLYMNO', 'LBXMCHSI', 'URXCRS')
# ('LBDLYMNO', 'LBXMC', 'URXCRS')
# ('LBXMCHSI', 'LBXMC', 'URXCRS')
# BPXODI1
# ('LBXMCVSI',)
# ('LBDLYMNO',)
# ('LBXMCHSI',)
# ('LBXMC',)
# ('LBXRBCSI',)
# ('URXCRS',)
# ('LBXMCVSI', 'LBDLYMNO')
# ('LBXMCVSI', 'LBXMCHSI')
# ('LBXMCVSI', 'LBXMC')
# ('LBXMCVSI', 'LBXRBCSI')
# ('LBXMCVSI', 'URXCRS')
# ('LBDLYMNO', 'LBXMCHSI')
# ('LBDLYMNO', 'LBXMC')
# ('LBDLYMNO', 'LBXRBCSI')
# ('LBDLYMNO', 'URXCRS')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'LBXRBCSI')
# ('LBXMCHSI', 'URXCRS')
# ('LBXMC', 'LBXRBCSI')
# ('LBXMC', 'URXCRS')
# ('LBXRBCSI', 'URXCRS')
# ('LBXMCVSI', 'LBDLYMNO', 'LBXMCHSI')
# ('LBXMCVSI', 'LBDLYMNO', 'LBXMC')
# ('LBXMCVSI', 'LBDLYMNO', 'LBXRBCSI')
# ('LBXMCVSI', 'LBDLYMNO', 'URXCRS')
# ('LBXMCVSI', 'LBXMCHSI', 'LBXMC')
# ('LBXMCVSI', 'LBXMCHSI', 'LBXRBCSI')
# ('LBXMCVSI', 'LBXMCHSI', 'URXCRS')
# ('LBXMCVSI', 'LBXMC', 'LBXRBCSI')
# ('LBXMCVSI', 'LBXMC', 'URXCRS')
# ('LBXMCVSI', 'LBXRBCSI', 'URXCRS')
# ('LBDLYMNO', 'LBXMCHSI', 'LBXMC')
# ('LBDLYMNO', 'LBXMCHSI', 'LBXRBCSI')
# ('LBDLYMNO', 'LBXMCHSI', 'URXCRS')
# ('LBDLYMNO', 'LBXMC', 'LBXRBCSI')
# ('LBDLYMNO', 'LBXMC', 'URXCRS')
# ('LBDLYMNO', 'LBXRBCSI', 'URXCRS')
# ('LBXMCHSI', 'LBXMC', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXMC', 'URXCRS')
# ('LBXMCHSI', 'LBXRBCSI', 'URXCRS')
# ('LBXMC', 'LBXRBCSI', 'URXCRS')
# LBDLYMNO
# ('BPXODI1',)
# ('LBXMCVSI',)
# P Value:  0.2286726914446725
# LBXMCVSI
# ('BPXODI1',)
# ('LBXMCHSI',)
# P Value:  0.46036078607374686
# LBXMC
# ('BPXODI1',)
# ('URXCRS',)
# P Value:  0.2611659383568117
# LBXMCHSI
# ('BPXODI1',)
# ('URXCRS',)
# ('LBXRBCSI',)
# ('BPXODI1', 'URXCRS')
# ('BPXODI1', 'LBXRBCSI')
# ('URXCRS', 'LBXRBCSI')
# P Value:  0.33992846230898754
# Train Adj: {'BPXODI1', 'URXCRS', 'LBXRBCSI'}
# corr_X: 0.003925637349878464
# corr_Y: 0.04799108649430128
# Identifiable:
#                        LBDFOTSI is cause and P-value is 0.83,
#                        BPXODI1 is effect and P-value is 0.01.
# find
# 0.8274655186735091 0.0076756482664843174
# corr_X: 0.023643230239798082
# corr_Y: 0.07005373451899836
# Identifiable:
#                        LBDFOTSI is cause and P-value is 0.19,
#                        URXCRS is effect and P-value is 0.0.
# corr_X: -0.010906484190320991
# corr_Y: 0.07446673842777672
# Identifiable:
#                        LBDFOTSI is cause and P-value is 0.54,
#                        LBXRBCSI is effect and P-value is 0.0.
# find
# 0.5448143287735765 3.47060233413657e-05
# parSet: []
# chiSet: ['BPXODI1', 'URXCRS', 'LBXRBCSI']
# Start Identify!
# Aim Variable: URXCRS
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS']
# Init Adj: {'LBXBMN', 'LBDFOTSI', 'LBXMCHSI', 'LBXMC', 'LBXRBCSI', 'LBXHGB', 'URDFLOW1'}
# URDFLOW1
# ('LBXBMN',)
# ('LBDFOTSI',)
# ('LBXMCHSI',)
# ('LBXMC',)
# ('LBXRBCSI',)
# ('LBXHGB',)
# ('LBXBMN', 'LBDFOTSI')
# ('LBXBMN', 'LBXMCHSI')
# ('LBXBMN', 'LBXMC')
# ('LBXBMN', 'LBXRBCSI')
# ('LBXBMN', 'LBXHGB')
# ('LBDFOTSI', 'LBXMCHSI')
# ('LBDFOTSI', 'LBXMC')
# ('LBDFOTSI', 'LBXRBCSI')
# ('LBDFOTSI', 'LBXHGB')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXHGB')
# ('LBXMC', 'LBXRBCSI')
# ('LBXMC', 'LBXHGB')
# ('LBXRBCSI', 'LBXHGB')
# ('LBXBMN', 'LBDFOTSI', 'LBXMCHSI')
# ('LBXBMN', 'LBDFOTSI', 'LBXMC')
# ('LBXBMN', 'LBDFOTSI', 'LBXRBCSI')
# ('LBXBMN', 'LBDFOTSI', 'LBXHGB')
# ('LBXBMN', 'LBXMCHSI', 'LBXMC')
# ('LBXBMN', 'LBXMCHSI', 'LBXRBCSI')
# ('LBXBMN', 'LBXMCHSI', 'LBXHGB')
# ('LBXBMN', 'LBXMC', 'LBXRBCSI')
# ('LBXBMN', 'LBXMC', 'LBXHGB')
# ('LBXBMN', 'LBXRBCSI', 'LBXHGB')
# ('LBDFOTSI', 'LBXMCHSI', 'LBXMC')
# ('LBDFOTSI', 'LBXMCHSI', 'LBXRBCSI')
# ('LBDFOTSI', 'LBXMCHSI', 'LBXHGB')
# ('LBDFOTSI', 'LBXMC', 'LBXRBCSI')
# ('LBDFOTSI', 'LBXMC', 'LBXHGB')
# ('LBDFOTSI', 'LBXRBCSI', 'LBXHGB')
# ('LBXMCHSI', 'LBXMC', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXMC', 'LBXHGB')
# ('LBXMCHSI', 'LBXRBCSI', 'LBXHGB')
# ('LBXMC', 'LBXRBCSI', 'LBXHGB')
# LBDFOTSI
# ('LBXBMN',)
# ('LBXMCHSI',)
# ('LBXMC',)
# ('LBXRBCSI',)
# ('LBXHGB',)
# ('URDFLOW1',)
# ('LBXBMN', 'LBXMCHSI')
# ('LBXBMN', 'LBXMC')
# ('LBXBMN', 'LBXRBCSI')
# ('LBXBMN', 'LBXHGB')
# ('LBXBMN', 'URDFLOW1')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXHGB')
# ('LBXMCHSI', 'URDFLOW1')
# ('LBXMC', 'LBXRBCSI')
# ('LBXMC', 'LBXHGB')
# ('LBXMC', 'URDFLOW1')
# ('LBXRBCSI', 'LBXHGB')
# ('LBXRBCSI', 'URDFLOW1')
# ('LBXHGB', 'URDFLOW1')
# ('LBXBMN', 'LBXMCHSI', 'LBXMC')
# ('LBXBMN', 'LBXMCHSI', 'LBXRBCSI')
# ('LBXBMN', 'LBXMCHSI', 'LBXHGB')
# ('LBXBMN', 'LBXMCHSI', 'URDFLOW1')
# ('LBXBMN', 'LBXMC', 'LBXRBCSI')
# ('LBXBMN', 'LBXMC', 'LBXHGB')
# ('LBXBMN', 'LBXMC', 'URDFLOW1')
# ('LBXBMN', 'LBXRBCSI', 'LBXHGB')
# ('LBXBMN', 'LBXRBCSI', 'URDFLOW1')
# ('LBXBMN', 'LBXHGB', 'URDFLOW1')
# ('LBXMCHSI', 'LBXMC', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXMC', 'LBXHGB')
# ('LBXMCHSI', 'LBXMC', 'URDFLOW1')
# ('LBXMCHSI', 'LBXRBCSI', 'LBXHGB')
# ('LBXMCHSI', 'LBXRBCSI', 'URDFLOW1')
# ('LBXMCHSI', 'LBXHGB', 'URDFLOW1')
# ('LBXMC', 'LBXRBCSI', 'LBXHGB')
# ('LBXMC', 'LBXRBCSI', 'URDFLOW1')
# ('LBXMC', 'LBXHGB', 'URDFLOW1')
# ('LBXRBCSI', 'LBXHGB', 'URDFLOW1')
# LBXBMN
# ('LBDFOTSI',)
# ('LBXMCHSI',)
# ('LBXMC',)
# ('LBXRBCSI',)
# ('LBXHGB',)
# ('URDFLOW1',)
# ('LBDFOTSI', 'LBXMCHSI')
# ('LBDFOTSI', 'LBXMC')
# ('LBDFOTSI', 'LBXRBCSI')
# ('LBDFOTSI', 'LBXHGB')
# ('LBDFOTSI', 'URDFLOW1')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCHSI', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXHGB')
# ('LBXMCHSI', 'URDFLOW1')
# ('LBXMC', 'LBXRBCSI')
# ('LBXMC', 'LBXHGB')
# ('LBXMC', 'URDFLOW1')
# ('LBXRBCSI', 'LBXHGB')
# ('LBXRBCSI', 'URDFLOW1')
# ('LBXHGB', 'URDFLOW1')
# ('LBDFOTSI', 'LBXMCHSI', 'LBXMC')
# ('LBDFOTSI', 'LBXMCHSI', 'LBXRBCSI')
# ('LBDFOTSI', 'LBXMCHSI', 'LBXHGB')
# ('LBDFOTSI', 'LBXMCHSI', 'URDFLOW1')
# ('LBDFOTSI', 'LBXMC', 'LBXRBCSI')
# ('LBDFOTSI', 'LBXMC', 'LBXHGB')
# ('LBDFOTSI', 'LBXMC', 'URDFLOW1')
# ('LBDFOTSI', 'LBXRBCSI', 'LBXHGB')
# ('LBDFOTSI', 'LBXRBCSI', 'URDFLOW1')
# ('LBDFOTSI', 'LBXHGB', 'URDFLOW1')
# ('LBXMCHSI', 'LBXMC', 'LBXRBCSI')
# ('LBXMCHSI', 'LBXMC', 'LBXHGB')
# ('LBXMCHSI', 'LBXMC', 'URDFLOW1')
# ('LBXMCHSI', 'LBXRBCSI', 'LBXHGB')
# ('LBXMCHSI', 'LBXRBCSI', 'URDFLOW1')
# ('LBXMCHSI', 'LBXHGB', 'URDFLOW1')
# ('LBXMC', 'LBXRBCSI', 'LBXHGB')
# ('LBXMC', 'LBXRBCSI', 'URDFLOW1')
# ('LBXMC', 'LBXHGB', 'URDFLOW1')
# ('LBXRBCSI', 'LBXHGB', 'URDFLOW1')
# LBXMC
# ('LBXBMN',)
# ('LBDFOTSI',)
# ('LBXMCHSI',)
# ('LBXRBCSI',)
# ('LBXHGB',)
# ('URDFLOW1',)
# ('LBXBMN', 'LBDFOTSI')
# ('LBXBMN', 'LBXMCHSI')
# ('LBXBMN', 'LBXRBCSI')
# ('LBXBMN', 'LBXHGB')
# ('LBXBMN', 'URDFLOW1')
# ('LBDFOTSI', 'LBXMCHSI')
# ('LBDFOTSI', 'LBXRBCSI')
# ('LBDFOTSI', 'LBXHGB')
# ('LBDFOTSI', 'URDFLOW1')
# P Value:  0.4190320440795188
# LBXMCHSI
# ('LBXBMN',)
# ('LBDFOTSI',)
# ('LBXRBCSI',)
# P Value:  0.2886408574195697
# LBXHGB
# ('LBXBMN',)
# ('LBDFOTSI',)
# ('URDFLOW1',)
# ('LBXRBCSI',)
# P Value:  0.3150571124591356
# LBXRBCSI
# ('LBXBMN',)
# ('LBDFOTSI',)
# ('URDFLOW1',)
# ('LBXBMN', 'LBDFOTSI')
# ('LBXBMN', 'URDFLOW1')
# ('LBDFOTSI', 'URDFLOW1')
# ('LBXBMN', 'LBDFOTSI', 'URDFLOW1')
# Train Adj: {'LBXBMN', 'LBDFOTSI', 'URDFLOW1', 'LBXRBCSI'}
# corr_X: 0.009497255621491731
# corr_Y: 0.012136526924670618
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that URXCRS cause LBXBMN.
# corr_X: 0.06803042167127892
# corr_Y: 0.024107762363099403
# Identifiable:
#                        LBDFOTSI is cause and P-value is 0.18,
#                        URXCRS is effect and P-value is 0.0.
# corr_X: 0.09298447964755818
# corr_Y: 0.04827023511367946
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that URDFLOW1 cause URXCRS.
# corr_X: 0.006113963259283022
# corr_Y: 0.009997650741389221
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that URXCRS cause LBXRBCSI.
# parSet: ['LBDFOTSI', 'URDFLOW1']
# chiSet: ['LBXBMN', 'LBXRBCSI']
# Start Identify!
# Aim Variable: URDACT
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS']
# Init Adj: {'LBDNENO', 'LBXHGB', 'LBXRBCSI'}
# LBXHGB
# ('LBDNENO',)
# ('LBXRBCSI',)
# ('LBDNENO', 'LBXRBCSI')
# LBXRBCSI
# ('LBDNENO',)
# ('LBXHGB',)
# ('LBDNENO', 'LBXHGB')
# P Value:  0.3220943882045749
# LBDNENO
# ('LBXHGB',)
# Train Adj: {'LBDNENO', 'LBXHGB'}
# corr_X: -0.016786795363514993
# corr_Y: -0.3761206253953788
# Identifiable:
#                        URDACT is cause and P-value is 0.35,
#                        LBDNENO is effect and P-value is 0.0.
# find
# 0.35129878472109 2.9367037741689806e-104
# corr_X: -0.00928824124121722
# corr_Y: 0.22230707364147645
# Identifiable:
#                        URDACT is cause and P-value is 0.61,
#                        LBXHGB is effect and P-value is 0.0.
# find
# 0.6060662206114774 7.534083284124471e-36
# parSet: []
# chiSet: ['LBDNENO', 'LBXHGB']
# Start Identify!
# Aim Variable: LBDFOTSI
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT']
# Init Adj: {'LBDLYMNO', 'LBXMCVSI', 'LBXMCHSI', 'LBXMC'}
# LBDLYMNO
# ('LBXMCVSI',)
# ('LBXMCHSI',)
# ('LBXMC',)
# ('LBXMCVSI', 'LBXMCHSI')
# ('LBXMCVSI', 'LBXMC')
# ('LBXMCHSI', 'LBXMC')
# ('LBXMCVSI', 'LBXMCHSI', 'LBXMC')
# LBXMCVSI
# ('LBDLYMNO',)
# ('LBXMCHSI',)
# P Value:  0.42923629054036305
# LBXMC
# ('LBDLYMNO',)
# ('LBXMCHSI',)
# P Value:  0.45788873722236767
# LBXMCHSI
# ('LBDLYMNO',)
# Train Adj: {'LBDLYMNO', 'LBXMCHSI'}
# corr_X: 0.010470098183845917
# corr_Y: 0.0038487054913535442
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBDLYMNO cause LBDFOTSI.
# corr_X: -0.0039023191527357472
# corr_Y: -0.026966807113092402
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBDFOTSI cause LBXMCHSI.
# find
# 0.8284743938533593 0.13426927974524056
# parSet: ['LBDLYMNO']
# chiSet: ['LBXMCHSI']
# Start Identify!
# Aim Variable: URDFLOW1
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT']
# Init Adj: {'LBXBCD', 'LBXWBCSI', 'LBXMC'}
# LBXBCD
# ('LBXWBCSI',)
# P Value:  0.4608349145635775
# LBXWBCSI
# ('LBXMC',)
# LBXMC
# ('LBXWBCSI',)
# Train Adj: {'LBXWBCSI', 'LBXMC'}
# corr_X: 0.004045204538243255
# corr_Y: -0.02928549340599881
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that URDFLOW1 cause LBXWBCSI.
# find
# 0.8222968799206113 0.10388857339144685
# corr_X: 0.009593257899320334
# corr_Y: -0.042986311653882434
# Identifiable:
#                        URDFLOW1 is cause and P-value is 0.59,
#                        LBXMC is effect and P-value is 0.02.
# find
# 0.5942880037550937 0.016953476650797203
# parSet: []
# chiSet: ['LBXWBCSI', 'LBXMC']
# Start Identify!
# Aim Variable: LBDLYMNO
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1']
# Init Adj: {'LBDBPBSI', 'LBDMONO', 'LBXMOPCT', 'LBDEONO', 'BPXOPLS1', 'LBXPLTSI'}
# LBXMOPCT
# ('LBDBPBSI',)
# ('LBDMONO',)
# ('LBDEONO',)
# ('BPXOPLS1',)
# ('LBXPLTSI',)
# ('LBDBPBSI', 'LBDMONO')
# ('LBDBPBSI', 'LBDEONO')
# ('LBDBPBSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXPLTSI')
# ('LBDMONO', 'LBDEONO')
# ('LBDMONO', 'BPXOPLS1')
# ('LBDMONO', 'LBXPLTSI')
# ('LBDEONO', 'BPXOPLS1')
# ('LBDEONO', 'LBXPLTSI')
# ('BPXOPLS1', 'LBXPLTSI')
# ('LBDBPBSI', 'LBDMONO', 'LBDEONO')
# ('LBDBPBSI', 'LBDMONO', 'BPXOPLS1')
# ('LBDBPBSI', 'LBDMONO', 'LBXPLTSI')
# ('LBDBPBSI', 'LBDEONO', 'BPXOPLS1')
# ('LBDBPBSI', 'LBDEONO', 'LBXPLTSI')
# ('LBDBPBSI', 'BPXOPLS1', 'LBXPLTSI')
# ('LBDMONO', 'LBDEONO', 'BPXOPLS1')
# ('LBDMONO', 'LBDEONO', 'LBXPLTSI')
# ('LBDMONO', 'BPXOPLS1', 'LBXPLTSI')
# ('LBDEONO', 'BPXOPLS1', 'LBXPLTSI')
# LBDBPBSI
# ('LBDMONO',)
# ('LBXMOPCT',)
# ('LBDEONO',)
# ('BPXOPLS1',)
# ('LBXPLTSI',)
# ('LBDMONO', 'LBXMOPCT')
# ('LBDMONO', 'LBDEONO')
# ('LBDMONO', 'BPXOPLS1')
# ('LBDMONO', 'LBXPLTSI')
# ('LBXMOPCT', 'LBDEONO')
# ('LBXMOPCT', 'BPXOPLS1')
# ('LBXMOPCT', 'LBXPLTSI')
# P Value:  0.3645706249834738
# BPXOPLS1
# ('LBXPLTSI',)
# ('LBDEONO',)
# ('LBDMONO',)
# ('LBXMOPCT',)
# ('LBXPLTSI', 'LBDEONO')
# ('LBXPLTSI', 'LBDMONO')
# ('LBXPLTSI', 'LBXMOPCT')
# ('LBDEONO', 'LBDMONO')
# ('LBDEONO', 'LBXMOPCT')
# ('LBDMONO', 'LBXMOPCT')
# P Value:  0.9156401335463107
# LBDEONO
# ('LBXPLTSI',)
# ('LBDMONO',)
# ('LBXMOPCT',)
# ('LBXPLTSI', 'LBDMONO')
# ('LBXPLTSI', 'LBXMOPCT')
# ('LBDMONO', 'LBXMOPCT')
# ('LBXPLTSI', 'LBDMONO', 'LBXMOPCT')
# P Value:  0.2085214256776089
# LBDMONO
# ('LBXPLTSI',)
# ('LBXMOPCT',)
# ('LBXPLTSI', 'LBXMOPCT')
# LBXPLTSI
# ('LBDMONO',)
# ('LBXMOPCT',)
# ('LBDMONO', 'LBXMOPCT')
# Train Adj: {'LBXPLTSI', 'LBDMONO', 'LBXMOPCT'}
# corr_X: -0.0167779839273659
# corr_Y: -0.011741257223152205
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXPLTSI cause LBDLYMNO.
# corr_X: 0.004920620879093573
# corr_Y: -0.018873051166636474
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBDLYMNO cause LBDMONO.
# corr_X: 0.02163521257086617
# corr_Y: 0.012391260451001937
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXMOPCT cause LBDLYMNO.
# parSet: ['LBXPLTSI', 'LBXMOPCT']
# chiSet: ['LBDMONO']
# Start Identify!
# Aim Variable: LBXPLTSI
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO']
# Init Adj: {'LBDBPBSI', 'LBXMCVSI', 'LBXMPSI', 'LBXMOPCT', 'BPXOPLS1'}
# LBXMPSI
# ('LBDBPBSI',)
# ('LBXMCVSI',)
# ('BPXOPLS1',)
# ('LBXMOPCT',)
# ('LBDBPBSI', 'LBXMCVSI')
# ('LBDBPBSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXMOPCT')
# ('LBXMCVSI', 'BPXOPLS1')
# ('LBXMCVSI', 'LBXMOPCT')
# ('BPXOPLS1', 'LBXMOPCT')
# ('LBDBPBSI', 'LBXMCVSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXMCVSI', 'LBXMOPCT')
# ('LBDBPBSI', 'BPXOPLS1', 'LBXMOPCT')
# ('LBXMCVSI', 'BPXOPLS1', 'LBXMOPCT')
# LBXMCVSI
# ('LBDBPBSI',)
# ('LBXMPSI',)
# ('BPXOPLS1',)
# ('LBXMOPCT',)
# ('LBDBPBSI', 'LBXMPSI')
# ('LBDBPBSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXMOPCT')
# ('LBXMPSI', 'BPXOPLS1')
# ('LBXMPSI', 'LBXMOPCT')
# ('BPXOPLS1', 'LBXMOPCT')
# ('LBDBPBSI', 'LBXMPSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXMPSI', 'LBXMOPCT')
# ('LBDBPBSI', 'BPXOPLS1', 'LBXMOPCT')
# ('LBXMPSI', 'BPXOPLS1', 'LBXMOPCT')
# LBXMOPCT
# ('LBDBPBSI',)
# ('LBXMCVSI',)
# ('BPXOPLS1',)
# ('LBXMPSI',)
# ('LBDBPBSI', 'LBXMCVSI')
# ('LBDBPBSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXMPSI')
# ('LBXMCVSI', 'BPXOPLS1')
# ('LBXMCVSI', 'LBXMPSI')
# ('BPXOPLS1', 'LBXMPSI')
# ('LBDBPBSI', 'LBXMCVSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXMCVSI', 'LBXMPSI')
# ('LBDBPBSI', 'BPXOPLS1', 'LBXMPSI')
# ('LBXMCVSI', 'BPXOPLS1', 'LBXMPSI')
# LBDBPBSI
# ('LBXMCVSI',)
# ('BPXOPLS1',)
# ('LBXMOPCT',)
# ('LBXMPSI',)
# ('LBXMCVSI', 'BPXOPLS1')
# ('LBXMCVSI', 'LBXMOPCT')
# ('LBXMCVSI', 'LBXMPSI')
# ('BPXOPLS1', 'LBXMOPCT')
# ('BPXOPLS1', 'LBXMPSI')
# ('LBXMOPCT', 'LBXMPSI')
# ('LBXMCVSI', 'BPXOPLS1', 'LBXMOPCT')
# ('LBXMCVSI', 'BPXOPLS1', 'LBXMPSI')
# ('LBXMCVSI', 'LBXMOPCT', 'LBXMPSI')
# ('BPXOPLS1', 'LBXMOPCT', 'LBXMPSI')
# BPXOPLS1
# ('LBDBPBSI',)
# ('LBXMCVSI',)
# ('LBXMOPCT',)
# ('LBXMPSI',)
# ('LBDBPBSI', 'LBXMCVSI')
# ('LBDBPBSI', 'LBXMOPCT')
# ('LBDBPBSI', 'LBXMPSI')
# ('LBXMCVSI', 'LBXMOPCT')
# ('LBXMCVSI', 'LBXMPSI')
# ('LBXMOPCT', 'LBXMPSI')
# ('LBDBPBSI', 'LBXMCVSI', 'LBXMOPCT')
# ('LBDBPBSI', 'LBXMCVSI', 'LBXMPSI')
# ('LBDBPBSI', 'LBXMOPCT', 'LBXMPSI')
# ('LBXMCVSI', 'LBXMOPCT', 'LBXMPSI')
# Train Adj: {'LBDBPBSI', 'LBXMCVSI', 'LBXMPSI', 'LBXMOPCT', 'BPXOPLS1'}
# corr_X: 0.044516579648234696
# corr_Y: 0.01574075608768267
# Identifiable:
#                        LBDBPBSI is cause and P-value is 0.38,
#                        LBXPLTSI is effect and P-value is 0.01.
# find
# 0.013405980765255883 0.38212635599297484
# corr_X: 0.015884992501617328
# corr_Y: 0.020614012396957954
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXPLTSI cause LBXMCVSI.
# corr_X: 0.0067596686594453385
# corr_Y: 0.013798457809781955
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXPLTSI cause LBXMPSI.
# corr_X: 0.018408724270883133
# corr_Y: 0.011890521183608716
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXMOPCT cause LBXPLTSI.
# corr_X: -0.0017358119409648543
# corr_Y: -0.01258723189675356
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXPLTSI cause BPXOPLS1.
# parSet: ['LBDBPBSI', 'LBXMOPCT']
# chiSet: ['LBXMCVSI', 'LBXMPSI', 'BPXOPLS1']
# Start Identify!
# Aim Variable: LBXMOPCT
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO']
# Init Adj: {'LBDBPBSI', 'LBXEOPCT', 'LBXMCVSI', 'BPXOPLS1', 'LBXPLTSI'}
# LBXPLTSI
# ('LBDBPBSI',)
# ('LBXEOPCT',)
# ('BPXOPLS1',)
# ('LBXMCVSI',)
# ('LBDBPBSI', 'LBXEOPCT')
# ('LBDBPBSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXMCVSI')
# ('LBXEOPCT', 'BPXOPLS1')
# ('LBXEOPCT', 'LBXMCVSI')
# ('BPXOPLS1', 'LBXMCVSI')
# ('LBDBPBSI', 'LBXEOPCT', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXEOPCT', 'LBXMCVSI')
# ('LBDBPBSI', 'BPXOPLS1', 'LBXMCVSI')
# ('LBXEOPCT', 'BPXOPLS1', 'LBXMCVSI')
# BPXOPLS1
# ('LBXPLTSI',)
# ('LBDBPBSI',)
# ('LBXEOPCT',)
# ('LBXMCVSI',)
# ('LBXPLTSI', 'LBDBPBSI')
# ('LBXPLTSI', 'LBXEOPCT')
# ('LBXPLTSI', 'LBXMCVSI')
# ('LBDBPBSI', 'LBXEOPCT')
# ('LBDBPBSI', 'LBXMCVSI')
# ('LBXEOPCT', 'LBXMCVSI')
# ('LBXPLTSI', 'LBDBPBSI', 'LBXEOPCT')
# ('LBXPLTSI', 'LBDBPBSI', 'LBXMCVSI')
# ('LBXPLTSI', 'LBXEOPCT', 'LBXMCVSI')
# ('LBDBPBSI', 'LBXEOPCT', 'LBXMCVSI')
# LBXMCVSI
# ('LBXPLTSI',)
# ('LBDBPBSI',)
# ('LBXEOPCT',)
# ('BPXOPLS1',)
# ('LBXPLTSI', 'LBDBPBSI')
# ('LBXPLTSI', 'LBXEOPCT')
# ('LBXPLTSI', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXEOPCT')
# ('LBDBPBSI', 'BPXOPLS1')
# ('LBXEOPCT', 'BPXOPLS1')
# ('LBXPLTSI', 'LBDBPBSI', 'LBXEOPCT')
# ('LBXPLTSI', 'LBDBPBSI', 'BPXOPLS1')
# ('LBXPLTSI', 'LBXEOPCT', 'BPXOPLS1')
# ('LBDBPBSI', 'LBXEOPCT', 'BPXOPLS1')
# LBDBPBSI
# ('LBXPLTSI',)
# ('LBXEOPCT',)
# ('BPXOPLS1',)
# ('LBXMCVSI',)
# ('LBXPLTSI', 'LBXEOPCT')
# ('LBXPLTSI', 'BPXOPLS1')
# ('LBXPLTSI', 'LBXMCVSI')
# ('LBXEOPCT', 'BPXOPLS1')
# ('LBXEOPCT', 'LBXMCVSI')
# ('BPXOPLS1', 'LBXMCVSI')
# ('LBXPLTSI', 'LBXEOPCT', 'BPXOPLS1')
# P Value:  0.21741966235480414
# LBXEOPCT
# ('LBXPLTSI',)
# ('LBXMCVSI',)
# ('BPXOPLS1',)
# ('LBXPLTSI', 'LBXMCVSI')
# ('LBXPLTSI', 'BPXOPLS1')
# ('LBXMCVSI', 'BPXOPLS1')
# ('LBXPLTSI', 'LBXMCVSI', 'BPXOPLS1')
# Train Adj: {'LBXPLTSI', 'LBXEOPCT', 'BPXOPLS1', 'LBXMCVSI'}
# corr_X: 0.010461208556542688
# corr_Y: 0.018493940002195786
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXMOPCT cause LBXPLTSI.
# corr_X: -0.009638431670397817
# corr_Y: 0.0017155347830303887
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXEOPCT cause LBXMOPCT.
# corr_X: 0.002014448719094101
# corr_Y: -0.006726763303051322
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXMOPCT cause BPXOPLS1.
# corr_X: 0.005676568971111455
# corr_Y: 0.004201090051704073
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXMCVSI cause LBXMOPCT.
# parSet: ['LBXEOPCT', 'LBXMCVSI']
# chiSet: ['LBXPLTSI', 'BPXOPLS1']
# Start Identify!
# Aim Variable: LBDBPBSI
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT']
# Init Adj: {'LBXBCD', 'LBXTHG'}
# LBXTHG
# ('LBXBCD',)
# LBXBCD
# ('LBXTHG',)
# Train Adj: {'LBXBCD', 'LBXTHG'}
# corr_X: -0.16401106907571186
# corr_Y: -0.07677980462993736
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LBXBCD cause LBDBPBSI.
# corr_X: -0.2516622088074115
# corr_Y: 0.025107770739627666
# Identifiable:
#                        LBXTHG is cause and P-value is 0.16,
#                        LBDBPBSI is effect and P-value is 0.0.
# parSet: ['LBXBCD', 'LBXTHG']
# chiSet: []
# Start Identify!
# Aim Variable: LBXMOPCT
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT']
# Init Adj: {'LBDBPBSI', 'LBXEOPCT'}
# LBDBPBSI
# ('LBXEOPCT',)
# LBXEOPCT
# ('LBDBPBSI',)
# Train Adj: {'LBDBPBSI', 'LBXEOPCT'}
# corr_X: -0.022906008069949736
# corr_Y: 0.006521318183549289
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBDBPBSI cause LBXMOPCT.
# corr_X: -0.010041991175396421
# corr_Y: 0.0015125742570030378
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXEOPCT cause LBXMOPCT.
# parSet: ['LBDBPBSI', 'LBXEOPCT']
# chiSet: []
# Start Identify!
# Aim Variable: LBXEOPCT
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT']
# Init Adj: {'LBDBPBSI', 'LBDEONO'}
# LBDBPBSI
# ('LBDEONO',)
# LBDEONO
# ('LBDBPBSI',)
# Train Adj: {'LBDBPBSI', 'LBDEONO'}
# corr_X: 0.007738001173061275
# corr_Y: -0.027996826497546704
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBXEOPCT cause LBDBPBSI.
# find
# 0.6674703967104278 0.1200184853903062
# corr_X: -0.044028742484042226
# corr_Y: -0.06098443393241042
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LBXEOPCT cause LBDEONO.
# parSet: ['LBDEONO']
# chiSet: ['LBDBPBSI']
# Start Identify!
# Aim Variable: LBXMCVSI
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT']
# Init Adj: {'LBDBPBSI', 'LBXBCD'}
# LBXBCD
# ('LBDBPBSI',)
# LBDBPBSI
# ('LBXBCD',)
# Train Adj: {'LBDBPBSI', 'LBXBCD'}
# corr_X: -0.026885869424932537
# corr_Y: 0.0025574655691897484
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that LBDBPBSI cause LBXMCVSI.
# find
# 0.1354422882942443 0.8870867960865092
# corr_X: -0.1368999079666448
# corr_Y: 0.023534397057507737
# Identifiable:
#                        LBXBCD is cause and P-value is 0.19,
#                        LBXMCVSI is effect and P-value is 0.0.
# parSet: ['LBDBPBSI', 'LBXBCD']
# chiSet: []
# Start Identify!
# Aim Variable: LBXBCD
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI']
# Init Adj: set()
# Train Adj: set()
# parSet: []
# chiSet: []
# Start Identify!
# Aim Variable: LBXTHG
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI']
# Init Adj: {'LBXBSE'}
# LBXBSE
# No much variable to CI test!
# Train Adj: {'LBXBSE'}
# corr_X: -0.004423673057242724
# corr_Y: -0.21939083897137923
# Identifiable:
#                        LBXTHG is cause and P-value is 0.81,
#                        LBXBSE is effect and P-value is 0.0.
# find
# 0.805988242412148 6.155226983546365e-35
# parSet: []
# chiSet: ['LBXBSE']
# Start Identify!
# Aim Variable: LBDBPBSI
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI']
# Init Adj: {'LBXBCD', 'LBXTHG'}
# LBXTHG
# ('LBXBCD',)
# LBXBCD
# ('LBXTHG',)
# Train Adj: {'LBXBCD', 'LBXTHG'}
# corr_X: -0.17133044260891925
# corr_Y: -0.09096364828177378
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LBXBCD cause LBDBPBSI.
# corr_X: -0.25585039812917443
# corr_Y: 0.025107770739627666
# Identifiable:
#                        LBXTHG is cause and P-value is 0.16,
#                        LBDBPBSI is effect and P-value is 0.0.
# parSet: ['LBXBCD', 'LBXTHG']
# chiSet: []
# Start Identify!
# Aim Variable: LBXEOPCT
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI']
# Init Adj: {'LBDEONO'}
# LBDEONO
# No much variable to CI test!
# Train Adj: {'LBDEONO'}
# corr_X: -0.044673623260436286
# corr_Y: -0.06098443393241042
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LBXEOPCT cause LBDEONO.
# parSet: ['LBDEONO']
# chiSet: []
# Start Identify!
# Aim Variable: LBDEONO
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI']
# Init Adj: set()
# Train Adj: set()
# parSet: []
# chiSet: []
# Start Identify!
# Aim Variable: LBDBPBSI
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI']
# Init Adj: {'LBXBCD', 'LBXTHG'}
# LBXTHG
# ('LBXBCD',)
# LBXBCD
# ('LBXTHG',)
# Train Adj: {'LBXBCD', 'LBXTHG'}
# corr_X: -0.16904172889304547
# corr_Y: -0.08865619193861883
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LBXBCD cause LBDBPBSI.
# corr_X: -0.23376986262564114
# corr_Y: 0.023990797801302446
# Identifiable:
#                        LBXTHG is cause and P-value is 0.18,
#                        LBDBPBSI is effect and P-value is 0.0.
# parSet: ['LBXBCD', 'LBXTHG']
# chiSet: []
# Start Identify!
# Aim Variable: LBXBCD
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI']
# Init Adj: set()
# Train Adj: set()
# parSet: []
# chiSet: []
# Start Identify!
# Aim Variable: LBXBCD
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI', 'LBXBSE', 'LBXBCD', 'LBXTHG', 'LBDBPBSI', 'LBXEOPCT', 'LBDEONO', 'LBDBPBSI', 'LBXBCD']
# Init Adj: set()
# Train Adj: set()
# parSet: []
# chiSet: []
# Start Identify!
# Aim Variable: LBXTHG
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI', 'LBXBSE', 'LBXBCD', 'LBXTHG', 'LBDBPBSI', 'LBXEOPCT', 'LBDEONO', 'LBDBPBSI', 'LBXBCD']
# Init Adj: set()
# Train Adj: set()
# parSet: []
# chiSet: []
# Start Identify!
# Aim Variable: LBDEONO
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI', 'LBXBSE', 'LBXBCD', 'LBXTHG', 'LBDBPBSI', 'LBXEOPCT', 'LBDEONO', 'LBDBPBSI', 'LBXBCD']
# Init Adj: set()
# Train Adj: set()
# parSet: []
# chiSet: []
# Start Identify!
# Aim Variable: LBXBCD
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI', 'LBXBSE', 'LBXBCD', 'LBXTHG', 'LBDBPBSI', 'LBXEOPCT', 'LBDEONO', 'LBDBPBSI', 'LBXBCD']
# Init Adj: set()
# Train Adj: set()
# parSet: []
# chiSet: []
# Start Identify!
# Aim Variable: LBXTHG
# exclSet: ['BMXBMI', 'LBDTCSI', 'BPXOSY1', 'LBXRDW', 'DIQ010', 'LBXLYPCT', 'LBXHCT', 'LBXNEPCT', 'LBDRFOSI', 'URXUMS', 'BPXODI1', 'URXCRS', 'LBXRBCSI', 'LBXBMN', 'LBXRBCSI', 'LBDNENO', 'LBXHGB', 'LBDFOTSI', 'URXCRS', 'URDACT', 'LBXMCHSI', 'LBXWBCSI', 'LBXMC', 'LBDFOTSI', 'URDFLOW1', 'LBDMONO', 'LBDLYMNO', 'LBXMCVSI', 'LBXMPSI', 'BPXOPLS1', 'LBXPLTSI', 'BPXOPLS1', 'LBXPLTSI', 'LBXMOPCT', 'LBDBPBSI', 'LBDBPBSI', 'LBXMOPCT', 'LBXEOPCT', 'LBXMCVSI', 'LBXBSE', 'LBXBCD', 'LBXTHG', 'LBDBPBSI', 'LBXEOPCT', 'LBDEONO', 'LBDBPBSI', 'LBXBCD']
# Init Adj: set()
# Train Adj: set()
# parSet: []
# chiSet: []
# Ancestors: {'DIQ010': ['LBDRFOSI', 'URXUMS'], 'LBDRFOSI': ['LBDFOTSI'], 'URXUMS': ['URXCRS', 'URDACT'], 'LBDFOTSI': ['LBDLYMNO'], 'URXCRS': ['LBDFOTSI', 'URDFLOW1'], 'URDACT': [], 'URDFLOW1': [], 'LBDLYMNO': ['LBXPLTSI', 'LBXMOPCT'], 'LBXPLTSI': ['LBDBPBSI', 'LBXMOPCT'], 'LBXMOPCT': ['LBDBPBSI', 'LBXEOPCT'], 'LBDBPBSI': ['LBXBCD', 'LBXTHG'], 'LBXEOPCT': ['LBDEONO'], 'LBXMCVSI': ['LBDBPBSI', 'LBXBCD'], 'LBXBCD': [], 'LBXTHG': [], 'LBDEONO': []}
# End_time: 2024-05-21 22:02:04.246549+08:00
# time_difference: 9:48:46.984877
