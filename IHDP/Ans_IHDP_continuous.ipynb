# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Jul 28 20:46:11 2024

@author: yhzha
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score,roc_auc_score,average_precision_score

from itertools import combinations
from utilPlus import gcm_test,anm_test
import os
import seaborn as sns

import datetime
import pytz

def causalDirect(p_value_foward,p_value_backward,v1,v2,alpha = 0.05):
    result = False
    if p_value_foward >= p_value_backward:
        if p_value_foward >= alpha:
            if p_value_backward < alpha:
                print("Identifiable: \n \
                      {} is cause and P-value is {}, \n \
                      {} is effect and P-value is {}.".format(v1,round(p_value_foward,2),v2,round(p_value_backward,2)))
                result = True
            else:
                print("Unidentifiable: \n \
                      ALL direction's P-value large than {}. \n \
                      The direction mabey that {} cause {}.".format(alpha, v1, v2))
        else:
            print("Unidentifiable: \n \
                  ALL direction's P-value small than {}. \n \
                  The direction mabey that {} cause {}.".format(alpha, v1, v2))
    else:
        if p_value_backward >= alpha:
            if p_value_foward < alpha:
                print("Identifiable: \n \
                      {} is cause and P-value is {}, \n \
                      {} is effect and P-value is {}.".format(v2,round(p_value_backward,2),v1,round(p_value_foward,2)))
                result = True
            else:
                print("Unidentifiable: \n \
                      ALL direction's P-value large than {}. \n \
                      The direction mabey that {} cause {}.".format(alpha,v2,v1))
        else:
            print("Unidentifiable: \n \
                  ALL direction's P-value small than {}. \n \
                  The direction mabey that {} cause {}.".format(alpha, v2,v1))
    return result
        
def P_Identify(dataFrame,searchV,aimV,searchVType,corMat,corTheta = 0.05,CITheta = 0.05,directTheta = 0.1,is_str = True,exclSet = []):
    """
    Parameters
    ----------
    dataFrame : dataFrame
        DESCRIPTION.
    searchV : list
        DESCRIPTION.
    aimV : TYPE
        DESCRIPTION.
    aimVType : TYPE
        DESCRIPTION.
    corMat : DataFrame
        DESCRIPTION.
    corTheta : TYPE, optional
        DESCRIPTION. The default is 0.2.
    CITheta : TYPE, optional
        DESCRIPTION. The default is 0.05.
    directTheta : TYPE, optional
        DESCRIPTION. The default is 0.05.
    is_str : TYPE, Bool
        DESCRIPTION. Whether strict judgement. 
        False means judging only according to the size of the P value in different directions; 
        True means judging the parent-child relationship strictly according to the threshold;

    Returns
    -------
    None.

    """
    aimVType = searchVType[aimV]

    if len(searchV) == len(corMat):
        print("Start Identify!")
        print("Aim Variable:",aimV)
    else:
        print("corMat is not consistency with searchV")
        return
    
    # AdjIndex = corMat[aimV] > corTheta
    # AdjIndex = (corMat[aimV] >= corTheta) | (corMat[aimV] <= -corTheta)
    if corTheta == 'count':
        corA = [np.abs(corMat[aimV].iloc[i]) for i in range(len(corMat[aimV]))]
        nLen = len(corA)
        if aimV == 'y':
            countNum = 20
            per_ = (1 - round(countNum / nLen, 2)) * 100
            corTheta = np.percentile(corA, per_)
        else:
            countNum = 6
            per_ = (1 - round(countNum / nLen, 2)) * 100
            corTheta = np.percentile(corA, per_)
            corTheta = max(corTheta, 0.1)

        AdjIndex = (corMat[aimV] >= corTheta) | (corMat[aimV] <= -corTheta)
    else:
        AdjIndex = (corMat[aimV] >= corTheta) | (corMat[aimV] <= -corTheta)
    
    '''
    if aimV == 'ajcc_pathologic_stage':
        CITheta = 0.3
        directTheta = 0.2
    '''

    Adj = set([searchV[i] for i in range(len(searchV)) if AdjIndex.iloc[i]])
    Adj = Adj - set([aimV])
    Adj = Adj - set(exclSet)
    print('exclSet:',exclSet)
    print('Init Adj:',Adj)
    print('Init Adj Length:',len(Adj))
    
    AdjDict = {}
    for x_a in Adj:
        AdjDict[x_a] = corMat.loc[x_a,aimV]
        # print(x_a,AdjDict[x_a])
    
    sortedAdjDict = sorted(AdjDict.items(), key=lambda x: x[1])
    # print(sortedAdjDict)

    NoAdj = [] 
    # for x_ in Adj:
    for x_c in sortedAdjDict:
        
        x_ = x_c[0]
        print(x_)
        size = 1
        CAdj = Adj - set([x_])
        if len(CAdj) >= size:
            test = True
        else:
            test = False
            print("No much variable to CI test!")
        while test:
            for CAdj_ in combinations(CAdj,size):
                print(CAdj_)
                
                test_statistic,P_ = gcm_test(X = dataFrame[[aimV]].values.ravel(), 
                                             Y = dataFrame[[x_]].values.ravel(), 
                                             Z = dataFrame[list(CAdj_)], 
                                             X_type = aimVType, 
                                             Y_type = searchVType[x_],
                                             is_hypyopt = True)
                
                if P_ > CITheta:
                    NoAdj.append(x_)
                    Adj = CAdj
                    test = False
                    
                    break
            size = size + 1
            if size > 3:
                test = False
            if len(CAdj) < size:
                test = False
    print("Train Adj:",Adj)

    parSet = []
    chiSet = []
    for pc_ in Adj:
        ## ANM
        P_foward_, P_back_ = anm_test(X = dataFrame[[aimV]].values.ravel(), 
                                      Y = dataFrame[[pc_]].values.ravel(), 
                                      X_type = aimVType, 
                                      Y_type = searchVType[pc_],
                                      is_hypyopt = True)

        causalDirect(P_foward_, P_back_,aimV, pc_)
        if is_str:
            if (P_foward_ > directTheta) & (P_back_ <= directTheta):
                print('find')
                print(P_foward_,P_back_)
                chiSet.append(pc_)
            elif (P_foward_ <= directTheta) & (P_back_ > directTheta):
                print('find')
                print(P_foward_,P_back_)
                parSet.append(pc_)
            elif P_foward_ <= P_back_:
                parSet.append(pc_)
            elif abs(P_foward_ - P_back_) <= round(directTheta / 2, 2):
                parSet.append(pc_)
            else:
                chiSet.append(pc_)
            '''
            else:
                parSet.append(pc_)
            '''
            
            
            
        else:
            if P_back_ >= directTheta:
                parSet.append(pc_)
            elif P_foward_ >= directTheta:
                chiSet.append(pc_)
            else:
                parSet.append(pc_)

    print("parSet:",parSet)
    print("chiSet:",chiSet)
                
    return parSet,chiSet,NoAdj,Adj


def A_Identify(dataFrame,searchV,aimV,searchVType,corMat,corTheta = 0.05,CITheta = 0.05,directTheta = 0.1,is_str = True):
    search = True
    toIdeSet = [aimV]
    Ancestors = {}
    exclSet = []
    while search:
        toIdeSet_ = []
        exclSet_ = []
        for IdeV in toIdeSet:
            P_IdeV,C_IdeV,NA_IdeV,A_IdeV = P_Identify(dataFrame,searchV,IdeV,searchVType,corMat,corTheta,CITheta,directTheta,is_str,exclSet)
            toIdeSet_.extend(P_IdeV)
            exclSet_.extend(C_IdeV)
            Ancestors[IdeV] = P_IdeV
        if len(toIdeSet_) == 0:
            search = False
        else:
            exclSet.extend(toIdeSet)
            exclSet.extend(exclSet_)
            toIdeSet = [item for item in toIdeSet_ if item not in exclSet]
            toIdeSet = list(set(toIdeSet))
            
    
    return Ancestors


dataFile = './data-ihdp-continuous.csv'

dataFrame = pd.read_csv(dataFile)
NoUseV = ['y_f', 'y_cf']
aimV = 'y'

dataFrame = dataFrame.drop(columns = NoUseV)
dataFrame.columns

useCol = list(dataFrame.columns)
disCol = ['sex', 'twin', 'b.marr', 'mom.lths', 'mom.hs', 'mom.scoll', 'cig', 'first', 'booze', 'drugs', 'work.dur', 'prenatal', 'ark', 'ein', 'har', 'mia', 'pen', 'tex', 'was']
conCol = list(set(useCol) - set(disCol))
useColType = {}
for col_ in conCol:
    useColType[col_] = 'continuous'
for col_ in disCol:
    useColType[col_] = 'discrete'

# useColType['t'] = 'discrete'
# 'discrete' 'continuous'
corMat = dataFrame.corr(method='spearman')
corPercDesc = corMat[aimV].describe(percentiles = [.1, .5, .75, .9, .95])

corTheta = corPercDesc.loc['90%']
print(corTheta)
corTheta = 'count'
corTheta = 0.2
# plt.subplots(figsize = (50,30))
# hosts1=sns.heatmap(corMat,annot=True,linewidths = .5,cmap ="YlGnBu")
# plt.show()

Start_time = datetime.datetime.now(pytz.timezone('Asia/Shanghai'))
print("Start_time:", Start_time)
 
# Gene Data
Ancestors = A_Identify(dataFrame = dataFrame,searchV = useCol,aimV = aimV,
                       searchVType = useColType, corMat = corMat, 
                       corTheta = corTheta,CITheta = 0.15,directTheta = 0.05)

print('Ancestors:',Ancestors)

End_time = datetime.datetime.now(pytz.timezone('Asia/Shanghai'))
print("End_time:", End_time)
 
# date diff
time_difference = End_time - Start_time
print("time_difference:", time_difference)
# Out:
# 0.2382343559003751
# Start_time: 2024-07-28 23:10:12.495288+08:00
# Start Identify!
# Aim Variable: y
# exclSet: []
# Init Adj: {'X_31', 'mom.lths', 'X_35', 'X_19', 't', 'X_2', 'X_11'}
# Init Adj Length: 7
# t
# ('X_31',)
# ('X_35',)
# ('mom.lths',)
# ('X_19',)
# ('X_2',)
# ('X_11',)
# ('X_31', 'X_35')
# ('X_31', 'mom.lths')
# ('X_31', 'X_19')
# ('X_31', 'X_2')
# ('X_31', 'X_11')
# ('X_35', 'mom.lths')
# ('X_35', 'X_19')
# ('X_35', 'X_2')
# ('X_35', 'X_11')
# ('mom.lths', 'X_19')
# ('mom.lths', 'X_2')
# ('mom.lths', 'X_11')
# ('X_19', 'X_2')
# ('X_19', 'X_11')
# ('X_2', 'X_11')
# ('X_31', 'X_35', 'mom.lths')
# ('X_31', 'X_35', 'X_19')
# ('X_31', 'X_35', 'X_2')
# ('X_31', 'X_35', 'X_11')
# ('X_31', 'mom.lths', 'X_19')
# ('X_31', 'mom.lths', 'X_2')
# ('X_31', 'mom.lths', 'X_11')
# ('X_31', 'X_19', 'X_2')
# ('X_31', 'X_19', 'X_11')
# ('X_31', 'X_2', 'X_11')
# ('X_35', 'mom.lths', 'X_19')
# ('X_35', 'mom.lths', 'X_2')
# ('X_35', 'mom.lths', 'X_11')
# ('X_35', 'X_19', 'X_2')
# ('X_35', 'X_19', 'X_11')
# ('X_35', 'X_2', 'X_11')
# ('mom.lths', 'X_19', 'X_2')
# ('mom.lths', 'X_19', 'X_11')
# ('mom.lths', 'X_2', 'X_11')
# ('X_19', 'X_2', 'X_11')
# mom.lths
# ('X_31',)
# ('X_35',)
# ('t',)
# ('X_19',)
# ('X_2',)
# X_35
# ('X_31',)
# ('t',)
# ('X_19',)
# X_31
# ('X_11',)
# X_2
# ('X_11',)
# ('X_19',)
# ('t',)
# ('X_11', 'X_19')
# ('X_11', 't')
# ('X_19', 't')
# ('X_11', 'X_19', 't')
# X_19
# ('X_2',)
# ('X_11',)
# ('t',)
# ('X_2', 'X_11')
# ('X_2', 't')
# ('X_11', 't')
# ('X_2', 'X_11', 't')
# X_11
# ('X_2',)
# ('t',)
# ('X_2', 't')
# Train Adj: {'X_2', 'X_11', 't'}
# corr_X: 0.013098371320726124
# corr_Y: -0.003337229579527267
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_2 cause y.
# corr_X: 0.03570889196849907
# corr_Y: 0.008788807507416369
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_11 cause y.
# corr_X: -0.012520613341813296
# corr_Y: -0.0022286390044126557
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that t cause y.
# parSet: ['X_2', 'X_11', 't']
# chiSet: []
# Start Identify!
# Aim Variable: X_2
# exclSet: ['y']
# Init Adj: {'was', 'har', 'X_8', 'X_31', 'X_0', 'momage', 'X_5', 'X_24', 'X_28', 'mom.hs', 'mom.lths', 'X_19', 'work.dur', 'mom.scoll'}
# Init Adj Length: 14
# mom.hs
# ('was',)
# ('har',)
# ('X_8',)
# ('X_31',)
# ('X_0',)
# ('momage',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# momage
# ('was',)
# ('har',)
# ('X_8',)
# ('X_31',)
# ('X_0',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# har
# ('was',)
# ('X_8',)
# ('X_31',)
# ('X_0',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# ('X_19',)
# ('work.dur',)
# ('mom.scoll',)
# ('was', 'X_8')
# ('was', 'X_31')
# ('was', 'X_0')
# ('was', 'X_5')
# ('was', 'X_24')
# ('was', 'X_28')
# ('was', 'mom.lths')
# mom.scoll
# ('was',)
# ('X_8',)
# ('X_31',)
# ('X_0',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# X_19
# ('was',)
# ('X_8',)
# ('X_31',)
# ('X_0',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# work.dur
# ('was',)
# ('X_8',)
# ('X_31',)
# ('X_0',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# X_8
# ('was',)
# ('X_31',)
# ('X_0',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# X_31
# ('was',)
# ('X_0',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# ('was', 'X_0')
# ('was', 'X_5')
# ('was', 'X_24')
# ('was', 'X_28')
# ('was', 'mom.lths')
# ('X_0', 'X_5')
# ('X_0', 'X_24')
# ('X_0', 'X_28')
# ('X_0', 'mom.lths')
# ('X_5', 'X_24')
# ('X_5', 'X_28')
# ('X_5', 'mom.lths')
# ('X_24', 'X_28')
# ('X_24', 'mom.lths')
# ('X_28', 'mom.lths')
# X_0
# ('was',)
# ('X_5',)
# ('X_24',)
# ('X_28',)
# ('mom.lths',)
# X_24
# ('was',)
# ('X_28',)
# ('mom.lths',)
# ('X_5',)
# ('was', 'X_28')
# ('was', 'mom.lths')
# was
# ('X_5',)
# ('X_28',)
# ('mom.lths',)
# ('X_5', 'X_28')
# ('X_5', 'mom.lths')
# ('X_28', 'mom.lths')
# ('X_5', 'X_28', 'mom.lths')
# X_5
# ('was',)
# ('X_28',)
# ('mom.lths',)
# ('was', 'X_28')
# ('was', 'mom.lths')
# X_28
# ('was',)
# ('mom.lths',)
# ('was', 'mom.lths')
# mom.lths
# ('was',)
# ('X_28',)
# ('was', 'X_28')
# Train Adj: {'was', 'X_28', 'mom.lths'}
# corr_X: -0.3231529546043991
# t_statistic_Y: 0.07579783115633136
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that was cause X_2.
# corr_X: -0.024512985059476338
# corr_Y: 0.01976537423798792
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_28 cause X_2.
# corr_X: 0.2537173047400138
# t_statistic_Y: 0.1407034177834324
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that mom.lths cause X_2.
# parSet: ['was', 'X_28', 'mom.lths']
# chiSet: []
# Start Identify!
# Aim Variable: X_11
# exclSet: ['y']
# Init Adj: {'X_31', 'X_35', 'X_0', 'nnhealth', 'momage', 'X_30', 'X_19', 'X_21'}
# Init Adj Length: 8
# X_30
# ('X_31',)
# X_21
# ('X_31',)
# ('X_35',)
# ('X_0',)
# nnhealth
# ('X_31',)
# ('X_35',)
# ('X_0',)
# ('momage',)
# ('X_19',)
# ('X_31', 'X_35')
# ('X_31', 'X_0')
# ('X_31', 'momage')
# ('X_31', 'X_19')
# ('X_35', 'X_0')
# ('X_35', 'momage')
# ('X_35', 'X_19')
# ('X_0', 'momage')
# ('X_0', 'X_19')
# ('momage', 'X_19')
# ('X_31', 'X_35', 'X_0')
# ('X_31', 'X_35', 'momage')
# ('X_31', 'X_35', 'X_19')
# ('X_31', 'X_0', 'momage')
# ('X_31', 'X_0', 'X_19')
# ('X_31', 'momage', 'X_19')
# ('X_35', 'X_0', 'momage')
# ('X_35', 'X_0', 'X_19')
# ('X_35', 'momage', 'X_19')
# ('X_0', 'momage', 'X_19')
# momage
# ('X_31',)
# ('X_35',)
# ('X_0',)
# ('nnhealth',)
# ('X_19',)
# ('X_31', 'X_35')
# ('X_31', 'X_0')
# ('X_31', 'nnhealth')
# ('X_31', 'X_19')
# ('X_35', 'X_0')
# ('X_35', 'nnhealth')
# ('X_35', 'X_19')
# ('X_0', 'nnhealth')
# ('X_0', 'X_19')
# ('nnhealth', 'X_19')
# ('X_31', 'X_35', 'X_0')
# ('X_31', 'X_35', 'nnhealth')
# ('X_31', 'X_35', 'X_19')
# ('X_31', 'X_0', 'nnhealth')
# ('X_31', 'X_0', 'X_19')
# ('X_31', 'nnhealth', 'X_19')
# ('X_35', 'X_0', 'nnhealth')
# ('X_35', 'X_0', 'X_19')
# ('X_35', 'nnhealth', 'X_19')
# ('X_0', 'nnhealth', 'X_19')
# X_0
# ('X_31',)
# ('X_35',)
# ('nnhealth',)
# ('momage',)
# X_35
# ('X_19',)
# X_31
# ('momage',)
# ('nnhealth',)
# ('X_19',)
# ('momage', 'nnhealth')
# ('momage', 'X_19')
# ('nnhealth', 'X_19')
# ('momage', 'nnhealth', 'X_19')
# X_19
# ('X_31',)
# ('nnhealth',)
# ('momage',)
# ('X_31', 'nnhealth')
# ('X_31', 'momage')
# ('nnhealth', 'momage')
# ('X_31', 'nnhealth', 'momage')
# Train Adj: {'X_19', 'X_31', 'nnhealth', 'momage'}
# corr_X: 0.0337812663393175
# corr_Y: 0.035336166244597324
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_11 cause X_19.
# corr_X: 0.04207937252875245
# corr_Y: 0.057202559719170876
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_11 cause X_31.
# corr_X: 0.03084792911646053
# corr_Y: 0.00044828170516571735
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that nnhealth cause X_11.
# corr_X: 0.05481458764279296
# corr_Y: 0.025560472535380744
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that momage cause X_11.
# parSet: ['X_19', 'nnhealth', 'momage']
# chiSet: ['X_31']
# Start Identify!
# Aim Variable: t
# exclSet: ['y']
# Init Adj: {'X_25', 'ein', 'X_16', 'pen', 'X_24', 'X_32'}
# Init Adj Length: 6
# X_32
# ('X_25',)
# ('ein',)
# ('X_16',)
# ('pen',)
# ('X_24',)
# ('X_25', 'ein')
# ('X_25', 'X_16')
# ('X_25', 'pen')
# ('X_25', 'X_24')
# ('ein', 'X_16')
# ('ein', 'pen')
# ('ein', 'X_24')
# ('X_16', 'pen')
# ('X_16', 'X_24')
# ('pen', 'X_24')
# ('X_25', 'ein', 'X_16')
# ('X_25', 'ein', 'pen')
# X_25
# ('pen',)
# ('X_24',)
# ('ein',)
# ('X_16',)
# ('pen', 'X_24')
# ('pen', 'ein')
# ('pen', 'X_16')
# ('X_24', 'ein')
# ('X_24', 'X_16')
# ('ein', 'X_16')
# ('pen', 'X_24', 'ein')
# ('pen', 'X_24', 'X_16')
# ('pen', 'ein', 'X_16')
# ('X_24', 'ein', 'X_16')
# X_24
# ('X_25',)
# ('pen',)
# ('ein',)
# ('X_16',)
# ('X_25', 'pen')
# ('X_25', 'ein')
# ('X_25', 'X_16')
# ('pen', 'ein')
# ('pen', 'X_16')
# ('ein', 'X_16')
# ('X_25', 'pen', 'ein')
# ('X_25', 'pen', 'X_16')
# ('X_25', 'ein', 'X_16')
# ('pen', 'ein', 'X_16')
# pen
# ('X_25',)
# ('X_24',)
# ('ein',)
# ('X_16',)
# ('X_25', 'X_24')
# ('X_25', 'ein')
# ('X_25', 'X_16')
# ('X_24', 'ein')
# ('X_24', 'X_16')
# ('ein', 'X_16')
# ('X_25', 'X_24', 'ein')
# ('X_25', 'X_24', 'X_16')
# ('X_25', 'ein', 'X_16')
# ('X_24', 'ein', 'X_16')
# ein
# ('X_25',)
# ('X_24',)
# ('pen',)
# ('X_16',)
# ('X_25', 'X_24')
# ('X_25', 'pen')
# ('X_25', 'X_16')
# ('X_24', 'pen')
# ('X_24', 'X_16')
# ('pen', 'X_16')
# ('X_25', 'X_24', 'pen')
# ('X_25', 'X_24', 'X_16')
# ('X_25', 'pen', 'X_16')
# ('X_24', 'pen', 'X_16')
# X_16
# ('X_25',)
# ('X_24',)
# ('pen',)
# ('ein',)
# ('X_25', 'X_24')
# ('X_25', 'pen')
# ('X_25', 'ein')
# ('X_24', 'pen')
# ('X_24', 'ein')
# ('pen', 'ein')
# ('X_25', 'X_24', 'pen')
# ('X_25', 'X_24', 'ein')
# ('X_25', 'pen', 'ein')
# ('X_24', 'pen', 'ein')
# Train Adj: {'X_25', 'ein', 'X_16', 'pen', 'X_24'}
# corr_X: -0.0037705264722781248
# corr_Y: -0.007453161414852684
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that t cause X_25.
# corr_X: -0.32825633920939057
# t_statistic_Y: 0.022040028471506764
# Identifiable:
#                        ein is cause and P-value is 0.55,
#                        t is effect and P-value is 0.0.
# find
# 3.167044895304184e-20 0.5475423522681107
# corr_X: -0.011025910353864023
# corr_Y: -0.008551100215977672
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_16 cause t.
# corr_X: -0.6055833491834481
# t_statistic_Y: 0.009413068179089224
# Identifiable:
#                        pen is cause and P-value is 0.8,
#                        t is effect and P-value is 0.0.
# find
# 5.944427436529925e-76 0.7972974665773542
# corr_X: -0.006312903403552707
# corr_Y: -0.002849752582321084
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_24 cause t.
# parSet: ['ein', 'X_16', 'pen', 'X_24']
# chiSet: ['X_25']
# Start Identify!
# Aim Variable: was
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: {'X_24'}
# Init Adj Length: 1
# X_24
# No much variable to CI test!
# Train Adj: {'X_24'}
# t_statistic_X: -0.01196628684098382
# corr_Y: 0.43609230012196487
# Identifiable:
#                        was is cause and P-value is 0.74,
#                        X_24 is effect and P-value is 0.0.
# find
# 0.7440323415691856 5.001637779919536e-36
# parSet: []
# chiSet: ['X_24']
# Start Identify!
# Aim Variable: ein
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: set()
# Init Adj Length: 0
# Train Adj: set()
# parSet: []
# chiSet: []
# Start Identify!
# Aim Variable: nnhealth
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: {'X_1', 'preterm'}
# Init Adj Length: 2
# preterm
# ('X_1',)
# X_1
# ('preterm',)
# Train Adj: {'X_1', 'preterm'}
# corr_X: 0.04296671079169443
# corr_Y: 0.06902545455780304
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that nnhealth cause X_1.
# corr_X: 0.006584726387029112
# corr_Y: 0.02279731185414399
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that nnhealth cause preterm.
# parSet: []
# chiSet: ['X_1', 'preterm']
# Start Identify!
# Aim Variable: momage
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: {'X_0', 'b.marr', 'X_17', 'birth.o', 'X_5', 'tex', 'mom.lths', 'X_41', 'X_19', 'work.dur', 'X_21', 'mom.scoll'}
# Init Adj Length: 12
# mom.lths
# ('X_0',)
# ('b.marr',)
# ('X_17',)
# ('birth.o',)
# ('X_5',)
# ('tex',)
# ('X_41',)
# ('X_19',)
# ('work.dur',)
# ('X_21',)
# ('mom.scoll',)
# ('X_0', 'b.marr')
# ('X_0', 'X_17')
# ('X_0', 'birth.o')
# ('X_0', 'X_5')
# ('X_0', 'tex')
# ('X_0', 'X_41')
# ('X_0', 'X_19')
# ('X_0', 'work.dur')
# ('X_0', 'X_21')
# ('X_0', 'mom.scoll')
# ('b.marr', 'X_17')
# ('b.marr', 'birth.o')
# ('b.marr', 'X_5')
# ('b.marr', 'tex')
# ('b.marr', 'X_41')
# ('b.marr', 'X_19')
# ('b.marr', 'work.dur')
# ('b.marr', 'X_21')
# ('b.marr', 'mom.scoll')
# ('X_17', 'birth.o')
# ('X_17', 'X_5')
# ('X_17', 'tex')
# ('X_17', 'X_41')
# ('X_17', 'X_19')
# ('X_17', 'work.dur')
# ('X_17', 'X_21')
# ('X_17', 'mom.scoll')
# ('birth.o', 'X_5')
# ('birth.o', 'tex')
# ('birth.o', 'X_41')
# ('birth.o', 'X_19')
# ('birth.o', 'work.dur')
# ('birth.o', 'X_21')
# ('birth.o', 'mom.scoll')
# ('X_5', 'tex')
# ('X_5', 'X_41')
# ('X_5', 'X_19')
# ('X_5', 'work.dur')
# ('X_5', 'X_21')
# ('X_5', 'mom.scoll')
# ('tex', 'X_41')
# ('tex', 'X_19')
# ('tex', 'work.dur')
# ('tex', 'X_21')
# ('tex', 'mom.scoll')
# ('X_41', 'X_19')
# ('X_41', 'work.dur')
# ('X_41', 'X_21')
# ('X_41', 'mom.scoll')
# ('X_19', 'work.dur')
# ('X_19', 'X_21')
# ('X_19', 'mom.scoll')
# ('work.dur', 'X_21')
# ('work.dur', 'mom.scoll')
# ('X_21', 'mom.scoll')
# ('X_0', 'b.marr', 'X_17')
# ('X_0', 'b.marr', 'birth.o')
# ('X_0', 'b.marr', 'X_5')
# ('X_0', 'b.marr', 'tex')
# ('X_0', 'b.marr', 'X_41')
# ('X_0', 'b.marr', 'X_19')
# ('X_0', 'b.marr', 'work.dur')
# ('X_0', 'b.marr', 'X_21')
# ('X_0', 'b.marr', 'mom.scoll')
# ('X_0', 'X_17', 'birth.o')
# ('X_0', 'X_17', 'X_5')
# ('X_0', 'X_17', 'tex')
# ('X_0', 'X_17', 'X_41')
# ('X_0', 'X_17', 'X_19')
# ('X_0', 'X_17', 'work.dur')
# ('X_0', 'X_17', 'X_21')
# ('X_0', 'X_17', 'mom.scoll')
# ('X_0', 'birth.o', 'X_5')
# ('X_0', 'birth.o', 'tex')
# ('X_0', 'birth.o', 'X_41')
# ('X_0', 'birth.o', 'X_19')
# ('X_0', 'birth.o', 'work.dur')
# ('X_0', 'birth.o', 'X_21')
# ('X_0', 'birth.o', 'mom.scoll')
# ('X_0', 'X_5', 'tex')
# ('X_0', 'X_5', 'X_41')
# ('X_0', 'X_5', 'X_19')
# ('X_0', 'X_5', 'work.dur')
# tex
# ('X_0',)
# ('b.marr',)
# ('X_17',)
# ('birth.o',)
# ('X_5',)
# ('X_41',)
# ('X_19',)
# ('work.dur',)
# ('X_21',)
# ('mom.scoll',)
# ('X_0', 'b.marr')
# ('X_0', 'X_17')
# ('X_0', 'birth.o')
# ('X_0', 'X_5')
# ('X_0', 'X_41')
# ('X_0', 'X_19')
# ('X_0', 'work.dur')
# ('X_0', 'X_21')
# ('X_0', 'mom.scoll')
# ('b.marr', 'X_17')
# ('b.marr', 'birth.o')
# ('b.marr', 'X_5')
# ('b.marr', 'X_41')
# ('b.marr', 'X_19')
# ('b.marr', 'work.dur')
# ('b.marr', 'X_21')
# ('b.marr', 'mom.scoll')
# ('X_17', 'birth.o')
# ('X_17', 'X_5')
# ('X_17', 'X_41')
# ('X_17', 'X_19')
# ('X_17', 'work.dur')
# ('X_17', 'X_21')
# ('X_17', 'mom.scoll')
# ('birth.o', 'X_5')
# ('birth.o', 'X_41')
# ('birth.o', 'X_19')
# ('birth.o', 'work.dur')
# ('birth.o', 'X_21')
# ('birth.o', 'mom.scoll')
# ('X_5', 'X_41')
# ('X_5', 'X_19')
# ('X_5', 'work.dur')
# ('X_5', 'X_21')
# ('X_5', 'mom.scoll')
# ('X_41', 'X_19')
# ('X_41', 'work.dur')
# ('X_41', 'X_21')
# ('X_41', 'mom.scoll')
# ('X_19', 'work.dur')
# ('X_19', 'X_21')
# ('X_19', 'mom.scoll')
# ('work.dur', 'X_21')
# ('work.dur', 'mom.scoll')
# ('X_21', 'mom.scoll')
# ('X_0', 'b.marr', 'X_17')
# X_5
# ('X_0',)
# ('b.marr',)
# ('X_17',)
# ('birth.o',)
# ('X_41',)
# ('X_19',)
# ('work.dur',)
# ('X_21',)
# ('mom.scoll',)
# ('X_0', 'b.marr')
# ('X_0', 'X_17')
# ('X_0', 'birth.o')
# ('X_0', 'X_41')
# ('X_0', 'X_19')
# ('X_0', 'work.dur')
# ('X_0', 'X_21')
# ('X_0', 'mom.scoll')
# ('b.marr', 'X_17')
# ('b.marr', 'birth.o')
# ('b.marr', 'X_41')
# ('b.marr', 'X_19')
# ('b.marr', 'work.dur')
# ('b.marr', 'X_21')
# ('b.marr', 'mom.scoll')
# ('X_17', 'birth.o')
# ('X_17', 'X_41')
# ('X_17', 'X_19')
# ('X_17', 'work.dur')
# ('X_17', 'X_21')
# ('X_17', 'mom.scoll')
# ('birth.o', 'X_41')
# ('birth.o', 'X_19')
# ('birth.o', 'work.dur')
# ('birth.o', 'X_21')
# ('birth.o', 'mom.scoll')
# ('X_41', 'X_19')
# ('X_41', 'work.dur')
# ('X_41', 'X_21')
# mom.scoll
# ('X_0',)
# ('b.marr',)
# ('X_17',)
# ('birth.o',)
# ('X_41',)
# ('X_19',)
# ('work.dur',)
# ('X_21',)
# ('X_0', 'b.marr')
# birth.o
# ('X_0',)
# ('b.marr',)
# ('X_17',)
# ('X_41',)
# ('X_19',)
# ('work.dur',)
# ('X_21',)
# ('X_0', 'b.marr')
# ('X_0', 'X_17')
# ('X_0', 'X_41')
# ('X_0', 'X_19')
# ('X_0', 'work.dur')
# ('X_0', 'X_21')
# ('b.marr', 'X_17')
# ('b.marr', 'X_41')
# ('b.marr', 'X_19')
# ('b.marr', 'work.dur')
# ('b.marr', 'X_21')
# ('X_17', 'X_41')
# ('X_17', 'X_19')
# ('X_17', 'work.dur')
# ('X_17', 'X_21')
# ('X_41', 'X_19')
# ('X_41', 'work.dur')
# ('X_41', 'X_21')
# ('X_19', 'work.dur')
# ('X_19', 'X_21')
# ('work.dur', 'X_21')
# ('X_0', 'b.marr', 'X_17')
# ('X_0', 'b.marr', 'X_41')
# ('X_0', 'b.marr', 'X_19')
# ('X_0', 'b.marr', 'work.dur')
# ('X_0', 'b.marr', 'X_21')
# ('X_0', 'X_17', 'X_41')
# ('X_0', 'X_17', 'X_19')
# ('X_0', 'X_17', 'work.dur')
# ('X_0', 'X_17', 'X_21')
# ('X_0', 'X_41', 'X_19')
# ('X_0', 'X_41', 'work.dur')
# ('X_0', 'X_41', 'X_21')
# ('X_0', 'X_19', 'work.dur')
# ('X_0', 'X_19', 'X_21')
# ('X_0', 'work.dur', 'X_21')
# ('b.marr', 'X_17', 'X_41')
# ('b.marr', 'X_17', 'X_19')
# ('b.marr', 'X_17', 'work.dur')
# ('b.marr', 'X_17', 'X_21')
# ('b.marr', 'X_41', 'X_19')
# ('b.marr', 'X_41', 'work.dur')
# ('b.marr', 'X_41', 'X_21')
# ('b.marr', 'X_19', 'work.dur')
# ('b.marr', 'X_19', 'X_21')
# ('b.marr', 'work.dur', 'X_21')
# ('X_17', 'X_41', 'X_19')
# ('X_17', 'X_41', 'work.dur')
# ('X_17', 'X_41', 'X_21')
# ('X_17', 'X_19', 'work.dur')
# ('X_17', 'X_19', 'X_21')
# ('X_17', 'work.dur', 'X_21')
# ('X_41', 'X_19', 'work.dur')
# ('X_41', 'X_19', 'X_21')
# ('X_41', 'work.dur', 'X_21')
# ('X_19', 'work.dur', 'X_21')
# X_19
# ('X_0',)
# work.dur
# ('X_0',)
# ('b.marr',)
# ('X_17',)
# ('birth.o',)
# ('X_41',)
# ('X_21',)
# ('X_0', 'b.marr')
# ('X_0', 'X_17')
# ('X_0', 'birth.o')
# ('X_0', 'X_41')
# ('X_0', 'X_21')
# ('b.marr', 'X_17')
# ('b.marr', 'birth.o')
# ('b.marr', 'X_41')
# ('b.marr', 'X_21')
# ('X_17', 'birth.o')
# ('X_17', 'X_41')
# ('X_17', 'X_21')
# ('birth.o', 'X_41')
# ('birth.o', 'X_21')
# ('X_41', 'X_21')
# ('X_0', 'b.marr', 'X_17')
# ('X_0', 'b.marr', 'birth.o')
# ('X_0', 'b.marr', 'X_41')
# ('X_0', 'b.marr', 'X_21')
# ('X_0', 'X_17', 'birth.o')
# ('X_0', 'X_17', 'X_41')
# ('X_0', 'X_17', 'X_21')
# ('X_0', 'birth.o', 'X_41')
# ('X_0', 'birth.o', 'X_21')
# ('X_0', 'X_41', 'X_21')
# ('b.marr', 'X_17', 'birth.o')
# ('b.marr', 'X_17', 'X_41')
# ('b.marr', 'X_17', 'X_21')
# ('b.marr', 'birth.o', 'X_41')
# ('b.marr', 'birth.o', 'X_21')
# ('b.marr', 'X_41', 'X_21')
# ('X_17', 'birth.o', 'X_41')
# ('X_17', 'birth.o', 'X_21')
# ('X_17', 'X_41', 'X_21')
# ('birth.o', 'X_41', 'X_21')
# X_17
# ('X_0',)
# X_41
# ('X_0',)
# X_21
# ('X_0',)
# b.marr
# ('X_0',)
# ('birth.o',)
# ('work.dur',)
# ('X_0', 'birth.o')
# ('X_0', 'work.dur')
# ('birth.o', 'work.dur')
# ('X_0', 'birth.o', 'work.dur')
# X_0
# ('birth.o',)
# ('b.marr',)
# ('work.dur',)
# ('birth.o', 'b.marr')
# ('birth.o', 'work.dur')
# ('b.marr', 'work.dur')
# ('birth.o', 'b.marr', 'work.dur')
# Train Adj: {'X_0', 'b.marr', 'birth.o', 'work.dur'}
# corr_X: 0.0680670353187357
# corr_Y: 0.2072691474144395
# Identifiable:
#                        momage is cause and P-value is 0.06,
#                        X_0 is effect and P-value is 0.0.
# find
# 0.06297017463718559 1.0800634389595652e-08
# corr_X: -0.06121257952204842
# t_statistic_Y: 0.047243202580988845
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that b.marr cause momage.
# corr_X: -0.08222663017229838
# corr_Y: -0.008180573017719645
# Identifiable:
#                        birth.o is cause and P-value is 0.82,
#                        momage is effect and P-value is 0.02.
# find
# 0.024614222343887243 0.823368171478885
# corr_X: -0.129163150042662
# t_statistic_Y: 0.0014799084245822513
# Identifiable:
#                        work.dur is cause and P-value is 0.97,
#                        momage is effect and P-value is 0.0.
# find
# 0.00040146319185252363 0.9677900885230366
# parSet: ['b.marr', 'birth.o', 'work.dur']
# chiSet: ['X_0']
# Start Identify!
# Aim Variable: X_16
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: {'X_10', 'X_35', 'X_33', 'X_34', 'X_41'}
# Init Adj Length: 5
# X_34
# ('X_10',)
# ('X_41',)
# ('X_35',)
# ('X_33',)
# ('X_10', 'X_41')
# ('X_10', 'X_35')
# ('X_10', 'X_33')
# ('X_41', 'X_35')
# ('X_41', 'X_33')
# ('X_35', 'X_33')
# ('X_10', 'X_41', 'X_35')
# ('X_10', 'X_41', 'X_33')
# ('X_10', 'X_35', 'X_33')
# ('X_41', 'X_35', 'X_33')
# X_35
# ('X_34',)
# ('X_10',)
# ('X_41',)
# ('X_33',)
# ('X_34', 'X_10')
# ('X_34', 'X_41')
# ('X_34', 'X_33')
# ('X_10', 'X_41')
# ('X_10', 'X_33')
# ('X_41', 'X_33')
# ('X_34', 'X_10', 'X_41')
# X_41
# ('X_34',)
# ('X_10',)
# ('X_33',)
# ('X_34', 'X_10')
# ('X_34', 'X_33')
# ('X_10', 'X_33')
# ('X_34', 'X_10', 'X_33')
# X_33
# ('X_34',)
# ('X_10',)
# ('X_41',)
# ('X_34', 'X_10')
# ('X_34', 'X_41')
# ('X_10', 'X_41')
# ('X_34', 'X_10', 'X_41')
# X_10
# ('X_34',)
# ('X_41',)
# ('X_33',)
# ('X_34', 'X_41')
# ('X_34', 'X_33')
# ('X_41', 'X_33')
# ('X_34', 'X_41', 'X_33')
# Train Adj: {'X_34', 'X_10', 'X_41', 'X_33'}
# corr_X: -0.029480943659658202
# corr_Y: 0.006168528683125788
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_34 cause X_16.
# corr_X: 0.011753915923187237
# corr_Y: 0.008254491493234196
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_10 cause X_16.
# corr_X: 0.001907732721541497
# corr_Y: -0.008118926077782477
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_16 cause X_41.
# corr_X: -0.007314688352987584
# corr_Y: -0.03716536372439911
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_16 cause X_33.
# parSet: ['X_34', 'X_10']
# chiSet: ['X_41', 'X_33']
# Start Identify!
# Aim Variable: pen
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: {'X_8'}
# Init Adj Length: 1
# X_8
# No much variable to CI test!
# Train Adj: {'X_8'}
# t_statistic_X: 0.07463897495540446
# corr_Y: -0.5366466737109448
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that pen cause X_8.
# parSet: []
# chiSet: ['X_8']
# Start Identify!
# Aim Variable: X_28
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: {'mom.lths'}
# Init Adj Length: 1
# mom.lths
# No much variable to CI test!
# Train Adj: {'mom.lths'}
# corr_X: -0.2603688424919302
# t_statistic_Y: -0.03860119438914631
# Identifiable:
#                        mom.lths is cause and P-value is 0.29,
#                        X_28 is effect and P-value is 0.0.
# find
# 4.852984092783845e-13 0.292044666038712
# parSet: ['mom.lths']
# chiSet: []
# Start Identify!
# Aim Variable: X_24
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: {'was', 'X_7', 'har', 'X_33', 'b.marr', 'X_29', 'X_5', 'mom.hs', 'mom.lths'}
# Init Adj Length: 9
# mom.hs
# ('was',)
# ('X_7',)
# ('har',)
# ('X_33',)
# ('b.marr',)
# ('X_29',)
# ('X_5',)
# was
# ('X_7',)
# ('har',)
# ('X_33',)
# ('b.marr',)
# ('X_29',)
# ('X_5',)
# ('mom.lths',)
# ('X_7', 'har')
# ('X_7', 'X_33')
# ('X_7', 'b.marr')
# ('X_7', 'X_29')
# ('X_7', 'X_5')
# ('X_7', 'mom.lths')
# ('har', 'X_33')
# ('har', 'b.marr')
# ('har', 'X_29')
# ('har', 'X_5')
# ('har', 'mom.lths')
# ('X_33', 'b.marr')
# ('X_33', 'X_29')
# ('X_33', 'X_5')
# ('X_33', 'mom.lths')
# ('b.marr', 'X_29')
# ('b.marr', 'X_5')
# ('b.marr', 'mom.lths')
# ('X_29', 'X_5')
# ('X_29', 'mom.lths')
# ('X_5', 'mom.lths')
# ('X_7', 'har', 'X_33')
# ('X_7', 'har', 'b.marr')
# ('X_7', 'har', 'X_29')
# ('X_7', 'har', 'X_5')
# ('X_7', 'har', 'mom.lths')
# ('X_7', 'X_33', 'b.marr')
# ('X_7', 'X_33', 'X_29')
# b.marr
# ('X_7',)
# ('har',)
# ('X_33',)
# ('X_29',)
# ('X_5',)
# ('mom.lths',)
# X_7
# ('har',)
# ('X_33',)
# ('X_29',)
# ('X_5',)
# ('mom.lths',)
# ('har', 'X_33')
# ('har', 'X_29')
# ('har', 'X_5')
# ('har', 'mom.lths')
# ('X_33', 'X_29')
# ('X_33', 'X_5')
# ('X_33', 'mom.lths')
# ('X_29', 'X_5')
# ('X_29', 'mom.lths')
# ('X_5', 'mom.lths')
# ('har', 'X_33', 'X_29')
# ('har', 'X_33', 'X_5')
# ('har', 'X_33', 'mom.lths')
# ('har', 'X_29', 'X_5')
# ('har', 'X_29', 'mom.lths')
# ('har', 'X_5', 'mom.lths')
# ('X_33', 'X_29', 'X_5')
# ('X_33', 'X_29', 'mom.lths')
# ('X_33', 'X_5', 'mom.lths')
# ('X_29', 'X_5', 'mom.lths')
# X_33
# ('X_7',)
# ('har',)
# ('X_29',)
# ('X_5',)
# ('mom.lths',)
# ('X_7', 'har')
# ('X_7', 'X_29')
# ('X_7', 'X_5')
# ('X_7', 'mom.lths')
# ('har', 'X_29')
# ('har', 'X_5')
# ('har', 'mom.lths')
# ('X_29', 'X_5')
# ('X_29', 'mom.lths')
# ('X_5', 'mom.lths')
# ('X_7', 'har', 'X_29')
# ('X_7', 'har', 'X_5')
# ('X_7', 'har', 'mom.lths')
# ('X_7', 'X_29', 'X_5')
# ('X_7', 'X_29', 'mom.lths')
# ('X_7', 'X_5', 'mom.lths')
# ('har', 'X_29', 'X_5')
# ('har', 'X_29', 'mom.lths')
# ('har', 'X_5', 'mom.lths')
# ('X_29', 'X_5', 'mom.lths')
# har
# ('X_7',)
# ('X_33',)
# ('X_29',)
# ('X_5',)
# X_29
# ('X_5',)
# ('X_7',)
# ('mom.lths',)
# ('X_33',)
# ('X_5', 'X_7')
# mom.lths
# ('X_5',)
# X_5
# ('X_7',)
# ('X_33',)
# ('X_7', 'X_33')
# Train Adj: {'X_5', 'X_7', 'X_33'}
# corr_X: 0.0746491291253529
# corr_Y: 0.002677568095207744
# Identifiable:
#                        X_5 is cause and P-value is 0.94,
#                        X_24 is effect and P-value is 0.04.
# find
# 0.04138145404083715 0.941759170428746
# corr_X: 0.01413798446211334
# corr_Y: -0.019198469553113173
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_24 cause X_7.
# corr_X: 0.013716260577859315
# corr_Y: 0.013595665223149771
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that X_33 cause X_24.
# parSet: ['X_5', 'X_33']
# chiSet: ['X_7']
# Start Identify!
# Aim Variable: mom.lths
# exclSet: ['y', 'X_2', 'X_11', 't', 'X_31', 'X_25']
# Init Adj: {'X_9', 'har', 'X_8', 'X_35', 'X_0', 'b.marr', 'momage', 'X_5', 'X_14', 'X_28', 'X_24', 'tex', 'mom.hs', 'X_19', 'work.dur', 'X_18', 'mom.scoll', 'X_13'}
# Init Adj Length: 18
# mom.hs
# ('X_9',)
# ('har',)
# ('X_8',)
# ('b.marr',)
# ('X_5',)
# ('X_14',)
# ('tex',)
# ('work.dur',)
# ('X_18',)
# ('mom.scoll',)
# ('X_13',)
# ('X_35',)
# ('X_0',)
# ('momage',)
# ('X_28',)
# ('X_24',)
# ('X_19',)
# ('X_9', 'har')
# ('X_9', 'X_8')
# ('X_9', 'b.marr')
# ('X_9', 'X_5')
# ('X_9', 'X_14')
# ('X_9', 'tex')
# ('X_9', 'work.dur')
# ('X_9', 'X_18')
# ('X_9', 'mom.scoll')
# ('X_9', 'X_13')
# ('X_9', 'X_35')
# ('X_9', 'X_0')
# ('X_9', 'momage')
# ('X_9', 'X_28')
# ('X_9', 'X_24')
# ('X_9', 'X_19')
# ('har', 'X_8')
# ('har', 'b.marr')
# ('har', 'X_5')
# ('har', 'X_14')
# ('har', 'tex')
# ('har', 'work.dur')
# ('har', 'X_18')
# ('har', 'mom.scoll')
# ('har', 'X_13')
# ('har', 'X_35')
# ('har', 'X_0')
# ('har', 'momage')
# ('har', 'X_28')
# ('har', 'X_24')
# ('har', 'X_19')
# ('X_8', 'b.marr')
# ('X_8', 'X_5')
# ('X_8', 'X_14')
# ('X_8', 'tex')
# ('X_8', 'work.dur')
# ('X_8', 'X_18')
# ('X_8', 'mom.scoll')
# ('X_8', 'X_13')
# momage
# ('X_9',)
# ('har',)
# ('X_8',)
# ('b.marr',)
# ('X_5',)
# ('X_14',)
# ('tex',)
# ('work.dur',)
# ('X_18',)
# ('mom.scoll',)
# ('X_13',)
# ('X_35',)
# ('X_0',)
# ('X_28',)
# ('X_24',)
# ('X_19',)
# ('X_9', 'har')
# ('X_9', 'X_8')
# ('X_9', 'b.marr')
# ('X_9', 'X_5')
# ('X_9', 'X_14')
# ('X_9', 'tex')
# ('X_9', 'work.dur')
# ('X_9', 'X_18')
# ('X_9', 'mom.scoll')
# ('X_9', 'X_13')
# ('X_9', 'X_35')
# ('X_9', 'X_0')
# ('X_9', 'X_28')
# ('X_9', 'X_24')
# ('X_9', 'X_19')
# ('har', 'X_8')
# ('har', 'b.marr')
# ('har', 'X_5')
# ('har', 'X_14')
# ('har', 'tex')
# ('har', 'work.dur')
# ('har', 'X_18')
# ('har', 'mom.scoll')
# ('har', 'X_13')
# ('har', 'X_35')
# ('har', 'X_0')
# ('har', 'X_28')
# ('har', 'X_24')
# ('har', 'X_19')
# ('X_8', 'b.marr')
# ('X_8', 'X_5')
# ('X_8', 'X_14')
# ('X_8', 'tex')
# ('X_8', 'work.dur')
# ('X_8', 'X_18')
# ('X_8', 'mom.scoll')
# ('X_8', 'X_13')
# ('X_8', 'X_35')
# ('X_8', 'X_0')
# ('X_8', 'X_28')
# ('X_8', 'X_24')
# ('X_8', 'X_19')
# ('b.marr', 'X_5')
# ('b.marr', 'X_14')
# ('b.marr', 'tex')
# ('b.marr', 'work.dur')
# ('b.marr', 'X_18')
# ('b.marr', 'mom.scoll')
# ('b.marr', 'X_13')
# ('b.marr', 'X_35')
# ('b.marr', 'X_0')
# ('b.marr', 'X_28')
# ('b.marr', 'X_24')
# ('b.marr', 'X_19')
# ('X_5', 'X_14')
# ('X_5', 'tex')
# ('X_5', 'work.dur')
# ('X_5', 'X_18')
# ('X_5', 'mom.scoll')
# ('X_5', 'X_13')
# ('X_5', 'X_35')
# ('X_5', 'X_0')
# ('X_5', 'X_28')
# ('X_5', 'X_24')
# ('X_5', 'X_19')
# ('X_14', 'tex')
# ('X_14', 'work.dur')
# ('X_14', 'X_18')
# ('X_14', 'mom.scoll')
# ('X_14', 'X_13')
# ('X_14', 'X_35')
# ('X_14', 'X_0')
# ('X_14', 'X_28')
# ('X_14', 'X_24')
# ('X_14', 'X_19')
# ('tex', 'work.dur')
# ('tex', 'X_18')
# ('tex', 'mom.scoll')
# ('tex', 'X_13')
# ('tex', 'X_35')
# ('tex', 'X_0')
# ('tex', 'X_28')
# ('tex', 'X_24')
# ('tex', 'X_19')
# ('work.dur', 'X_18')
# ('work.dur', 'mom.scoll')
# ('work.dur', 'X_13')
# ('work.dur', 'X_35')
# ('work.dur', 'X_0')
# ('work.dur', 'X_28')
# ('work.dur', 'X_24')
# ('work.dur', 'X_19')
# ('X_18', 'mom.scoll')
# ('X_18', 'X_13')
# ('X_18', 'X_35')
# ('X_18', 'X_0')
# ('X_18', 'X_28')
# ('X_18', 'X_24')
# ('X_18', 'X_19')
# ('mom.scoll', 'X_13')
# ('mom.scoll', 'X_35')
# ('mom.scoll', 'X_0')
# ('mom.scoll', 'X_28')
# ('mom.scoll', 'X_24')
# ('mom.scoll', 'X_19')
# ('X_13', 'X_35')
# ('X_13', 'X_0')
# ('X_13', 'X_28')
# ('X_13', 'X_24')
# ('X_13', 'X_19')
# ('X_35', 'X_0')
# ('X_35', 'X_28')
# ('X_35', 'X_24')
# ('X_35', 'X_19')
# ('X_0', 'X_28')
# ('X_0', 'X_24')
# ('X_0', 'X_19')
# ('X_28', 'X_24')
# ('X_28', 'X_19')
# ('X_24', 'X_19')
# ('X_9', 'har', 'X_8')
# ('X_9', 'har', 'b.marr')
# ('X_9', 'har', 'X_5')
# ('X_9', 'har', 'X_14')
# ('X_9', 'har', 'tex')
# ('X_9', 'har', 'work.dur')
# ('X_9', 'har', 'X_18')
# ('X_9', 'har', 'mom.scoll')
# ('X_9', 'har', 'X_13')
# ('X_9', 'har', 'X_35')
# ('X_9', 'har', 'X_0')
# ('X_9', 'har', 'X_28')
# ('X_9', 'har', 'X_24')
# ('X_9', 'har', 'X_19')
# ('X_9', 'X_8', 'b.marr')
# ('X_9', 'X_8', 'X_5')
# ('X_9', 'X_8', 'X_14')
# ('X_9', 'X_8', 'tex')
# ('X_9', 'X_8', 'work.dur')
# ('X_9', 'X_8', 'X_18')
# ('X_9', 'X_8', 'mom.scoll')
# ('X_9', 'X_8', 'X_13')
# ('X_9', 'X_8', 'X_35')
# ('X_9', 'X_8', 'X_0')
# ('X_9', 'X_8', 'X_28')
# ('X_9', 'X_8', 'X_24')
# ('X_9', 'X_8', 'X_19')
# ('X_9', 'b.marr', 'X_5')
# ('X_9', 'b.marr', 'X_14')
# ('X_9', 'b.marr', 'tex')
# ('X_9', 'b.marr', 'work.dur')
# ('X_9', 'b.marr', 'X_18')
# ('X_9', 'b.marr', 'mom.scoll')
# ('X_9', 'b.marr', 'X_13')
# ('X_9', 'b.marr', 'X_35')
# ('X_9', 'b.marr', 'X_0')
# ('X_9', 'b.marr', 'X_28')
# ('X_9', 'b.marr', 'X_24')
# ('X_9', 'b.marr', 'X_19')
# ('X_9', 'X_5', 'X_14')
# ('X_9', 'X_5', 'tex')
# ('X_9', 'X_5', 'work.dur')
# ('X_9', 'X_5', 'X_18')
# mom.scoll
# ('X_9',)
# ('har',)
# ('X_8',)
# ('b.marr',)
# ('X_5',)
# ('X_14',)
# ('tex',)
# ('work.dur',)
# ('X_18',)
# ('X_13',)
# ('X_35',)
# ('X_0',)
# ('X_28',)
# ('X_24',)
# ('X_19',)
# ('X_9', 'har')
# ('X_9', 'X_8')
# ('X_9', 'b.marr')
# ('X_9', 'X_5')
# ('X_9', 'X_14')
# ('X_9', 'tex')
# ('X_9', 'work.dur')
# ('X_9', 'X_18')
# ('X_9', 'X_13')
# ('X_9', 'X_35')
# ('X_9', 'X_0')
# ('X_9', 'X_28')
# ('X_9', 'X_24')
# ('X_9', 'X_19')
# ('har', 'X_8')
# ('har', 'b.marr')
# ('har', 'X_5')
# ('har', 'X_14')
# ('har', 'tex')
# ('har', 'work.dur')
# ('har', 'X_18')
# ('har', 'X_13')
# ('har', 'X_35')
# ('har', 'X_0')
# ('har', 'X_28')
# ('har', 'X_24')
# ('har', 'X_19')
# ('X_8', 'b.marr')
# ('X_8', 'X_5')
# ('X_8', 'X_14')
# ('X_8', 'tex')
# ('X_8', 'work.dur')
# ('X_8', 'X_18')
# ('X_8', 'X_13')
# ('X_8', 'X_35')
# ('X_8', 'X_0')
# ('X_8', 'X_28')
# ('X_8', 'X_24')
# ('X_8', 'X_19')
# ('b.marr', 'X_5')
# ('b.marr', 'X_14')
# ('b.marr', 'tex')
# ('b.marr', 'work.dur')
# ('b.marr', 'X_18')
# ('b.marr', 'X_13')
# ('b.marr', 'X_35')
# ('b.marr', 'X_0')
# ('b.marr', 'X_28')
# ('b.marr', 'X_24')
# ('b.marr', 'X_19')
# ('X_5', 'X_14')
# ('X_5', 'tex')
# ('X_5', 'work.dur')
# ('X_5', 'X_18')
# ('X_5', 'X_13')
# ('X_5', 'X_35')
# ('X_5', 'X_0')
# ('X_5', 'X_28')
# ('X_5', 'X_24')
# ('X_5', 'X_19')
# ('X_14', 'tex')
# ('X_14', 'work.dur')
# ('X_14', 'X_18')
# ('X_14', 'X_13')
# ('X_14', 'X_35')
# ('X_14', 'X_0')
# ('X_14', 'X_28')
# ('X_14', 'X_24')
# ('X_14', 'X_19')
# ('tex', 'work.dur')
# ('tex', 'X_18')
# ('tex', 'X_13')
# ('tex', 'X_35')
# ('tex', 'X_0')
# ('tex', 'X_28')
# ('tex', 'X_24')
# ('tex', 'X_19')
# ('work.dur', 'X_18')
# ('work.dur', 'X_13')
# ('work.dur', 'X_35')
# ('work.dur', 'X_0')
# ('work.dur', 'X_28')
# ('work.dur', 'X_24')
# ('work.dur', 'X_19')
# ('X_18', 'X_13')
# ('X_18', 'X_35')
# ('X_18', 'X_0')
# ('X_18', 'X_28')
# ('X_18', 'X_24')
# ('X_18', 'X_19')
# ('X_13', 'X_35')
# ('X_13', 'X_0')
# ('X_13', 'X_28')
# ('X_13', 'X_24')
# ('X_13', 'X_19')
# ('X_35', 'X_0')
# ('X_35', 'X_28')
# ('X_35', 'X_24')
# ('X_35', 'X_19')
# ('X_0', 'X_28')
# ('X_0', 'X_24')
# ('X_0', 'X_19')
# ('X_28', 'X_24')
# ('X_28', 'X_19')
# ('X_24', 'X_19')
# ('X_9', 'har', 'X_8')
# ('X_9', 'har', 'b.marr')
# ('X_9', 'har', 'X_5')
# ('X_9', 'har', 'X_14')
# ('X_9', 'har', 'tex')
# ('X_9', 'har', 'work.dur')
# ('X_9', 'har', 'X_18')
# ('X_9', 'har', 'X_13')
# ('X_9', 'har', 'X_35')
# ('X_9', 'har', 'X_0')
# ('X_9', 'har', 'X_28')
# ('X_9', 'har', 'X_24')
# ('X_9', 'har', 'X_19')
# ('X_9', 'X_8', 'b.marr')
# ('X_9', 'X_8', 'X_5')
# ('X_9', 'X_8', 'X_14')
# ('X_9', 'X_8', 'tex')
# ('X_9', 'X_8', 'work.dur')
# ('X_9', 'X_8', 'X_18')
# ('X_9', 'X_8', 'X_13')
# ('X_9', 'X_8', 'X_35')
# ('X_9', 'X_8', 'X_0')
# ('X_9', 'X_8', 'X_28')
# ('X_9', 'X_8', 'X_24')
# ('X_9', 'X_8', 'X_19')
# ('X_9', 'b.marr', 'X_5')
# ('X_9', 'b.marr', 'X_14')
# ('X_9', 'b.marr', 'tex')
# ('X_9', 'b.marr', 'work.dur')
# ('X_9', 'b.marr', 'X_18')
# ('X_9', 'b.marr', 'X_13')
# ('X_9', 'b.marr', 'X_35')
# ('X_9', 'b.marr', 'X_0')
# ('X_9', 'b.marr', 'X_28')
# ('X_9', 'b.marr', 'X_24')
# ('X_9', 'b.marr', 'X_19')
# ('X_9', 'X_5', 'X_14')
# ('X_9', 'X_5', 'tex')
# b.marr
# ('X_9',)
# ('har',)
# ('X_8',)
# ('X_35',)
# ('X_0',)
# ('X_5',)
# ('X_14',)
# ('X_28',)
# ('X_24',)
# ('tex',)
# ('X_19',)
# ('work.dur',)
# ('X_18',)
# ('X_13',)
# ('X_9', 'har')
# ('X_9', 'X_8')
# ('X_9', 'X_35')
# ('X_9', 'X_0')
# ('X_9', 'X_5')
# ('X_9', 'X_14')
# ('X_9', 'X_28')
# ('X_9', 'X_24')
# ('X_9', 'tex')
# ('X_9', 'X_19')
# ('X_9', 'work.dur')
# ('X_9', 'X_18')
# ('X_9', 'X_13')
# ('har', 'X_8')
# ('har', 'X_35')
# ('har', 'X_0')
# ('har', 'X_5')
# ('har', 'X_14')
# ('har', 'X_28')
# ('har', 'X_24')
# ('har', 'tex')
# ('har', 'X_19')
# ('har', 'work.dur')
# ('har', 'X_18')
# ('har', 'X_13')
# ('X_8', 'X_35')
# ('X_8', 'X_0')
# ('X_8', 'X_5')
# ('X_8', 'X_14')
# ('X_8', 'X_28')
# ('X_8', 'X_24')
# ('X_8', 'tex')
# ('X_8', 'X_19')
# ('X_8', 'work.dur')
# ('X_8', 'X_18')
# ('X_8', 'X_13')
# ('X_35', 'X_0')
# ('X_35', 'X_5')
# ('X_35', 'X_14')
# ('X_35', 'X_28')
# ('X_35', 'X_24')
# ('X_35', 'tex')
# ('X_35', 'X_19')
# ('X_35', 'work.dur')
# ('X_35', 'X_18')
# ('X_35', 'X_13')
# ('X_0', 'X_5')
# ('X_0', 'X_14')
# ('X_0', 'X_28')
# ('X_0', 'X_24')
# ('X_0', 'tex')
# ('X_0', 'X_19')
# ('X_0', 'work.dur')
# ('X_0', 'X_18')
# ('X_0', 'X_13')
# ('X_5', 'X_14')
# ('X_5', 'X_28')
# ('X_5', 'X_24')
# ('X_5', 'tex')
# ('X_5', 'X_19')
# ('X_5', 'work.dur')
# ('X_5', 'X_18')
# ('X_5', 'X_13')
# ('X_14', 'X_28')
# ('X_14', 'X_24')
# ('X_14', 'tex')
# ('X_14', 'X_19')
# ('X_14', 'work.dur')
# ('X_14', 'X_18')
# ('X_14', 'X_13')
# ('X_28', 'X_24')
# ('X_28', 'tex')
# ('X_28', 'X_19')
# ('X_28', 'work.dur')
# ('X_28', 'X_18')
# ('X_28', 'X_13')
# ('X_24', 'tex')
# ('X_24', 'X_19')
# ('X_24', 'work.dur')
# ('X_24', 'X_18')
# ('X_24', 'X_13')
# ('tex', 'X_19')
# ('tex', 'work.dur')
# ('tex', 'X_18')
# ('tex', 'X_13')
# ('X_19', 'work.dur')
# ('X_19', 'X_18')
# ('X_19', 'X_13')
# ('work.dur', 'X_18')
# ('work.dur', 'X_13')
# ('X_18', 'X_13')
# ('X_9', 'har', 'X_8')
# ('X_9', 'har', 'X_35')
# ('X_9', 'har', 'X_0')
# ('X_9', 'har', 'X_5')
# ('X_9', 'har', 'X_14')
# ('X_9', 'har', 'X_28')
# ('X_9', 'har', 'X_24')
# ('X_9', 'har', 'tex')
# ('X_9', 'har', 'X_19')
# ('X_9', 'har', 'work.dur')
# ('X_9', 'har', 'X_18')
# ('X_9', 'har', 'X_13')
# ('X_9', 'X_8', 'X_35')
# ('X_9', 'X_8', 'X_0')
# ('X_9', 'X_8', 'X_5')
# ('X_9', 'X_8', 'X_14')
# work.dur
# ('X_9',)
# ('har',)
# ('X_8',)
# ('X_35',)
# ('X_0',)
# ('X_5',)
# ('X_14',)
# ('X_28',)
# ('X_24',)
# ('tex',)
# ('X_19',)
# ('X_18',)
# ('X_13',)
# ('X_9', 'har')
# ('X_9', 'X_8')
# ('X_9', 'X_35')
# ('X_9', 'X_0')
# ('X_9', 'X_5')
# ('X_9', 'X_14')
# ('X_9', 'X_28')
# ('X_9', 'X_24')
# ('X_9', 'tex')
# ('X_9', 'X_19')
# ('X_9', 'X_18')
# ('X_9', 'X_13')
# ('har', 'X_8')
# ('har', 'X_35')
# ('har', 'X_0')
# ('har', 'X_5')
# ('har', 'X_14')
# ('har', 'X_28')
# ('har', 'X_24')
# ('har', 'tex')
# ('har', 'X_19')
# ('har', 'X_18')
# ('har', 'X_13')
# ('X_8', 'X_35')
# ('X_8', 'X_0')
# ('X_8', 'X_5')
# ('X_8', 'X_14')
# ('X_8', 'X_28')
# ('X_8', 'X_24')
# ('X_8', 'tex')
# ('X_8', 'X_19')
# ('X_8', 'X_18')
# ('X_8', 'X_13')
# ('X_35', 'X_0')
# ('X_35', 'X_5')
# ('X_35', 'X_14')
# ('X_35', 'X_28')
# ('X_35', 'X_24')
# ('X_35', 'tex')
# ('X_35', 'X_19')
# ('X_35', 'X_18')
# ('X_35', 'X_13')
# ('X_0', 'X_5')
# ('X_0', 'X_14')
# ('X_0', 'X_28')
# ('X_0', 'X_24')
# ('X_0', 'tex')
# ('X_0', 'X_19')
# ('X_0', 'X_18')
# ('X_0', 'X_13')
# ('X_5', 'X_14')
# ('X_5', 'X_28')
# ('X_5', 'X_24')
# ('X_5', 'tex')
# ('X_5', 'X_19')
# ('X_5', 'X_18')
# ('X_5', 'X_13')
# ('X_14', 'X_28')
# ('X_14', 'X_24')
# ('X_14', 'tex')
# ('X_14', 'X_19')
# ('X_14', 'X_18')
# X_0
# ('X_9',)
# ('har',)
# ('X_8',)
# ('X_35',)
# ('X_5',)
# ('X_14',)
# ('X_28',)
# ('X_24',)
# ('tex',)
# ('X_19',)
# ('X_18',)
# ('X_13',)
# ('X_9', 'har')
# ('X_9', 'X_8')
# ('X_9', 'X_35')
# ('X_9', 'X_5')
# ('X_9', 'X_14')
# ('X_9', 'X_28')
# ('X_9', 'X_24')
# ('X_9', 'tex')
# ('X_9', 'X_19')
# ('X_9', 'X_18')
# ('X_9', 'X_13')
# ('har', 'X_8')
# ('har', 'X_35')
# ('har', 'X_5')
# ('har', 'X_14')
# ('har', 'X_28')
# ('har', 'X_24')
# ('har', 'tex')
# ('har', 'X_19')
# ('har', 'X_18')
# ('har', 'X_13')
# ('X_8', 'X_35')
# ('X_8', 'X_5')
# ('X_8', 'X_14')
# ('X_8', 'X_28')
# ('X_8', 'X_24')
# ('X_8', 'tex')
# ('X_8', 'X_19')
# ('X_8', 'X_18')
# ('X_8', 'X_13')
# ('X_35', 'X_5')
# ('X_35', 'X_14')
# ('X_35', 'X_28')
# ('X_35', 'X_24')
# ('X_35', 'tex')
# ('X_35', 'X_19')
# ('X_35', 'X_18')
# ('X_35', 'X_13')
# ('X_5', 'X_14')
# ('X_5', 'X_28')
# ('X_5', 'X_24')
# ('X_5', 'tex')
# ('X_5', 'X_19')
# ('X_5', 'X_18')
# ('X_5', 'X_13')
# ('X_14', 'X_28')
# ('X_14', 'X_24')
# ('X_14', 'tex')
# ('X_14', 'X_19')
# ('X_14', 'X_18')
# ('X_14', 'X_13')
# ('X_28', 'X_24')
# ('X_28', 'tex')
# ('X_28', 'X_19')
# ('X_28', 'X_18')
# ('X_28', 'X_13')
# ('X_24', 'tex')
# ('X_24', 'X_19')
# ('X_24', 'X_18')
# ('X_24', 'X_13')
# ('tex', 'X_19')
# ('tex', 'X_18')
# ('tex', 'X_13')
# ('X_19', 'X_18')
# ('X_19', 'X_13')
# ('X_18', 'X_13')
# ('X_9', 'har', 'X_8')
# ('X_9', 'har', 'X_35')
# ('X_9', 'har', 'X_5')
# ('X_9', 'har', 'X_14')
# ('X_9', 'har', 'X_28')
# ('X_9', 'har', 'X_24')
# ('X_9', 'har', 'tex')
# ('X_9', 'har', 'X_19')
# ('X_9', 'har', 'X_18')
# ('X_9', 'har', 'X_13')
# ('X_9', 'X_8', 'X_35')
# ('X_9', 'X_8', 'X_5')
# ('X_9', 'X_8', 'X_14')
# ('X_9', 'X_8', 'X_28')
# ('X_9', 'X_8', 'X_24')
# ('X_9', 'X_8', 'tex')
# ('X_9', 'X_8', 'X_19')
# ('X_9', 'X_8', 'X_18')
# ('X_9', 'X_8', 'X_13')
# ('X_9', 'X_35', 'X_5')
# ('X_9', 'X_35', 'X_14')
# ('X_9', 'X_35', 'X_28')
# ('X_9', 'X_35', 'X_24')
# ('X_9', 'X_35', 'tex')
# ('X_9', 'X_35', 'X_19')
# ('X_9', 'X_35', 'X_18')
# ('X_9', 'X_35', 'X_13')
# ('X_9', 'X_5', 'X_14')
# ('X_9', 'X_5', 'X_28')
# ('X_9', 'X_5', 'X_24')
# ('X_9', 'X_5', 'tex')
# ('X_9', 'X_5', 'X_19')
# ('X_9', 'X_5', 'X_18')
# X_8
# ('X_9',)
# ('har',)
# ('X_35',)
# ('X_5',)
# ('X_14',)
# ('X_28',)
# ('X_24',)
# ('tex',)
# ('X_19',)
# ('X_18',)
# ('X_13',)
# ('X_9', 'har')
# ('X_9', 'X_35')
# ('X_9', 'X_5')
# ('X_9', 'X_14')
# ('X_9', 'X_28')
# ('X_9', 'X_24')
# ('X_9', 'tex')
# ('X_9', 'X_19')
# ('X_9', 'X_18')
# ('X_9', 'X_13')
# ('har', 'X_35')
# ('har', 'X_5')
# X_19
# ('X_9',)
# ('har',)
# ('X_35',)
# ('X_5',)
# ('X_14',)
# ('X_28',)
# ('X_24',)
# ('tex',)
# ('X_18',)
# ('X_13',)
# ('X_9', 'har')
# ('X_9', 'X_35')
# ('X_9', 'X_5')
# ('X_9', 'X_14')
# ('X_9', 'X_28')
# ('X_9', 'X_24')
# ('X_9', 'tex')
# ('X_9', 'X_18')
# ('X_9', 'X_13')
# ('har', 'X_35')
# ('har', 'X_5')
# ('har', 'X_14')
