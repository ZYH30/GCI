# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Dec 22 10:51:46 2023

@author: yhzha
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score,roc_auc_score,average_precision_score
from itertools import combinations
from utilPlus import gcm_test,anm_test
import os
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

import datetime
import pytz

def causalDirect(p_value_foward,p_value_backward,v1,v2,alpha = 0.05):
    result = False
    if p_value_foward >= p_value_backward:
        if p_value_foward >= alpha:
            if p_value_backward < alpha:
                print("Identifiable: \n \
                      {} is cause and P-value is {}, \n \
                      {} is effect and P-value is {}.".format(v1,round(p_value_foward,2),v2,round(p_value_backward,2)))
                result = True
            else:
                print("Unidentifiable: \n \
                      ALL direction's P-value large than {}. \n \
                      The direction mabey that {} cause {}.".format(alpha, v1, v2))
        else:
            print("Unidentifiable: \n \
                  ALL direction's P-value small than {}. \n \
                  The direction mabey that {} cause {}.".format(alpha, v1, v2))
    else:
        if p_value_backward >= alpha:
            if p_value_foward < alpha:
                print("Identifiable: \n \
                      {} is cause and P-value is {}, \n \
                      {} is effect and P-value is {}.".format(v2,round(p_value_backward,2),v1,round(p_value_foward,2)))
                result = True
            else:
                print("Unidentifiable: \n \
                      ALL direction's P-value large than {}. \n \
                      The direction mabey that {} cause {}.".format(alpha,v2,v1))
        else:
            print("Unidentifiable: \n \
                  ALL direction's P-value small than {}. \n \
                  The direction mabey that {} cause {}.".format(alpha, v2,v1))
    return result
        
def P_Identify(dataFrame,searchV,aimV,searchVType,corMat,corTheta = 0.05,CITheta = 0.05,directTheta = 0.1,is_str = True,exclSet = []):
    """
    Parameters
    ----------
    dataFrame : dataFrame
        DESCRIPTION.
    searchV : list
        DESCRIPTION.
    aimV : TYPE
        DESCRIPTION.
    aimVType : TYPE
        DESCRIPTION.
    corMat : DataFrame
        DESCRIPTION.
    corTheta : TYPE, optional
        DESCRIPTION. The default is 0.2.
    CITheta : TYPE, optional
        DESCRIPTION. The default is 0.05.
    directTheta : TYPE, optional
        DESCRIPTION. The default is 0.05.
    is_str : TYPE, Bool
        DESCRIPTION. Whether strict judgement. 
        False means judging only according to the size of the P value in different directions; 
        True means judging the parent-child relationship strictly according to the threshold;

    Returns
    -------
    None.

    """
    aimVType = searchVType[aimV]
    if len(searchV) == len(corMat):
        print("Start Identify!")
        print("Aim Variable:",aimV)
    else:
        print("corMat is not consistency with searchV")
        return
    
    if corTheta == 'count':
        corA = [np.abs(corMat[aimV].iloc[i]) for i in range(len(corMat[aimV]))]
        nLen = len(corA)
        if aimV == 'ajcc_pathologic_stage':
            countNum = 50
            per_ = (1 - round(countNum / nLen, 2)) * 100
            corTheta = np.percentile(corA, per_)
        else:
            countNum = 12
            per_ = (1 - round(countNum / nLen, 2)) * 100
            corTheta = np.percentile(corA, per_)
            corTheta = max(corTheta, 0.35)

        AdjIndex = (corMat[aimV] >= corTheta) | (corMat[aimV] <= -corTheta)
    else:
        AdjIndex = (corMat[aimV] >= corTheta) | (corMat[aimV] <= -corTheta)
    if aimV == 'ajcc_pathologic_stage':
        CITheta = 0.3
        directTheta = 0.2

    Adj = set([searchV[i] for i in range(len(searchV)) if AdjIndex.iloc[i]])
    Adj = Adj - set([aimV])
    Adj = Adj - set(exclSet)
    print('exclSet:',exclSet)
    print('Init Adj:',Adj)
    print('Init Adj Length:',len(Adj))
    
    
    AdjDict = {}
    for x_a in Adj:
        AdjDict[x_a] = corMat.loc[x_a,aimV]
    
    sortedAdjDict = sorted(AdjDict.items(), key=lambda x: x[1])

    NoAdj = [] 
    for x_c in sortedAdjDict:
        
        x_ = x_c[0]
        print(x_)
        size = 1
        CAdj = Adj - set([x_])
        if len(CAdj) >= size:
            test = True
        else:
            test = False
            print("No much variable to CI test!")
        while test:
            for CAdj_ in combinations(CAdj,size):
                print(CAdj_)
                test_statistic,P_ = gcm_test(X = dataFrame[[aimV]].values.ravel(), 
                                             Y = dataFrame[[x_]].values.ravel(), 
                                             Z = dataFrame[list(CAdj_)], 
                                             X_type = aimVType, 
                                             Y_type = searchVType[x_],
                                             is_hypyopt = True)
                
                # 
                if P_ > CITheta:
                    print("P Value: ", P_)
                    NoAdj.append(x_)
                    Adj = CAdj
                    test = False
                    break
            size = size + 1
            if size > 3:
                test = False
            if len(CAdj) < size:
                test = False
    print("Train Adj:",Adj)
    parSet = []
    chiSet = []
    for pc_ in Adj:     
        P_foward_, P_back_ = anm_test(X = dataFrame[[aimV]].values.ravel(), 
                                      Y = dataFrame[[pc_]].values.ravel(), 
                                      X_type = aimVType, 
                                      Y_type = searchVType[pc_],
                                      is_hypyopt = True)
        
        causalDirect(P_foward_, P_back_,aimV, pc_)
        if is_str:
            if (P_foward_ > directTheta) & (P_back_ <= directTheta):
                print('find')
                print(P_foward_,P_back_)
                chiSet.append(pc_)
            elif (P_foward_ <= directTheta) & (P_back_ > directTheta):
                print('find')
                print(P_foward_,P_back_)
                parSet.append(pc_)
            elif P_foward_ <= P_back_:
                parSet.append(pc_)
            elif abs(P_foward_ - P_back_) <= round(directTheta / 5, 2):
                parSet.append(pc_)
            else:
                chiSet.append(pc_)
        else:
            if P_back_ >= directTheta:
                parSet.append(pc_)
            elif P_foward_ >= directTheta:
                chiSet.append(pc_)
            else:
                parSet.append(pc_)

    print("parSet:",parSet)
    print("chiSet:",chiSet)
                
    return parSet,chiSet,NoAdj,Adj


def A_Identify(dataFrame,searchV,aimV,searchVType,corMat,corTheta = 0.05,CITheta = 0.05,directTheta = 0.1,is_str = True):
    search = True
    toIdeSet = [aimV]
    Ancestors = {}
    exclSet = []
    
    while search:
        toIdeSet_ = []
        exclSet_ = []
        for IdeV in toIdeSet:
            
            P_IdeV,C_IdeV,NA_IdeV,A_IdeV = P_Identify(dataFrame,searchV,IdeV,searchVType,corMat,corTheta,CITheta,directTheta,is_str,exclSet)
            toIdeSet_.extend(P_IdeV)
            exclSet_.extend(C_IdeV)
            Ancestors[IdeV] = P_IdeV
        if len(toIdeSet_) == 0:
            search = False
        else:
            exclSet.extend(toIdeSet)
            exclSet.extend(exclSet_)
            toIdeSet = [item for item in toIdeSet_ if item not in exclSet]
            toIdeSet = list(set(toIdeSet))
            
    return Ancestors

dataFile = '../dataset/LUAD.csv'

dataFrame = pd.read_csv(dataFile)
NoUseV = ['case_submitter_id', 'project_id', 'age_at_index', 'gender', 'race']
dataFrame = dataFrame.drop(columns = NoUseV)

dataFrame.columns

aimV = 'ajcc_pathologic_stage'
useCol = list(dataFrame.columns)
dataFrame = dataFrame.loc[(dataFrame[aimV] == 1) |  (dataFrame[aimV] == 3),:]
# 'discrete' 'continuous'
useColType = {}
for col_ in useCol:
    useColType[col_] = 'continuous'

useColType[aimV] = 'discrete'

continuousV = [key for key, value in useColType.items() if value == 'continuous']

scaler = MinMaxScaler()
dataFrame.loc[:,continuousV] = scaler.fit_transform(dataFrame.loc[:,continuousV])


corMat = dataFrame.corr(method='spearman')
corPercDesc = corMat[aimV].describe(percentiles = [.1, .5, .9, .95])
corTheta = corPercDesc.loc['95%']
corTheta = 'count'

Start_time = datetime.datetime.now(pytz.timezone('Asia/Shanghai'))
print("Start_time:", Start_time)
 

# Gene Data
Ancestors = A_Identify(dataFrame = dataFrame,searchV = useCol,aimV = aimV,
                       searchVType = useColType, corMat = corMat, 
                       corTheta = corTheta,CITheta = 0.08,directTheta = 0.05) #time out: dec CITheta

print('Ancestors:',Ancestors)

End_time = datetime.datetime.now(pytz.timezone('Asia/Shanghai'))
print("End_time:", End_time)
 
time_difference = End_time - Start_time
print("time_difference:", time_difference)
# Out:
# Start_time: 2024-06-02 10:54:02.955172+08:00
# Start Identify!
# Aim Variable: ajcc_pathologic_stage
# exclSet: []
# Init Adj: {'PLK1', 'FAM83A-AS1', 'TLL2', 'LINC00460', 'GJB3', 'ANLN', 'KIF20A', 'RHOV', 'LIPK', 'FOXM1', 'PIMREG', 'IGHJ1', 'RRM2', 'B3GNT3', 'CCNB1', 'AP000553.7', 'TMPRSS11E', 'HMMR', 'AC005077.4', 'AURKB', 'SKA3', 'IGKJ4', 'CEP55', 'GALNT14', 'KLK6', 'CDK5R2', 'PKMYT1', 'FP565171.1', 'CYP24A1', 'CDCA3', 'PITX1', 'FAM83A', 'IGKV3D-15', 'AC106045.1', 'TPX2', 'CCNB2', 'AC068228.1', 'UHRF1', 'CDC25C', 'SKA1', 'AC112777.1', 'KRT6A', 'CDC20', 'IGKJ3'}
# Init Adj Length: 44
# IGHJ1
# ('PLK1',)
# ('FAM83A-AS1',)
# ('TLL2',)
# ('LINC00460',)
# ('GJB3',)
# ('ANLN',)
# ('KIF20A',)
# ('RHOV',)
# ('LIPK',)
# ('FOXM1',)
# ('PIMREG',)
# ('RRM2',)
# ('B3GNT3',)
# ('CCNB1',)
# ('AP000553.7',)
# ('TMPRSS11E',)
# ('HMMR',)
# ('AC005077.4',)
# ('AURKB',)
# ('SKA3',)
# ('IGKJ4',)
# ('CEP55',)
# ('GALNT14',)
# ('KLK6',)
# ('CDK5R2',)
# ('PKMYT1',)
# ('FP565171.1',)
# ('CYP24A1',)
# ('CDCA3',)
# ('PITX1',)
# ('FAM83A',)
# ('IGKV3D-15',)
# ('AC106045.1',)
# ('TPX2',)
# ('CCNB2',)
# ('AC068228.1',)
# ('PLK1', 'TLL2')
# ('PLK1', 'LINC00460')
# ('PLK1', 'GJB3')
# ('PLK1', 'ANLN')
# ('PLK1', 'KIF20A')
# ('PLK1', 'RHOV')
# ('PLK1', 'LIPK')
# ('PLK1', 'FOXM1')
# ('PLK1', 'PIMREG')
# ('PLK1', 'RRM2')
# ('PLK1', 'B3GNT3')
# ('PLK1', 'TMPRSS11E')
# ('PLK1', 'HMMR')
# ('PLK1', 'AC005077.4')
# ('PLK1', 'AURKB')
# ('PLK1', 'SKA3')
# ('PLK1', 'CEP55')
# ('PLK1', 'GALNT14')
# ('PLK1', 'KLK6')
# ('PLK1', 'CDK5R2')
# ('PLK1', 'PKMYT1')
# ('PLK1', 'FP565171.1')
# ('PLK1', 'CYP24A1')
# ('PLK1', 'CDCA3')
# ('PLK1', 'PITX1')
# ('PLK1', 'FAM83A')
# ('PLK1', 'IGKV3D-15')
# ('PLK1', 'AC106045.1')
# ('PLK1', 'TPX2')
# ('PLK1', 'CCNB2')
# ('PLK1', 'AC068228.1')
# ('PLK1', 'UHRF1')
# ('PLK1', 'CDC25C')
# ('PLK1', 'SKA1')
# ('PLK1', 'AC112777.1')
# ('PLK1', 'KRT6A')
# ('PLK1', 'CDC20')
# ('PLK1', 'CCNB1')
# ('FAM83A-AS1', 'TLL2')
# ('FAM83A-AS1', 'LINC00460')
# ('FAM83A-AS1', 'GJB3')
# ('FAM83A-AS1', 'ANLN')
# ('FAM83A-AS1', 'KIF20A')
# ('FAM83A-AS1', 'RHOV')
# ('FAM83A-AS1', 'LIPK')
# ('FAM83A-AS1', 'FOXM1')
# ('FAM83A-AS1', 'PIMREG')
# ('FAM83A-AS1', 'RRM2')
# ('FAM83A-AS1', 'B3GNT3')
# ('FAM83A-AS1', 'TMPRSS11E')
# ('FAM83A-AS1', 'HMMR')
# ('FAM83A-AS1', 'AC005077.4')
# ('FAM83A-AS1', 'AURKB')
# ('FAM83A-AS1', 'SKA3')
# ('FAM83A-AS1', 'CEP55')
# ('FAM83A-AS1', 'GALNT14')
# ('FAM83A-AS1', 'KLK6')
# ('FAM83A-AS1', 'CDK5R2')
# ('FAM83A-AS1', 'PKMYT1')
# ('FAM83A-AS1', 'FP565171.1')
# ('FAM83A-AS1', 'CYP24A1')
# ('FAM83A-AS1', 'CDCA3')
# ('FAM83A-AS1', 'PITX1')
# ('FAM83A-AS1', 'FAM83A')
# ('FAM83A-AS1', 'IGKV3D-15')
# ('FAM83A-AS1', 'AC106045.1')
# ('FAM83A-AS1', 'TPX2')
# ('FAM83A-AS1', 'CCNB2')
# ('FAM83A-AS1', 'AC068228.1')
# ('FAM83A-AS1', 'UHRF1')
# ('FAM83A-AS1', 'CDC25C')
# ('FAM83A-AS1', 'SKA1')
# ('FAM83A-AS1', 'AC112777.1')
# ('FAM83A-AS1', 'KRT6A')
# ('FAM83A-AS1', 'CDC20')
# ('FAM83A-AS1', 'CCNB1')
# ('TLL2', 'LINC00460')
# ('TLL2', 'GJB3')
# ('TLL2', 'ANLN')
# ('TLL2', 'KIF20A')
# ('TLL2', 'RHOV')
# ('TLL2', 'LIPK')
# ('TLL2', 'FOXM1')
# ('TLL2', 'PIMREG')
# ('TLL2', 'RRM2')
# ('TLL2', 'B3GNT3')
# ('TLL2', 'TMPRSS11E')
# ('TLL2', 'HMMR')
# ('TLL2', 'AC005077.4')
# ('TLL2', 'AURKB')
# ('TLL2', 'SKA3')
# ('TLL2', 'CEP55')
# ('TLL2', 'GALNT14')
# ('TLL2', 'KLK6')
# ('TLL2', 'CDK5R2')
# P Value:  0.32294925558704635
# IGKV3D-15
# ('PLK1',)
# ('FAM83A-AS1',)
# ('TLL2',)
# ('LINC00460',)
# ('GJB3',)
# ('ANLN',)
# ('KIF20A',)
# ('RHOV',)
# ('LIPK',)
# ('FOXM1',)
# ('PIMREG',)
# ('RRM2',)
# ('B3GNT3',)
# ('TMPRSS11E',)
# ('HMMR',)
# ('AC005077.4',)
# ('AURKB',)
# ('SKA3',)
# ('CEP55',)
# ('GALNT14',)
# ('KLK6',)
# ('CDK5R2',)
# ('PKMYT1',)
# ('FP565171.1',)
# ('CYP24A1',)
# ('CDCA3',)
# ('PITX1',)
# ('FAM83A',)
# ('AC106045.1',)
# ('TPX2',)
# ('CCNB2',)
# ('AC068228.1',)
# ('UHRF1',)
# ('CDC25C',)
# ('SKA1',)
# ('AC112777.1',)
# ('KRT6A',)
# ('CDC20',)
# ('CCNB1',)
# ('PLK1', 'FAM83A-AS1')
# ('PLK1', 'TLL2')
# ('PLK1', 'LINC00460')
# ('PLK1', 'GJB3')
# ('PLK1', 'ANLN')
# ('PLK1', 'KIF20A')
# ('PLK1', 'RHOV')
# ('PLK1', 'LIPK')
# ('PLK1', 'FOXM1')
# ('PLK1', 'PIMREG')
# ('PLK1', 'RRM2')
# ('PLK1', 'B3GNT3')
# ('PLK1', 'TMPRSS11E')
# ('PLK1', 'HMMR')
# ('PLK1', 'AC005077.4')
# ('PLK1', 'AURKB')
# ('PLK1', 'SKA3')
# ('PLK1', 'CEP55')
# ('PLK1', 'GALNT14')
# ('PLK1', 'KLK6')
# ('PLK1', 'CDK5R2')
# ('PLK1', 'PKMYT1')
# ('PLK1', 'FP565171.1')
# ('PLK1', 'CYP24A1')
# ('PLK1', 'CDCA3')
# ('PLK1', 'PITX1')
# ('PLK1', 'FAM83A')
# ('PLK1', 'AC106045.1')
# ('PLK1', 'TPX2')
# ('PLK1', 'CCNB2')
# ('PLK1', 'AC068228.1')
# ('PLK1', 'UHRF1')
# ('PLK1', 'CDC25C')
# ('PLK1', 'SKA1')
# ('PLK1', 'AC112777.1')
# ('PLK1', 'KRT6A')
# ('PLK1', 'CDC20')
# ('PLK1', 'CCNB1')
# ('FAM83A-AS1', 'TLL2')
# ('FAM83A-AS1', 'LINC00460')
# ('FAM83A-AS1', 'GJB3')
# ('FAM83A-AS1', 'ANLN')
# ('FAM83A-AS1', 'KIF20A')
# ('FAM83A-AS1', 'RHOV')
# ('FAM83A-AS1', 'LIPK')
# ('FAM83A-AS1', 'FOXM1')
# ('CDK5R2',)
# ('FAM83A',)
# ('PITX1', 'RHOV')
# ('PITX1', 'CDK5R2')
# ('PITX1', 'FAM83A')
# P Value:  0.6465823100103405
# RHOV
# ('CDK5R2',)
# ('PITX1',)
# ('FAM83A',)
# ('CDK5R2', 'PITX1')
# ('CDK5R2', 'FAM83A')
# ('PITX1', 'FAM83A')
# ('CDK5R2', 'PITX1', 'FAM83A')
# PITX1
# ('RHOV',)
# ('CDK5R2',)
# ('FAM83A',)
# ('RHOV', 'CDK5R2')
# ('RHOV', 'FAM83A')
# ('CDK5R2', 'FAM83A')
# ('RHOV', 'CDK5R2', 'FAM83A')
# CDK5R2
# ('RHOV',)
# P Value:  0.9865227448015988
# FAM83A
# ('RHOV',)
# ('PITX1',)
# ('RHOV', 'PITX1')
# P Value:  0.5514961522151528
# Train Adj: {'RHOV', 'PITX1'}
# t_statistic_X: -0.3097506793970391
# corr_Y: -0.24319523522150893
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that RHOV cause ajcc_pathologic_stage.
# t_statistic_X: -0.24833014372844495
# corr_Y: -0.17008883992494023
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that PITX1 cause ajcc_pathologic_stage.
# parSet: ['RHOV', 'PITX1']
# chiSet: []
# Start Identify!
# Aim Variable: RHOV
# exclSet: ['ajcc_pathologic_stage']
# Init Adj: {'FAM83A-AS1', 'KRT16', 'GJB3', 'TFAP2A', 'KRT6B', 'EPN3', 'TNS4', 'SLC2A1', 'KRT6A', 'CBLC', 'AC005077.4', 'B3GNT3', 'LYPD3', 'FAM83A'}
# Init Adj Length: 14
# EPN3
# ('FAM83A-AS1',)
# ('KRT16',)
# ('GJB3',)
# ('TFAP2A',)
# ('KRT6B',)
# ('TNS4',)
# ('SLC2A1',)
# ('KRT6A',)
# ('CBLC',)
# ('AC005077.4',)
# P Value:  0.12219195951035973
# TNS4
# ('FAM83A-AS1',)
# ('KRT16',)
# ('FAM83A',)
# ('GJB3',)
# ('TFAP2A',)
# ('KRT6B',)
# ('AC005077.4',)
# ('KRT6A',)
# ('SLC2A1',)
# ('B3GNT3',)
# ('LYPD3',)
# P Value:  0.11151934371153646
# CBLC
# ('FAM83A-AS1',)
# ('KRT16',)
# ('GJB3',)
# ('TFAP2A',)
# ('KRT6B',)
# ('SLC2A1',)
# ('KRT6A',)
# ('AC005077.4',)
# ('B3GNT3',)
# ('LYPD3',)
# ('FAM83A',)
# ('FAM83A-AS1', 'KRT16')
# ('FAM83A-AS1', 'GJB3')
# ('FAM83A-AS1', 'TFAP2A')
# ('FAM83A-AS1', 'KRT6B')
# ('FAM83A-AS1', 'SLC2A1')
# ('FAM83A-AS1', 'KRT6A')
# ('FAM83A-AS1', 'AC005077.4')
# ('FAM83A-AS1', 'B3GNT3')
# ('FAM83A-AS1', 'LYPD3')
# ('FAM83A-AS1', 'FAM83A')
# ('KRT16', 'GJB3')
# ('KRT16', 'TFAP2A')
# ('KRT16', 'KRT6B')
# ('KRT16', 'SLC2A1')
# ('KRT16', 'KRT6A')
# ('KRT16', 'AC005077.4')
# P Value:  0.1077534962059097
# KRT6B
# ('FAM83A-AS1',)
# P Value:  0.13516055441522926
# FAM83A-AS1
# ('KRT16',)
# ('GJB3',)
# P Value:  0.731713247095964
# SLC2A1
# ('KRT16',)
# ('GJB3',)
# ('TFAP2A',)
# ('AC005077.4',)
# ('KRT6A',)
# ('B3GNT3',)
# ('LYPD3',)
# P Value:  0.16072912531332217
# B3GNT3
# ('KRT16',)
# P Value:  0.9918224992350441
# TFAP2A
# ('KRT16',)
# ('GJB3',)
# ('KRT6A',)
# ('AC005077.4',)
# ('LYPD3',)
# ('FAM83A',)
# ('KRT16', 'GJB3')
# P Value:  0.08751005758044372
# AC005077.4
# ('KRT16',)
# ('GJB3',)
# ('KRT6A',)
# ('LYPD3',)
# ('FAM83A',)
# ('KRT16', 'GJB3')
# ('KRT16', 'KRT6A')
# ('KRT16', 'LYPD3')
# ('KRT16', 'FAM83A')
# ('GJB3', 'KRT6A')
# ('GJB3', 'LYPD3')
# ('GJB3', 'FAM83A')
# ('KRT6A', 'LYPD3')
# ('KRT6A', 'FAM83A')
# ('LYPD3', 'FAM83A')
# ('KRT16', 'GJB3', 'KRT6A')
# ('KRT16', 'GJB3', 'LYPD3')
# ('KRT16', 'GJB3', 'FAM83A')
# ('KRT16', 'KRT6A', 'LYPD3')
# ('KRT16', 'KRT6A', 'FAM83A')
# P Value:  0.10797931303859593
# KRT6A
# ('FAM83A',)
# P Value:  0.3858862161146861
# GJB3
# ('KRT16',)
# ('LYPD3',)
# P Value:  0.6748242625133938
# FAM83A
# ('KRT16',)
# ('LYPD3',)
# ('KRT16', 'LYPD3')
# LYPD3
# ('KRT16',)
# ('FAM83A',)
# ('KRT16', 'FAM83A')
# KRT16
# ('LYPD3',)
# P Value:  0.8679243029461247
# Train Adj: {'LYPD3', 'FAM83A'}
# corr_X: -0.3145629150999277
# corr_Y: -0.29431764677803257
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LYPD3 cause RHOV.
# corr_X: -0.24648880518482996
# corr_Y: -0.3201693271394258
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that RHOV cause FAM83A.
# parSet: ['LYPD3', 'FAM83A']
# chiSet: []
# Start Identify!
# Aim Variable: PITX1
# exclSet: ['ajcc_pathologic_stage']
# Init Adj: {'KRT16', 'ITPKA', 'GJB3', 'UHRF1', 'KRT6B', 'AC112777.1', 'TNS4', 'PKMYT1', 'KRT6A', 'SLC2A1', 'SAPCD2', 'MYEOV', 'B3GNT3', 'FAM83A'}
# Init Adj Length: 14
# ITPKA
# ('KRT16',)
# P Value:  0.19066183535270453
# KRT16
# ('GJB3',)
# P Value:  0.30102614495830426
# SLC2A1
# ('GJB3',)
# P Value:  0.15413461502343084
# PKMYT1
# ('GJB3',)
# ('UHRF1',)
# P Value:  0.970293100673824
# AC112777.1
# ('GJB3',)
# ('UHRF1',)
# P Value:  0.1939117456721421
# TNS4
# ('GJB3',)
# P Value:  0.33676753966271156
# KRT6B
# ('GJB3',)
# P Value:  0.8350991738346962
# KRT6A
# ('GJB3',)
# P Value:  0.5852124808388579
# SAPCD2
# ('GJB3',)
# ('UHRF1',)
# P Value:  0.08913655281747737
# B3GNT3
# ('MYEOV',)
# ('UHRF1',)
# ('FAM83A',)
# ('GJB3',)
# P Value:  0.29410855904796385
# UHRF1
# ('MYEOV',)
# ('GJB3',)
# ('FAM83A',)
# P Value:  0.09702871562027411
# MYEOV
# ('FAM83A',)
# P Value:  0.16176239391341496
# FAM83A
# ('GJB3',)
# P Value:  0.3064070011239761
# GJB3
# No much variable to CI test!
# Train Adj: {'GJB3'}
# corr_X: -0.29662464750406586
# corr_Y: -0.12777223979688138
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that GJB3 cause PITX1.
# parSet: ['GJB3']
# chiSet: []
# Start Identify!
# Aim Variable: LYPD3
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1']
# Init Adj: {'PSMD10P2', 'AC106045.1', 'KRT16', 'KLK6', 'NCCRP1', 'CCNE1', 'GJB3', 'ADGRF4', 'TNS4', 'KRT6A', 'SLC2A1', 'AKR1B15', 'KRT81'}
# Init Adj Length: 13
# NCCRP1
# ('PSMD10P2',)
# ('AC106045.1',)
# ('KRT16',)
# ('KLK6',)
# ('CCNE1',)
# ('GJB3',)
# ('ADGRF4',)
# ('TNS4',)
# ('KRT6A',)
# ('SLC2A1',)
# ('AKR1B15',)
# ('KRT81',)
# ('PSMD10P2', 'AC106045.1')
# ('PSMD10P2', 'KRT16')
# ('PSMD10P2', 'KLK6')
# P Value:  0.09287554412518254
# AC106045.1
# ('KRT16',)
# ('KLK6',)
# ('CCNE1',)
# ('GJB3',)
# ('ADGRF4',)
# ('TNS4',)
# ('KRT6A',)
# ('SLC2A1',)
# ('AKR1B15',)
# ('PSMD10P2',)
# P Value:  0.08249608292291971
# ADGRF4
# ('PSMD10P2',)
# ('KRT16',)
# ('KLK6',)
# ('CCNE1',)
# ('GJB3',)
# ('TNS4',)
# ('KRT6A',)
# ('SLC2A1',)
# ('AKR1B15',)
# ('KRT81',)
# ('PSMD10P2', 'KRT16')
# ('PSMD10P2', 'KLK6')
# ('PSMD10P2', 'CCNE1')
# ('PSMD10P2', 'GJB3')
# ('PSMD10P2', 'TNS4')
# ('PSMD10P2', 'KRT6A')
# ('PSMD10P2', 'SLC2A1')
# ('PSMD10P2', 'AKR1B15')
# ('PSMD10P2', 'KRT81')
# ('KRT16', 'KLK6')
# ('KRT16', 'CCNE1')
# P Value:  0.20560089542266202
# AKR1B15
# ('KRT16',)
# ('KLK6',)
# ('CCNE1',)
# ('GJB3',)
# ('TNS4',)
# ('KRT6A',)
# ('SLC2A1',)
# ('PSMD10P2',)
# ('KRT81',)
# ('KRT16', 'KLK6')
# ('KRT16', 'CCNE1')
# ('KRT16', 'GJB3')
# ('KRT16', 'TNS4')
# ('KRT16', 'KRT6A')
# ('KRT16', 'SLC2A1')
# ('KRT16', 'PSMD10P2')
# ('KRT16', 'KRT81')
# ('KLK6', 'CCNE1')
# ('KLK6', 'GJB3')
# ('KLK6', 'TNS4')
# ('KLK6', 'KRT6A')
# ('KLK6', 'SLC2A1')
# ('KLK6', 'PSMD10P2')
# ('KLK6', 'KRT81')
# ('CCNE1', 'GJB3')
# ('CCNE1', 'TNS4')
# ('CCNE1', 'KRT6A')
# P Value:  0.19793839719407624
# MYEOV
# ('FAM83A-AS1',)
# P Value:  0.09674185456704827
# AC068228.1
# ('FAM83A-AS1',)
# FAM83A-AS1
# ('AC068228.1',)
# Train Adj: {'FAM83A-AS1', 'AC068228.1'}
# corr_X: -0.14168752339270513
# corr_Y: -0.05991527449599361
# Identifiable:
#                        FAM83A-AS1 is cause and P-value is 0.24,
#                        FAM83A is effect and P-value is 0.01.
# find
# 0.0055964621522635654 0.24332946019598908
# corr_X: -0.07550278295861605
# corr_Y: -0.11879501581069142
# Identifiable:
#                        FAM83A is cause and P-value is 0.14,
#                        AC068228.1 is effect and P-value is 0.02.
# find
# 0.1412874780509572 0.020374126264339824
# parSet: ['FAM83A-AS1']
# chiSet: ['AC068228.1']
# Start Identify!
# Aim Variable: GJB3
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1']
# Init Adj: {'RAET1L', 'GJB2', 'KRT16', 'KLK6', 'LY6D', 'ARL14', 'KRT6B', 'ADGRF4', 'TNS4', 'KRT6A', 'PADI1', 'SLC2A1', 'PSMD10P2', 'B3GNT3'}
# Init Adj Length: 14
# GJB2
# ('RAET1L',)
# ('KRT16',)
# ('KLK6',)
# ('LY6D',)
# ('ARL14',)
# ('KRT6B',)
# ('ADGRF4',)
# ('TNS4',)
# ('KRT6A',)
# ('PADI1',)
# ('SLC2A1',)
# ('PSMD10P2',)
# ('B3GNT3',)
# ('RAET1L', 'KRT16')
# ('RAET1L', 'KLK6')
# ('RAET1L', 'LY6D')
# ('RAET1L', 'ARL14')
# ('RAET1L', 'KRT6B')
# P Value:  0.10840916104521453
# LY6D
# ('RAET1L',)
# ('KRT16',)
# P Value:  0.18394026827863408
# RAET1L
# ('KRT16',)
# ('KLK6',)
# ('ARL14',)
# ('KRT6B',)
# P Value:  0.47240141997943275
# PSMD10P2
# ('KRT16',)
# ('KLK6',)
# ('ARL14',)
# ('KRT6B',)
# ('ADGRF4',)
# ('TNS4',)
# ('KRT6A',)
# ('PADI1',)
# ('SLC2A1',)
# ('B3GNT3',)
# ('KRT16', 'KLK6')
# ('KRT16', 'ARL14')
# P Value:  0.7530456325303043
# ARL14
# ('KRT16',)
# ('KLK6',)
# P Value:  0.44995842624685
# KLK6
# ('KRT16',)
# ('KRT6B',)
# ('ADGRF4',)
# ('TNS4',)
# ('KRT6A',)
# ('PADI1',)
# ('SLC2A1',)
# P Value:  0.09872856289835921
# KRT6B
# ('KRT16',)
# P Value:  0.39731920247687613
# ADGRF4
# ('KRT16',)
# ('TNS4',)
# ('KRT6A',)
# ('PADI1',)
# ('SLC2A1',)
# ('B3GNT3',)
# ('KRT16', 'TNS4')
# P Value:  0.22170339631656744
# PADI1
# ('KRT16',)
# P Value:  0.3710344120453587
# TNS4
# ('SLC2A1',)
# ('KRT6A',)
# ('KRT16',)
# ('B3GNT3',)
# ('SLC2A1', 'KRT6A')
# ('SLC2A1', 'KRT16')
# ('SLC2A1', 'B3GNT3')
# ('KRT6A', 'KRT16')
# P Value:  0.0995727732539506
# SLC2A1
# ('KRT6A',)
# ('KRT16',)
# ('B3GNT3',)
# ('KRT6A', 'KRT16')
# ('KRT6A', 'B3GNT3')
# ('KRT16', 'B3GNT3')
# ('KRT6A', 'KRT16', 'B3GNT3')
# B3GNT3
# ('SLC2A1',)
# ('KRT6A',)
# ('KRT16',)
# ('SLC2A1', 'KRT6A')
# ('SLC2A1', 'KRT16')
# ('KRT6A', 'KRT16')
# ('SLC2A1', 'KRT6A', 'KRT16')
# KRT6A
# ('SLC2A1',)
# ('KRT16',)
# ('B3GNT3',)
# ('SLC2A1', 'KRT16')
# ('SLC2A1', 'B3GNT3')
# ('KRT16', 'B3GNT3')
# ('SLC2A1', 'KRT16', 'B3GNT3')
# KRT16
# ('SLC2A1',)
# ('KRT6A',)
# P Value:  0.38962362770628856
# Train Adj: {'SLC2A1', 'KRT6A', 'B3GNT3'}
# corr_X: -0.161912359639668
# corr_Y: -0.2812631405367522
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that GJB3 cause SLC2A1.
# corr_X: -0.49769675742980113
# corr_Y: -0.20497651399711642
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that KRT6A cause GJB3.
# corr_X: -0.13180992420038967
# corr_Y: -0.1813926744965642
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that GJB3 cause B3GNT3.
# parSet: ['SLC2A1', 'KRT6A', 'B3GNT3']
# chiSet: []
# Start Identify!
# Aim Variable: SLC2A1
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1']
# Init Adj: {'CEP55', 'PLK1', 'TPX2', 'KIF4A', 'DLGAP5', 'CDCA5', 'CCNB2', 'ANLN', 'KIF2C', 'CDC20', 'CDCA8', 'CDC6', 'RRM2', 'CCNB1'}
# Init Adj Length: 14
# CEP55
# ('PLK1',)
# P Value:  0.975867758243499
# CCNB1
# ('PLK1',)
# P Value:  0.7623838326400028
# CDC6
# ('PLK1',)
# P Value:  0.1013570820964902
# DLGAP5
# ('PLK1',)
# P Value:  0.37251904452366
# CDCA5
# ('PLK1',)
# P Value:  0.8623812305126867
# CDC20
# ('PLK1',)
# P Value:  0.3746428032573331
# PLK1
# ('TPX2',)
# ('KIF4A',)
# ('CCNB2',)
# ('ANLN',)
# ('KIF2C',)
# ('CDCA8',)
# ('RRM2',)
# ('TPX2', 'KIF4A')
# P Value:  0.39585289420517844
# CCNB2
# ('TPX2',)
# P Value:  0.08582544399556535
# KIF4A
# ('TPX2',)
# ('ANLN',)
# ('KIF2C',)
# ('CDCA8',)
# ('RRM2',)
# ('TPX2', 'ANLN')
# P Value:  0.7052550167501292
# TPX2
# ('ANLN',)
# P Value:  0.20827306622822983
# KIF2C
# ('ANLN',)
# P Value:  0.1703174805787927
# RRM2
# ('ANLN',)
# ('CDCA8',)
# P Value:  0.12819367697366862
# CDCA8
# ('ANLN',)
# ANLN
# ('CDCA8',)
# Train Adj: {'ANLN', 'CDCA8'}
# corr_X: -0.16384548790039985
# corr_Y: -0.26093737456143967
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that SLC2A1 cause ANLN.
# corr_X: -0.14361562478980566
# corr_Y: -0.20894912591698978
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that SLC2A1 cause CDCA8.
# parSet: ['ANLN', 'CDCA8']
# chiSet: []
# Start Identify!
# Aim Variable: KRT16
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1']
# Init Adj: {'GPR87', 'RAET1L', 'GJB2', 'KCNN4', 'KRT6B', 'TNS4', 'KRT6A', 'PADI1', 'MMP11', 'SLC2A1', 'KRT14', 'B3GNT3'}
# Init Adj Length: 12
# B3GNT3
# ('GPR87',)
# ('RAET1L',)
# P Value:  0.22017016198957196
# MMP11
# ('GPR87',)
# P Value:  0.7983191133452263
# TNS4
# ('GPR87',)
# ('RAET1L',)
# ('GJB2',)
# ('KCNN4',)
# ('KRT6B',)
# ('KRT6A',)
# P Value:  0.5272176765909585
# SLC2A1
# ('GPR87',)
# ('RAET1L',)
# P Value:  0.5282579968674301
# KRT6B
# ('GPR87',)
# ('RAET1L',)
# P Value:  0.13960363594278408
# GJB2
# ('GPR87',)
# ('RAET1L',)
# P Value:  0.08807079727757493
# KCNN4
# ('GPR87',)
# P Value:  0.21793959513389494
# GPR87
# ('RAET1L',)
# ('KRT6A',)
# ('PADI1',)
# ('KRT14',)
# ('RAET1L', 'KRT6A')
# P Value:  0.08543934681119587
# KRT14
# ('RAET1L',)
# P Value:  0.3045114923733633
# RAET1L
# ('KRT6A',)
# P Value:  0.2622424817424521
# PADI1
# ('KRT6A',)
# KRT6A
# ('PADI1',)
# Train Adj: {'KRT6A', 'PADI1'}
# corr_X: -0.37493027602907125
# corr_Y: -0.3616294533749862
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that KRT6A cause KRT16.
# corr_X: -0.47805661890273504
# corr_Y: -0.2855456075839968
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that PADI1 cause KRT16.
# parSet: ['KRT6A', 'PADI1']
# chiSet: []
# Start Identify!
# Aim Variable: FAM83A-AS1
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1']
# Init Adj: {'UHRF1', 'LINC01792', 'ADGRF4', 'C15orf48', 'AL133335.2', 'CYP24A1', 'KIF14', 'MYEOV', 'AP005233.2', 'LASTR', 'TUBB3'}
# Init Adj Length: 11
# KIF14
# ('UHRF1',)
# P Value:  0.17662108743546379
# UHRF1
# ('LINC01792',)
# ('ADGRF4',)
# ('C15orf48',)
# ('AL133335.2',)
# ('CYP24A1',)
# ('MYEOV',)
# ('AP005233.2',)
# ('LASTR',)
# ('TUBB3',)
# ('LINC01792', 'ADGRF4')
# P Value:  0.12319491275591597
# C15orf48
# ('LINC01792',)
# ('ADGRF4',)
# ('AL133335.2',)
# ('CYP24A1',)
# ('MYEOV',)
# ('AP005233.2',)
# ('LASTR',)
# ('TUBB3',)
# ('LINC01792', 'ADGRF4')
# P Value:  0.20510152998500775
# CYP24A1
# ('LINC01792',)
# P Value:  0.37178017740926306
# AL133335.2
# ('LINC01792',)
# ('ADGRF4',)
# ('MYEOV',)
# ('AP005233.2',)
# ('LASTR',)
# ('TUBB3',)
# ('LINC01792', 'ADGRF4')
# ('LINC01792', 'MYEOV')
# P Value:  0.39624486894230915
# ADGRF4
# ('LINC01792',)
# ('MYEOV',)
# P Value:  0.29217591238424745
# LASTR
# ('MYEOV',)
# ('AP005233.2',)
# ('LINC01792',)
# ('TUBB3',)
# ('MYEOV', 'AP005233.2')
# ('MYEOV', 'LINC01792')
# ('MYEOV', 'TUBB3')
# ('AP005233.2', 'LINC01792')
# ('AP005233.2', 'TUBB3')
# ('LINC01792', 'TUBB3')
# P Value:  0.15169263679106307
# TUBB3
# ('MYEOV',)
# ('AP005233.2',)
# ('LINC01792',)
# ('MYEOV', 'AP005233.2')
# ('MYEOV', 'LINC01792')
# ('AP005233.2', 'LINC01792')
# ('MYEOV', 'AP005233.2', 'LINC01792')
# LINC01792
# ('MYEOV',)
# ('AP005233.2',)
# ('TUBB3',)
# ('MYEOV', 'AP005233.2')
# ('MYEOV', 'TUBB3')
# P Value:  0.16790627888438436
# MYEOV
# ('AP005233.2',)
# P Value:  0.10660457118615571
# AP005233.2
# ('TUBB3',)
# Train Adj: {'AP005233.2', 'TUBB3'}
# corr_X: -0.3066299703381848
# corr_Y: -0.23157861318696862
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that AP005233.2 cause FAM83A-AS1.
# corr_X: -0.14474288100709293
# corr_Y: -0.3644001449175578
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that FAM83A-AS1 cause TUBB3.
# parSet: ['AP005233.2', 'TUBB3']
# chiSet: []
# Start Identify!
# Aim Variable: SLC2A1
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1']
# Init Adj: {'CEP55', 'PLK1', 'TPX2', 'KIF4A', 'DLGAP5', 'CDCA5', 'CCNB2', 'ANLN', 'KIF2C', 'CDC20', 'CDCA8', 'CDC6', 'RRM2', 'CCNB1'}
# Init Adj Length: 14
# CEP55
# ('PLK1',)
# P Value:  0.6077131053531827
# CCNB1
# ('PLK1',)
# P Value:  0.7606240601949865
# CDC6
# ('PLK1',)
# P Value:  0.10135708337822573
# DLGAP5
# ('PLK1',)
# P Value:  0.67438711745695
# CDCA5
# ('PLK1',)
# P Value:  0.8612971825059883
# CDC20
# ('PLK1',)
# P Value:  0.37413758938385644
# PLK1
# ('TPX2',)
# ('KIF4A',)
# ('CCNB2',)
# ('ANLN',)
# ('KIF2C',)
# ('CDCA8',)
# ('RRM2',)
# ('TPX2', 'KIF4A')
# ('TPX2', 'CCNB2')
# ('TPX2', 'ANLN')
# ('TPX2', 'KIF2C')
# ('TPX2', 'CDCA8')
# ('TPX2', 'RRM2')
# P Value:  0.5932588501264022
# CCNB2
# ('TPX2',)
# ('KIF4A',)
# P Value:  0.21034647708495968
# KIF4A
# ('TPX2',)
# ('ANLN',)
# ('KIF2C',)
# ('CDCA8',)
# ('RRM2',)
# ('TPX2', 'ANLN')
# P Value:  0.959813791229789
# TPX2
# ('ANLN',)
# P Value:  0.12161552757721675
# KIF2C
# ('ANLN',)
# P Value:  0.3105114019698877
# RRM2
# ('ANLN',)
# P Value:  0.09094530328882942
# CDCA8
# ('ANLN',)
# ANLN
# ('CDCA8',)
# Train Adj: {'ANLN', 'CDCA8'}
# corr_X: -0.2047686723094581
# corr_Y: -0.26093737456143967
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that SLC2A1 cause ANLN.
# corr_X: -0.14361562478980566
# corr_Y: -0.20894912591698978
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that SLC2A1 cause CDCA8.
# parSet: ['ANLN', 'CDCA8']
# chiSet: []
# Start Identify!
# Aim Variable: KRT6A
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1']
# Init Adj: {'KRT16', 'KLK6', 'KRT6B', 'SPRR1B', 'TNS4', 'S100A7', 'SERPINB5', 'SLC2A1', 'UCN2', 'KRT14', 'DSG3'}
# Init Adj Length: 11
# KLK6
# ('KRT16',)
# ('KRT6B',)
# P Value:  0.17959090497437857
# DSG3
# ('KRT16',)
# P Value:  0.09292217823397828
# UCN2
# ('KRT16',)
# P Value:  0.5573199215917073
# KRT14
# ('KRT16',)
# P Value:  0.14023626584107715
# SPRR1B
# ('KRT16',)
# P Value:  0.08353286443177085
# S100A7
# ('KRT16',)
# P Value:  0.11960593493417346
# SLC2A1
# ('KRT6B',)
# P Value:  0.734194423886106
# SERPINB5
# ('KRT6B',)
# ('KRT16',)
# ('TNS4',)
# P Value:  0.17166313198533323
# TNS4
# ('KRT6B',)
# ('KRT16',)
# ('KRT6B', 'KRT16')
# KRT16
# ('KRT6B',)
# ('TNS4',)
# ('KRT6B', 'TNS4')
# KRT6B
# ('KRT16',)
# P Value:  0.20120897617535138
# Train Adj: {'KRT16', 'TNS4'}
# corr_X: -0.3369737035334831
# corr_Y: -0.45819429669802586
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that KRT6A cause KRT16.
# corr_X: -0.19994788241039457
# corr_Y: -0.3345941563346433
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that KRT6A cause TNS4.
# parSet: ['KRT16', 'TNS4']
# chiSet: []
# Start Identify!
# Aim Variable: B3GNT3
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1']
# Init Adj: {'GJB2', 'KRT16', 'PTPRH', 'KCNN4', 'ADGRF4', 'SLC2A1', 'KRT78', 'PADI1', 'AC005077.4', 'NGEF', 'PSMD10P2', 'CBLC'}
# Init Adj Length: 12
# NGEF
# ('GJB2',)
# ('KRT16',)
# ('PTPRH',)
# ('KCNN4',)
# ('ADGRF4',)
# ('SLC2A1',)
# ('KRT78',)
# ('PADI1',)
# ('AC005077.4',)
# ('PSMD10P2',)
# ('CBLC',)
# ('GJB2', 'KRT16')
# ('GJB2', 'PTPRH')
# ('GJB2', 'KCNN4')
# ('GJB2', 'ADGRF4')
# P Value:  0.3696897138297476
# SLC2A1
# ('GJB2',)
# ('KRT16',)
# ('PTPRH',)
# P Value:  0.5948516783008801
# KRT78
# ('GJB2',)
# P Value:  0.1384215423868861
# ADGRF4
# ('GJB2',)
# ('KRT16',)
# ('PTPRH',)
# ('KCNN4',)
# ('PADI1',)
# ('AC005077.4',)
# ('PSMD10P2',)
# ('CBLC',)
# ('GJB2', 'KRT16')
# ('GJB2', 'PTPRH')
# ('GJB2', 'KCNN4')
# ('GJB2', 'PADI1')
# ('GJB2', 'AC005077.4')
# ('GJB2', 'PSMD10P2')
# ('GJB2', 'CBLC')
# ('KRT16', 'PTPRH')
# ('KRT16', 'KCNN4')
# ('KRT16', 'PADI1')
# P Value:  0.2247201051808182
# CBLC
# ('GJB2',)
# ('KRT16',)
# ('PTPRH',)
# ('KCNN4',)
# ('PADI1',)
# ('AC005077.4',)
# ('PSMD10P2',)
# ('GJB2', 'KRT16')
# ('GJB2', 'PTPRH')
# ('GJB2', 'KCNN4')
# ('GJB2', 'PADI1')
# ('GJB2', 'AC005077.4')
# ('GJB2', 'PSMD10P2')
# ('KRT16', 'PTPRH')
# ('KRT16', 'KCNN4')
# ('KRT16', 'PADI1')
# ('KRT16', 'AC005077.4')
# ('KRT16', 'PSMD10P2')
# ('PTPRH', 'KCNN4')
# ('PTPRH', 'PADI1')
# ('PTPRH', 'AC005077.4')
# ('PTPRH', 'PSMD10P2')
# ('KCNN4', 'PADI1')
# ('KCNN4', 'AC005077.4')
# ('KCNN4', 'PSMD10P2')
# ('PADI1', 'AC005077.4')
# ('PADI1', 'PSMD10P2')
# ('AC005077.4', 'PSMD10P2')
# ('GJB2', 'KRT16', 'PTPRH')
# ('GJB2', 'KRT16', 'KCNN4')
# ('GJB2', 'KRT16', 'PADI1')
# ('GJB2', 'KRT16', 'AC005077.4')
# P Value:  0.15325002021837855
# KCNN4
# ('GJB2',)
# ('PTPRH',)
# ('KRT16',)
# ('PADI1',)
# ('AC005077.4',)
# ('PSMD10P2',)
# ('GJB2', 'PTPRH')
# ('GJB2', 'KRT16')
# ('GJB2', 'PADI1')
# P Value:  0.22030122603805402
# GJB2
# ('KRT16',)
# P Value:  0.1466944455540708
# PSMD10P2
# ('AC005077.4',)
# ('PTPRH',)
# ('PADI1',)
# ('KRT16',)
# ('AC005077.4', 'PTPRH')
# P Value:  0.15590542769264626
# AC005077.4
# ('KRT16',)
# ('PADI1',)
# ('PTPRH',)
# P Value:  0.15182618660468447
# KRT16
# ('PADI1',)
# P Value:  0.3487273964350376
# PADI1
# ('PTPRH',)
# PTPRH
# ('PADI1',)
# Train Adj: {'PADI1', 'PTPRH'}
# corr_X: -0.315314970307898
# corr_Y: -0.047806793740057606
# Identifiable:
#                        PADI1 is cause and P-value is 0.35,
#                        B3GNT3 is effect and P-value is 0.0.
# find
# 3.0582017182922283e-10 0.3520514928065658
# corr_X: -0.16080567085355718
# corr_Y: -0.09935449994901091
# Identifiable:
#                        PTPRH is cause and P-value is 0.05,
#                        B3GNT3 is effect and P-value is 0.0.
# find
# 0.001638272209916097 0.05265407697393779
# parSet: ['PADI1', 'PTPRH']
# chiSet: []
# Start Identify!
# Aim Variable: ANLN
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1', 'SLC2A1', 'KRT16', 'FAM83A-AS1', 'SLC2A1', 'KRT6A', 'B3GNT3']
# Init Adj: {'NDC80', 'TPX2', 'KIF4A', 'DLGAP5', 'MELK', 'DEPDC1', 'TOP2A', 'NCAPH', 'NCAPG', 'KIF14', 'TTK', 'KIF2C', 'CKAP2L', 'BUB1B'}
# Init Adj Length: 14
# TTK
# ('NDC80',)
# P Value:  0.16757847917364344
# NDC80
# ('TPX2',)
# P Value:  0.12099549645178827
# KIF14
# ('TPX2',)
# ('KIF4A',)
# ('DLGAP5',)
# ('MELK',)
# ('DEPDC1',)
# ('TOP2A',)
# ('NCAPH',)
# ('NCAPG',)
# ('KIF2C',)
# ('CKAP2L',)
# ('BUB1B',)
# ('TPX2', 'KIF4A')
# ('TPX2', 'DLGAP5')
# P Value:  0.668107090739749
# NCAPG
# ('TPX2',)
# P Value:  0.13122701261906544
# NCAPH
# ('TPX2',)
# P Value:  0.7522356295186935
# MELK
# ('TPX2',)
# P Value:  0.2700616139837191
# TPX2
# ('KIF4A',)
# ('TPX2',)
# ('KIF4A',)
# ('CDCA5',)
# ('CENPA',)
# ('CDC20',)
# ('KIF2C',)
# ('TPX2', 'KIF4A')
# ('TPX2', 'CDCA5')
# P Value:  0.40122191869921175
# KIF4A
# ('TPX2',)
# ('CDCA5',)
# ('CENPA',)
# ('CDC20',)
# ('KIF2C',)
# ('TPX2', 'CDCA5')
# P Value:  0.2183521731053495
# CENPA
# ('CDC20',)
# ('TPX2',)
# ('KIF2C',)
# P Value:  0.4148719828979437
# CDCA5
# ('CDC20',)
# ('TPX2',)
# ('KIF2C',)
# ('CDC20', 'TPX2')
# P Value:  0.10574535462783789
# TPX2
# ('CDC20',)
# ('KIF2C',)
# ('CDC20', 'KIF2C')
# CDC20
# ('TPX2',)
# ('KIF2C',)
# ('TPX2', 'KIF2C')
# KIF2C
# ('CDC20',)
# ('TPX2',)
# ('CDC20', 'TPX2')
# Train Adj: {'CDC20', 'TPX2', 'KIF2C'}
# corr_X: -0.0744824608414717
# corr_Y: -0.03267618896769896
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that CDC20 cause CDCA8.
# corr_X: -0.08457244029395745
# corr_Y: -0.1406011937953884
# Identifiable:
#                        CDCA8 is cause and P-value is 0.1,
#                        TPX2 is effect and P-value is 0.01.
# find
# 0.09928738565217589 0.0059763387271376195
# corr_X: -0.06466955821759535
# corr_Y: -0.03569105391173031
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that KIF2C cause CDCA8.
# parSet: ['CDC20', 'KIF2C']
# chiSet: ['TPX2']
# Start Identify!
# Aim Variable: PADI1
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1', 'SLC2A1', 'KRT16', 'FAM83A-AS1', 'SLC2A1', 'KRT6A', 'B3GNT3']
# Init Adj: {'GPR87', 'RAET1L', 'TGM5', 'KCNN4', 'STX1A', 'LINC02783', 'ADGRF4', 'PADI3', 'PSMD10P2', 'AC004870.2'}
# Init Adj Length: 10
# STX1A
# ('GPR87',)
# P Value:  0.19087812873565324
# PSMD10P2
# ('GPR87',)
# P Value:  0.11075083836461191
# AC004870.2
# ('GPR87',)
# ('RAET1L',)
# ('TGM5',)
# ('KCNN4',)
# ('LINC02783',)
# ('ADGRF4',)
# ('PADI3',)
# ('GPR87', 'RAET1L')
# P Value:  0.10371641563707144
# GPR87
# ('RAET1L',)
# P Value:  0.09847031910847066
# KCNN4
# ('RAET1L',)
# P Value:  0.09092420266060501
# TGM5
# ('RAET1L',)
# ('LINC02783',)
# ('ADGRF4',)
# P Value:  0.08865390510056773
# ADGRF4
# ('RAET1L',)
# P Value:  0.3416133399714163
# RAET1L
# ('LINC02783',)
# ('PADI3',)
# P Value:  0.8534020145284188
# LINC02783
# ('PADI3',)
# PADI3
# ('LINC02783',)
# Train Adj: {'LINC02783', 'PADI3'}
# corr_X: -0.4767429445015374
# corr_Y: -0.5547266318691132
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that PADI1 cause LINC02783.
# corr_X: -0.3856520006840251
# corr_Y: -0.32027540180358677
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that PADI3 cause PADI1.
# parSet: ['LINC02783', 'PADI3']
# chiSet: []
# Start Identify!
# Aim Variable: AP005233.2
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1', 'SLC2A1', 'KRT16', 'FAM83A-AS1', 'SLC2A1', 'KRT6A', 'B3GNT3']
# Init Adj: {'MYEOV', 'COL7A1', 'C8orf74', 'FER1L4'}
# Init Adj Length: 4
# FER1L4
# ('MYEOV',)
# ('COL7A1',)
# ('C8orf74',)
# ('MYEOV', 'COL7A1')
# P Value:  0.2854720525953518
# COL7A1
# ('MYEOV',)
# P Value:  0.09703871028447637
# C8orf74
# ('MYEOV',)
# P Value:  0.9387695398177173
# MYEOV
# No much variable to CI test!
# Train Adj: {'MYEOV'}
# corr_X: -0.40394749334143837
# corr_Y: -0.16507684333501574
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that MYEOV cause AP005233.2.
# parSet: ['MYEOV']
# chiSet: []
# Start Identify!
# Aim Variable: TUBB3
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1', 'SLC2A1', 'KRT16', 'FAM83A-AS1', 'SLC2A1', 'KRT6A', 'B3GNT3']
# Init Adj: {'RECQL4', 'TMEM184A', 'RHBG', 'AL645608.8', 'STX1A', 'CELSR3', 'GPC2', 'PKMYT1', 'COL7A1', 'LASTR', 'TEDC2'}
# Init Adj Length: 11
# RECQL4
# ('TMEM184A',)
# ('RHBG',)
# ('AL645608.8',)
# ('STX1A',)
# ('CELSR3',)
# ('GPC2',)
# ('PKMYT1',)
# ('COL7A1',)
# ('LASTR',)
# ('TEDC2',)
# ('TMEM184A', 'RHBG')
# ('TMEM184A', 'AL645608.8')
# ('TMEM184A', 'STX1A')
# ('TMEM184A', 'CELSR3')
# ('TMEM184A', 'GPC2')
# P Value:  0.09996537340629692
# PKMYT1
# ('TMEM184A',)
# ('RHBG',)
# ('AL645608.8',)
# ('STX1A',)
# ('CELSR3',)
# ('GPC2',)
# ('COL7A1',)
# ('LASTR',)
# ('TEDC2',)
# ('TMEM184A', 'RHBG')
# ('TMEM184A', 'AL645608.8')
# ('TMEM184A', 'STX1A')
# ('TMEM184A', 'CELSR3')
# ('TMEM184A', 'GPC2')
# ('TMEM184A', 'COL7A1')
# ('TMEM184A', 'LASTR')
# ('TMEM184A', 'TEDC2')
# ('RHBG', 'AL645608.8')
# ('RHBG', 'STX1A')
# ('RHBG', 'CELSR3')
# ('RHBG', 'GPC2')
# ('RHBG', 'COL7A1')
# P Value:  0.18363091239314389
# COL7A1
# ('TMEM184A',)
# ('RHBG',)
# ('AL645608.8',)
# ('STX1A',)
# ('CELSR3',)
# ('GPC2',)
# ('LASTR',)
# ('TEDC2',)
# ('TMEM184A', 'RHBG')
# ('TMEM184A', 'AL645608.8')
# ('TMEM184A', 'STX1A')
# ('TMEM184A', 'CELSR3')
# ('TMEM184A', 'GPC2')
# ('TMEM184A', 'LASTR')
# ('TMEM184A', 'TEDC2')
# ('RHBG', 'AL645608.8')
# ('RHBG', 'STX1A')
# ('RHBG', 'CELSR3')
# ('RHBG', 'GPC2')
# ('RHBG', 'LASTR')
# ('RHBG', 'TEDC2')
# ('AL645608.8', 'STX1A')
# P Value:  0.13143384319850568
# TEDC2
# ('TMEM184A',)
# ('RHBG',)
# ('AL645608.8',)
# ('STX1A',)
# ('CELSR3',)
# ('GPC2',)
# P Value:  0.10519459134708437
# AL645608.8
# ('RHBG',)
# ('TMEM184A',)
# ('STX1A',)
# ('CELSR3',)
# ('GPC2',)
# ('LASTR',)
# ('RHBG', 'TMEM184A')
# ('RHBG', 'STX1A')
# ('RHBG', 'CELSR3')
# ('RHBG', 'GPC2')
# ('RHBG', 'LASTR')
# ('TMEM184A', 'STX1A')
# ('TMEM184A', 'CELSR3')
# ('TMEM184A', 'GPC2')
# P Value:  0.10160854001406058
# RHBG
# ('TMEM184A',)
# ('STX1A',)
# ('CELSR3',)
# ('GPC2',)
# ('LASTR',)
# ('TMEM184A', 'STX1A')
# ('TMEM184A', 'CELSR3')
# ('TMEM184A', 'GPC2')
# P Value:  0.10265275975373979
# TMEM184A
# ('STX1A',)
# ('CELSR3',)
# ('LASTR',)
# ('GPC2',)
# ('STX1A', 'CELSR3')
# ('STX1A', 'LASTR')
# ('STX1A', 'GPC2')
# ('CELSR3', 'LASTR')
# ('CELSR3', 'GPC2')
# ('LASTR', 'GPC2')
# ('STX1A', 'CELSR3', 'LASTR')
# ('STX1A', 'CELSR3', 'GPC2')
# ('STX1A', 'LASTR', 'GPC2')
# ('CELSR3', 'LASTR', 'GPC2')
# CELSR3
# ('STX1A',)
# ('LASTR',)
# ('TMEM184A',)
# ('GPC2',)
# ('STX1A', 'LASTR')
# ('STX1A', 'TMEM184A')
# ('STX1A', 'GPC2')
# ('LASTR', 'TMEM184A')
# ('LASTR', 'GPC2')
# ('TMEM184A', 'GPC2')
# ('STX1A', 'LASTR', 'TMEM184A')
# ('STX1A', 'LASTR', 'GPC2')
# ('STX1A', 'TMEM184A', 'GPC2')
# ('LASTR', 'TMEM184A', 'GPC2')
# LASTR
# ('STX1A',)
# ('CELSR3',)
# ('TMEM184A',)
# ('GPC2',)
# ('STX1A', 'CELSR3')
# ('STX1A', 'TMEM184A')
# ('STX1A', 'GPC2')
# ('CELSR3', 'TMEM184A')
# ('CELSR3', 'GPC2')
# ('TMEM184A', 'GPC2')
# ('STX1A', 'CELSR3', 'TMEM184A')
# ('STX1A', 'CELSR3', 'GPC2')
# ('STX1A', 'TMEM184A', 'GPC2')
# ('CELSR3', 'TMEM184A', 'GPC2')
# GPC2
# ('STX1A',)
# ('CELSR3',)
# P Value:  0.2457252617128367
# STX1A
# ('CELSR3',)
# ('LASTR',)
# ('TMEM184A',)
# ('CELSR3', 'LASTR')
# ('CELSR3', 'TMEM184A')
# ('LASTR', 'TMEM184A')
# ('CELSR3', 'LASTR', 'TMEM184A')
# Train Adj: {'STX1A', 'CELSR3', 'LASTR', 'TMEM184A'}
# corr_X: -0.1398576742364063
# corr_Y: -0.10353051118887625
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that STX1A cause TUBB3.
# corr_X: -0.09121873873256837
# corr_Y: -0.10329736614281715
# Identifiable:
#                        TUBB3 is cause and P-value is 0.08,
#                        CELSR3 is effect and P-value is 0.04.
# find
# 0.07534186695282595 0.04389916195643717
# corr_X: -0.21337637247474892
# corr_Y: -0.1391748995555353
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LASTR cause TUBB3.
# corr_X: -0.09174913384980889
# corr_Y: -0.17924170446955678
# Identifiable:
#                        TUBB3 is cause and P-value is 0.07,
#                        TMEM184A is effect and P-value is 0.0.
# find
# 0.0736531993266209 0.0004386364947530755
# parSet: ['STX1A', 'LASTR']
# chiSet: ['CELSR3', 'TMEM184A']
# Start Identify!
# Aim Variable: ANLN
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1', 'SLC2A1', 'KRT16', 'FAM83A-AS1', 'SLC2A1', 'KRT6A', 'B3GNT3']
# Init Adj: {'NDC80', 'TPX2', 'KIF4A', 'DLGAP5', 'MELK', 'DEPDC1', 'TOP2A', 'NCAPH', 'NCAPG', 'KIF14', 'TTK', 'KIF2C', 'CKAP2L', 'BUB1B'}
# Init Adj Length: 14
# TTK
# ('NDC80',)
# P Value:  0.16757077948008103
# NDC80
# ('TPX2',)
# P Value:  0.11612565216151294
# KIF14
# ('TPX2',)
# ('KIF4A',)
# ('DLGAP5',)
# ('MELK',)
# ('DEPDC1',)
# ('TOP2A',)
# ('NCAPH',)
# ('NCAPG',)
# ('KIF2C',)
# ('CKAP2L',)
# ('BUB1B',)
# ('TPX2', 'KIF4A')
# ('TPX2', 'DLGAP5')
# P Value:  0.22485035168295808
# NCAPG
# ('TPX2',)
# P Value:  0.10788894425637871
# NCAPH
# ('TPX2',)
# P Value:  0.5849998280953734
# MELK
# ('TPX2',)
# P Value:  0.278612895211377
# TPX2
# ('KIF4A',)
# P Value:  0.5853700059489599
# TOP2A
# ('KIF4A',)
# P Value:  0.4492443518371122
# DEPDC1
# ('KIF4A',)
# ('DLGAP5',)
# ('KIF2C',)
# ('CKAP2L',)
# ('BUB1B',)
# ('KIF4A', 'DLGAP5')
# P Value:  0.4551909823000846
# KIF2C
# ('CKAP2L',)
# ('KIF4A',)
# P Value:  0.2658815176555781
# BUB1B
# ('DLGAP5',)
# ('KIF4A',)
# P Value:  0.12566079101112324
# DLGAP5
# ('KIF4A',)
# P Value:  0.0812143656836583
# KIF4A
# ('CKAP2L',)
# CKAP2L
# ('KIF4A',)
# Train Adj: {'KIF4A', 'CKAP2L'}
# corr_X: -0.12973835008017218
# corr_Y: -0.20353734027942014
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that ANLN cause KIF4A.
# corr_X: -0.1815410852645899
# corr_Y: -0.15921189104457611
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that CKAP2L cause ANLN.
# parSet: ['CKAP2L']
# chiSet: ['KIF4A']
# Start Identify!
# Aim Variable: CDCA8
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1', 'SLC2A1', 'KRT16', 'FAM83A-AS1', 'SLC2A1', 'KRT6A', 'B3GNT3']
# Init Adj: {'TPX2', 'KIF4A', 'HJURP', 'CDCA5', 'CCNB2', 'BIRC5', 'CENPA', 'NCAPH', 'MYBL2', 'CDC20', 'KIF18B', 'GTSE1', 'KIF2C', 'CKAP2L'}
# Init Adj Length: 14
# HJURP
# ('TPX2',)
# ('KIF4A',)
# ('CDCA5',)
# ('CCNB2',)
# ('BIRC5',)
# ('CENPA',)
# ('NCAPH',)
# ('MYBL2',)
# ('CDC20',)
# ('KIF18B',)
# ('GTSE1',)
# ('KIF2C',)
# P Value:  0.10848497154582828
# CKAP2L
# ('TPX2',)
# ('KIF4A',)
# ('CDCA5',)
# ('CCNB2',)
# ('CENPA',)
# ('NCAPH',)
# ('MYBL2',)
# ('CDC20',)
# ('KIF18B',)
# ('GTSE1',)
# ('KIF2C',)
# ('BIRC5',)
# ('TPX2', 'KIF4A')
# P Value:  0.14026327224518134
# GTSE1
# ('TPX2',)
# ('KIF4A',)
# ('CDCA5',)
# ('CCNB2',)
# ('CENPA',)
# ('NCAPH',)
# ('MYBL2',)
# ('CDC20',)
# ('KIF18B',)
# ('KIF2C',)
# ('BIRC5',)
# ('TPX2', 'KIF4A')
# ('TPX2', 'CDCA5')
# ('TPX2', 'CCNB2')
# P Value:  0.2103081244863022
# BIRC5
# ('TPX2',)
# ('KIF4A',)
# ('CDCA5',)
# ('CCNB2',)
# ('CENPA',)
# ('NCAPH',)
# ('MYBL2',)
# ('CDC20',)
# ('KIF18B',)
# ('KIF2C',)
# ('TPX2', 'KIF4A')
# ('TPX2', 'CDCA5')
# P Value:  0.2680165229765694
# MYBL2
# ('TPX2',)
# P Value:  0.156702495895835
# KIF18B
# ('TPX2',)
# ('KIF4A',)
# ('CDCA5',)
# ('CCNB2',)
# ('CENPA',)
# ('NCAPH',)
# ('CDC20',)
# ('KIF2C',)
# P Value:  0.11939394181331914
# CCNB2
# ('TPX2',)
# ('KIF4A',)
# ('CDCA5',)
# ('CENPA',)
# P Value:  0.09655351764643401
# NCAPH
# ('TPX2',)
# ('KIF4A',)
# ('CDCA5',)
# ('CENPA',)
# ('CDC20',)
# ('KIF2C',)
# ('TPX2', 'KIF4A')
# ('TPX2', 'CDCA5')
# ('TPX2', 'CENPA')
# P Value:  0.2781171400067628
# KIF4A
# ('TPX2',)
# ('CDCA5',)
# ('CENPA',)
# ('CDC20',)
# ('KIF2C',)
# ('TPX2', 'CDCA5')
# P Value:  0.09609710110819653
# CENPA
# ('CDC20',)
# ('TPX2',)
# ('KIF2C',)
# P Value:  0.39693840031841254
# CDCA5
# ('CDC20',)
# ('TPX2',)
# ('KIF2C',)
# ('CDC20', 'TPX2')
# ('CDC20', 'KIF2C')
# P Value:  0.3799934383830317
# TPX2
# ('CDC20',)
# ('KIF2C',)
# ('CDC20', 'KIF2C')
# P Value:  0.16822009188586073
# CDC20
# ('KIF2C',)
# KIF2C
# ('CDC20',)
# Train Adj: {'CDC20', 'KIF2C'}
# corr_X: -0.04565800864861581
# corr_Y: -0.057073270222594445
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
#                        The direction mabey that CDCA8 cause CDC20.
# corr_X: -0.08855653170110418
# corr_Y: -0.03610243814590688
# Unidentifiable:
#                        ALL direction's P-value large than 0.05.
# ...
# Init Adj: {'LINC02438'}
# Init Adj Length: 1
# LINC02438
# No much variable to CI test!
# Train Adj: {'LINC02438'}
# corr_X: -0.20052729597515734
# corr_Y: -0.4754347798246815
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that LINC01885 cause LINC02438.
# parSet: ['LINC02438']
# chiSet: []
# Start Identify!
# Aim Variable: LINC02438
# exclSet: ['ajcc_pathologic_stage', 'RHOV', 'PITX1', 'LYPD3', 'FAM83A', 'GJB3', 'AC068228.1', 'SLC2A1', 'KRT16', 'FAM83A-AS1', 'SLC2A1', 'KRT6A', 'B3GNT3', 'ANLN', 'CDCA8', 'PADI1', 'AP005233.2', 'TUBB3', 'ANLN', 'CDCA8', 'TNS4', 'PADI1', 'PTPRH', 'TPX2', 'CELSR3', 'TMEM184A', 'KIF4A', 'CDC20', 'KIF2C', 'LINC02783', 'PADI3', 'MYEOV', 'STX1A', 'LASTR', 'CKAP2L', 'KIF2C', 'SERPINB5', 'LINC02783', 'PADI3', 'NGEF', 'PSMD10P2', 'PLEKHN1', 'IQGAP3', 'NCAPH', 'ADGRF4', 'CENPA', 'AC004870.2', 'AC103740.2', 'C8orf74', 'AC005077.4',
NNC1', 'EGLN3', 'TNNC1', 'STK32A-AS1', 'CLIC5', 'CLIC5', 'LINC02560', 'LINC01460', 'Z98257.1', 'PCP4', 'TFAP2D', 'ECEL1P2', 'AGER', 'AC007639.1', 'AC080037.2', 'ECEL1P2', 'AGER', 'AC010998.1', 'AGER', 'PLXNB3', 'AC093904.4', 'AL359704.2', 'ITPRID1', 'FRMD5', 'SYT12', 'TBXT', 'AC025580.1', 'CNTN6', 'CLDN18', 'SFTPC', 'FER1L4', 'RPL32P33', 'CAVIN2', 'CNTN6', 'CLDN18', 'SFTPC', 'VEGFD', 'CLDN18', 'SFTPC', 'INMT', 'C11orf86', 'DMBX1', 'LNCDAT', 'RNF183', 'FEZF1', 'C2CD4A', 'FENDRR', 'LGI3', 'AL645608.8', 'CCNP', 'AF222684.1', 'TCF21', 'FENDRR', 'LGI3', 'ADH1B', 'LGI3', 'ADAMTS8', 'ADAMTS8', 'ADAMTS8', 'TCF21', 'TRIM31', 'IL36G', 'UPK3A', 'LINC02387', 'FEZF1-AS1', 'AC002378.1', 'CLDN10-AS1', 'AC135012.3', 'GPIHBP1', 'RECQL4', 'RUNDC3A-AS1', 'YBX2', 'IL17C', 'AC007493.1', 'AC135012.3', 'GPIHBP1', 'GPIHBP1', 'TMEM63C', 'MNX1-AS2', 'UNC5CL', 'TEK', 'RXFP1', 'TMEM63C', 'RHBG', 'SAPCD2', 'PAH', 'TRIM15', 'IL37', 'NLRP3P1', 'SYNGR4', 'AC111149.2', 'IL37', 'FGL1', 'CLDN10', 'FAM107A', 'CLEC3B', 'AURKB', 'TEDC2', 'NAT16', 'TCAM1P', 'PRAME', 'TPSP2', 'CA4', 'FAM107A', 'CLEC3B', 'FAM107A', 'CLEC3B', 'TEDC2', 'PIMREG', 'SMC1B', 'EDNRB', 'EPS8L3', 'CDK8P2', 'ANKRD34B', 'AL590666.4', 'BPIFA1', 'CDK8P2', 'FGB', 'BTNL9', 'RAMP3', 'MYBL2', 'MYBL2', 'FOXM1', 'RTBDN', 'GPC2', 'ZNF280A', 'AC120498.4', 'PRSS29P', 'FCN3', 'BTNL9', 'RAMP3', 'BTNL9', 'RAMP3', 'ANKS4B', 'DGCR5', 'DGCR5', 'LDC1P', 'RAMP3', 'CHRM1', 'AL590226.1', 'NR2E1', 'CRYGN', 'CRABP2', 'BPIFA2', 'AL606970.1', 'ADAMTS7P3', 'CD300LG' ...
# Init Adj: {'AC024230.1'}
# Init Adj Length: 1
# AC024230.1
# No much variable to CI test!
# Train Adj: {'AC024230.1'}
# corr_X: -0.36576683317295333
# corr_Y: -0.16548140895678418
# Unidentifiable:
#                    ALL direction's P-value small than 0.05.
#                    The direction mabey that AC024230.1 cause LINC02438.
# parSet: ['AC024230.1']
# chiSet: []
# Start Identify!
# Aim Variable: AC024230.1
# Init Adj: set()
# Init Adj Length: 0
# Train Adj: set()
# parSet: []
# chiSet: []
# Ancestors: {'ajcc_pathologic_stage': ['RHOV', 'PITX1'], 'RHOV': ['LYPD3', 'FAM83A'], 'PITX1': ['GJB3'], 'LYPD3': ['SLC2A1', 'KRT16'], 'FAM83A': ['FAM83A-AS1'], 'GJB3': ['SLC2A1', 'KRT6A', 'B3GNT3'], 'SLC2A1': ['ANLN', 'CDCA8'], 'KRT16': ['KRT6A', 'PADI1'], 'FAM83A-AS1': ['AP005233.2', 'TUBB3'], 'KRT6A': ['KRT16', 'TNS4'], 'B3GNT3': ['PADI1', 'PTPRH'], 'ANLN': ['CKAP2L'], 'CDCA8': ['KIF2C'], 'PADI1': ['LINC02783', 'PADI3'], 'AP005233.2': ['MYEOV'], 'TUBB3': ['STX1A', 'LASTR'], 'TNS4': ['SERPINB5'], 'PTPRH': ['NGEF', 'PSMD10P2'], 'KIF2C': ['CENPA'], 'LINC02783': ['AC004870.2'], 'PADI3': ['AC103740.2'], 'MYEOV': ['C8orf74'], 'STX1A': ['AC005077.4', 'CAMK2N2'], 'LASTR': ['ITPKA', 'ADGRF4', 'CALML3-AS1'], 'CKAP2L': ['TOP2A', 'DLGAP5'], 'SERPINB5': ['KRT6B', 'RAB3B'], 'NGEF': ['AC133785.1', 'PSMD10P2'], 'PSMD10P2': ['AHSG'], 'CENPA': ['HJURP', 'NUF2'], 'AC004870.2': ['GPR87'], 'AC103740.2': [], 'C8orf74': ['LINC00887'], 'AC005077.4': [], 'CAMK2N2': [], 'ITPKA': [], 'CALML3-AS1': ['AL732437.3', 'AL079303.1'], 'TOP2A': ['CDC6'], 'DLGAP5': [], 'KRT6B': ['DSG3'], 'RAB3B': [], 'AC133785.1': [], 'AHSG': ['CCNE1'], 'HJURP': [], 'NUF2': [], 'GPR87': ['TGM5', 'C15orf48'], 'LINC00887': ['LINC02048'], 'AL732437.3': ['LINC01977'], 'AL079303.1': ['TEX48'], 'CDC6': ['CDC45', 'CDCA5'], 'DSG3': ['SERPINB4'], 'CCNE1': [], 'TGM5': ['MYO3B', 'RAET1L'], 'C15orf48': ['GJB2'], 'LINC02048': ['DRP2'], 'LINC01977': ['AP003559.1'], 'TEX48': [], 'CDC45': ['CDCA5', 'KIF18B'], 'CDCA5': ['CDC45'], 'SERPINB4': ['MMP10'], 'MYO3B': ['KRTAP2-3'], 'RAET1L': ['UCN2'], 'TMPRSS11E': ['IL36RN', 'LIPK'], 'GJB2': ['PLPP4', 'GJB6'], 'DRP2': ['ADAM12', 'POLQ'], 'AP003559.1': ['SYT7', 'AP003108.5'], 'KIF18B': ['SPAG5'], 'MMP10': ['MMP1'], 'IL36RN': ['LINC01214', 'AC011294.1'], 'KRTAP2-3': ['MMP11'], 'UCN2': ['COL7A1'], 'LIPK': ['ARL14'], 'PLPP4': [], 'GJB6': [], 'ADAM12': ['COL11A1', 'LINC01614'], 'POLQ': ['ASPM'], 'SYT7': ['AP003108.5'], 'AP003108.5': ['AL121949.2'], 'SPAG5': ['BUB1B'], 'MMP1': ['MMP3'], 'LINC01214': ['LINC01213'], 'AC011294.1': ['EPS15P1'], 'MMP11': [], 'COL7A1': ['LINC01711', 'GPR78'], 'ARL14': ['LINC00705'], 'LINC01614': ['GREM1', 'EPYC'], 'ASPM': ['KIF14'], 'AL121949.2': ['AL121949.3'], 'BUB1B': ['MCM10'], 'MMP3': ['GREM1', 'NETO1'], 'LINC01213': ['LINC02029'], 'EPS15P1': [], 'LINC01711': ['APCDD1L'], 'GPR78': ['MANCR'], 'LINC00705': ['MANCR'], 'GREM1': ['AC113346.1'], 'EPYC': ['LINC02544', 'NETO1'], 'KIF14': [], 'AL121949.3': [], 'MCM10': [], 'NETO1': ['SLC24A2', 'AC090125.1', 'EPYC'], 'C4orf54': ['SPTB'], 'MANCR': ['ITGB1-DT'], 'LINC02029': ['AL109946.1'], 'AC113346.1': [], 'LINC02544': ['SLC24A2'], 'SLC24A2': ['LINC02544'], 'AC090125.1': ['AC112721.2'], 'SPTB': ['SLC16A9', 'AC008496.3'], 'ITGB1-DT': ['AC090192.2'], 'AL109946.1': ['LINC02003'], 'AC112721.2': ['MMP12'], 'SLC16A9': ['MUC21', 'TTLL11-IT1'], 'AC008496.3': ['AL928596.1', 'AP002957.1', 'UMODL1'], 'AC090192.2': ['TNNC1'], 'LINC02003': ['LINC00511'], 'MMP12': ['EGLN3'], 'MUC21': ['AL928596.1', 'LINC02560'], 'TTLL11-IT1': ['LINC01460'], 'AL928596.1': ['MUC21'], 'AP002957.1': ['Z98257.1'], 'UMODL1': ['PCP4', 'TFAP2D'], 'TNNC1': ['AGER'], 'LINC00511': ['AC007639.1', 'AC080037.2'], 'EGLN3': ['AC010998.1'], 'LINC02560': ['LINC01460'], 'LINC01460': ['SYT12', 'LINC02560'], 'Z98257.1': ['TBXT'], 'PCP4': ['AC025580.1'], 'TFAP2D': [], 'ECEL1P2': ['CNTN6', 'AGER'], 'AGER': ['CLDN18', 'SFTPC'], 'AC007639.1': ['FER1L4'], 'AC080037.2': ['RPL32P33', 'CAVIN2'], 'AC010998.1': ['VEGFD'], 'SYT12': ['C11orf86', 'DMBX1'], 'TBXT': ['LNCDAT'], 'AC025580.1': ['RNF183', 'FEZF1', 'C2CD4A'], 'CNTN6': ['SFTPC', 'FENDRR'], 'CLDN18': ['SFTPC'], 'SFTPC': ['LGI3'], 'FER1L4': ['AL645608.8'], 'RPL32P33': ['CCNP', 'AF222684.1'], 'CAVIN2': ['TCF21'], 'VEGFD': ['ADH1B'], 'C11orf86': ['TRIM31'], 'DMBX1': ['IL36G', 'AL645608.8'], 'LNCDAT': ['UPK3A'], 'RNF183': ['LINC02387'], 'FEZF1': ['FEZF1-AS1'], 'C2CD4A': ['AC002378.1', 'CLDN10-AS1'], 'FENDRR': ['AC135012.3'], 'LGI3': ['GPIHBP1', 'ADH1B'], 'AL645608.8': ['RECQL4', 'DMBX1', 'RUND ...
# End_time: 2024-06-04 14:57:23.338756+08:00
# time_difference: 2 days, 4:03:20.383584
